# %% [markdown]
# # NEO Data Fetching and Processing Pipeline
#
# This notebook contains a production-ready pipeline to fetch, parse, and process data for Near-Earth Objects (NEOs) from the [NeoDyS-2](https://newton.spacedys.com/neodys/) service.
#
# The pipeline is organized into three main sections:
# 1.  **Configuration & Imports:** Sets the number of objects to process (`N_OBJECTS`) and imports all necessary libraries.
# 2.  **Helper Functions:** Contains all the functions for fetching, parsing, and processing the data.
# 3.  **Execution Pipeline:** Runs the main logic to fetch the object list, verify data, process the objects, and export the final dataset.
#
# The final output is a single CSV file named `DataSet_NEO_VSA.csv` containing the processed data for the specified number of objects.

# %%
# --- Imports ---
import requests
import time
import pandas as pd
import numpy as np
import re
import random
from datetime import datetime
from io import StringIO
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import urllib.parse
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
import traceback
from astropy.time import Time
import re
from numpy.polynomial.polyutils import RankWarning
import warnings
warnings.filterwarnings("ignore", category=RankWarning)

# %%
def parse_rwo(rwo_content):
    """Parse RWO content from NeoDyS-2 format using dynamic field detection for robustness."""
    nights_data = {}
    if not rwo_content: 
        return nights_data

    lines = rwo_content.split('\n')
    for idx, line in enumerate(lines):
        # Skip header and empty lines
        if (line.startswith('!') or not line.strip() or 
            line.startswith('version') or line.startswith('errmod') or 
            line.startswith('RMS') or line.startswith('END_OF_HEADER')):
            continue
        parts = line.split()
        # Find year (4-digit number), month (1-2 digit), day_frac (float)
        year_idx, month_idx, day_frac_idx = None, None, None
        for i, val in enumerate(parts):
            if year_idx is None and re.match(r'^\d{4}$', val):
                year_idx = i
                # Try to get month and day_frac right after year
                if i+2 < len(parts):
                    month_idx = i+1
                    day_frac_idx = i+2
                break
        if year_idx is None or month_idx is None or day_frac_idx is None:
            continue
        year_val = parts[year_idx]
        month_val = parts[month_idx]
        day_frac_val = parts[day_frac_idx]
        # Check if year and month are integers and day_frac is float
        try:
            year = int(year_val) if year_val is not None and year_val.isdigit() else None
            month = int(month_val) if month_val is not None and month_val.isdigit() else None
            day_frac = float(day_frac_val) if day_frac_val is not None else None
        except Exception as e:
            print(f"DEBUG: Line {idx+1} invalid date fields: year={year_val}, month={month_val}, day_frac={day_frac_val} | {e}")
            continue
        if year is None or month is None or day_frac is None:
            print(f"DEBUG: Line {idx+1} missing or invalid date fields: year={year_val}, month={month_val}, day_frac={day_frac_val}")
            continue

        # Dynamically find RA and Dec indices: RA is 3 consecutive fields after day_frac (hours, min, sec), Dec is 3 consecutive fields after RA (deg, min, sec)
        ra_start = day_frac_idx + 2
        dec_start = None
        # Find RA indices (should be float/int values)
        if ra_start + 2 < len(parts):
            ra_h_idx, ra_m_idx, ra_s_idx = ra_start, ra_start+1, ra_start+2
        else:
            continue
        # Find Dec indices: look for first value after RA that matches degree pattern (+/-dd or dd)
        for j in range(ra_s_idx+1, len(parts)-2):
            if re.match(r'^[+-]?\d+$', parts[j]):
                dec_start = j
                break
        if dec_start is not None and dec_start+2 < len(parts):
            dec_d_idx, dec_m_idx, dec_s_idx = dec_start, dec_start+1, dec_start+2
        else:
            continue

        try:
            day_int = int(day_frac)
            frac = day_frac - day_int
            total_seconds = frac * 24 * 3600
            hours = int(total_seconds // 3600)
            minutes = int((total_seconds % 3600) // 60)
            seconds = int(total_seconds % 60)

            ra_h = float(parts[ra_h_idx]) if parts[ra_h_idx] is not None else 0.0
            ra_m = float(parts[ra_m_idx]) if parts[ra_m_idx] is not None else 0.0
            ra_s = float(parts[ra_s_idx]) if parts[ra_s_idx] is not None else 0.0
            alpha = np.deg2rad(15.0 * (ra_h + ra_m / 60.0 + ra_s / 3600.0))

            dec_d = float(parts[dec_d_idx]) if parts[dec_d_idx] is not None else 0.0
            dec_m = float(parts[dec_m_idx]) if parts[dec_m_idx] is not None else 0.0
            dec_s = float(parts[dec_s_idx]) if parts[dec_s_idx] is not None else 0.0
            dec_sign = -1 if str(parts[dec_d_idx]).startswith('-') else 1
            delta_deg = dec_sign * (abs(dec_d) + dec_m / 60.0 + dec_s / 3600.0)
            delta = np.deg2rad(delta_deg)

            iso_str = f"{year:04d}-{month:02d}-{day_int:02d}T{hours:02d}:{minutes:02d}:{seconds:02d}"
            epoch = Time(iso_str, format='isot', scale='utc').mjd
            night_date = f"{year}-{month:02d}-{day_int:02d}"
            if night_date not in nights_data:
                nights_data[night_date] = []
            nights_data[night_date].append({
                'mjd': epoch,
                'alpha': alpha,
                'delta': delta
            })

        except (ValueError, IndexError, KeyError) as e:
            print(f"DEBUG: Line {idx+1} parse error: {repr(line)} | {e}")
            continue

    return nights_data

def fetch_kep_elements(object_name):
    """Fetches and parses real Keplerian elements using table row order and symbol labels."""
    encoded_name = urllib.parse.quote(object_name)
    url = f"https://newton.spacedys.com/neodys/index.php?pc=1.1.1&n={encoded_name}"
    html_content = get_content(url)
    if not html_content:
        return {}
    try:
        soup = BeautifulSoup(html_content, 'html.parser')
        tables = soup.find_all('table')
        for table in tables:
            if "keplerian" in table.get_text(strip=True).lower():
                rows = table.find_all('tr')
                values = []
                for row in rows:
                    cells = row.find_all(['td', 'th'])
                    if len(cells) >= 2:
                        val = cells[1].get_text(strip=True)
                        numeric_match = re.search(r'([-+]?\d*\.?\d+)', val)
                        if numeric_match:
                            values.append(float(numeric_match.group(1)))
                if len(values) >= 6:
                    # Assign by order: a, e, i, Omega (symbol), omega (symbol), M
                    elements = {
                        'a_kep': values[0],
                        'e': values[1],
                        'i': values[2],
                        'Omega': values[3],
                        'omega': values[4],
                        'M': values[5]
                    }
                    return elements
    except Exception as e:
        pass
    return {}

def process_object(neo_name):
    """
    Fetches, parses, and processes all data for a single NEO object and validates
	that the files contain usable data (e.g., RWO has valid nights, elements are present).
    This function is designed to be executed in a concurrent manner.

    Args:
        neo_name (str): The name of the NEO object to process.

    Returns:
        tuple: A tuple containing:
            - list: A list of dictionaries, each representing a processed observation night.
            - str: The name of the object, for tracking.
            - str: The status of the processing ('processed' or 'rejected').
    """

    ALPHA_DOT_THRESHOLD = np.pi/2  # radians/day
    DELTA_DOT_THRESHOLD = np.pi/2  # radians/day

    ALPHA_MIN, ALPHA_MAX = 0.0, 2 * np.pi
    DELTA_MIN, DELTA_MAX = -np.pi / 2, np.pi / 2

    # Step 1: Fetch all required data for the object
    rwo_result = fetch_rwo(neo_name)
    kep_elements = fetch_kep_elements(neo_name)
    eq0_elements = fetch_equ0_elements(neo_name)

    # Step 2: Validate that ALL required data was fetched successfully
    # Require RWO data AND Keplerian elements AND EQU elements
    if not rwo_result or not rwo_result.get('content') or not kep_elements or not eq0_elements:
        print(f"REJECTED: Missing data for {neo_name}")
        return [], neo_name, 'rejected'

    # Step 3: Parse the RWO data to get observation nights
    nights_data = parse_rwo(rwo_result['content'])
    if not nights_data:
        print(f"REJECTED: No valid nights for {neo_name}")
        return [], neo_name, 'rejected'

    # Step 4: Process each valid night of observation to create data rows
    object_rows = []
    sorted_nights = sorted(nights_data.items())
    for night_index, (night_date, obs_list) in enumerate(sorted_nights, 1):
        alpha_dot, delta_dot = 0.0, 0.0
        a_fit, d_fit = None, None
        if len(obs_list) < 2:
            print(f"Skipping night {night_index} ({night_date}) due to insufficient observations: {len(obs_list)}")
            continue

        obs_list.sort(key=lambda o: o.get('mjd', 0))
        mid_obs = obs_list[len(obs_list) // 2]
        t_fit = mid_obs.get('mjd', 0.0)

        # Calculate alpha_dot and delta_dot using np.polyfit (same as loader)
        if len(obs_list) >= 4:
            t = np.array([obs['mjd'] for obs in obs_list])
            alpha = np.array([obs['alpha'] for obs in obs_list])
            delta = np.array([obs['delta'] for obs in obs_list])

            with warnings.catch_warnings(record=True) as w:
                warnings.simplefilter('always', RankWarning)
                try:
                    a_fit = np.polyfit(t, alpha, 2)
                    d_fit = np.polyfit(t, delta, 2)
                    rankwarn = any(isinstance(warn.message, RankWarning) for warn in w)
                    if rankwarn:
                        a_fit = np.polyfit(t, alpha, 1)
                        d_fit = np.polyfit(t, delta, 1)
                        alpha_dot = a_fit[0]
                        delta_dot = d_fit[0]
                    else:
                        alpha_dot = 2 * a_fit[0] * t_fit + a_fit[1]
                        delta_dot = 2 * d_fit[0] * t_fit + d_fit[1]
                except Exception as fit_err:
                    print(f"Fit error in night {night_index}: {fit_err}")
                    a_fit, d_fit = None, None
                    alpha_dot, delta_dot = 0.0, 0.0

        elif len(obs_list) <= 3:
            t = np.array([obs['mjd'] for obs in obs_list])
            alpha = np.array([obs['alpha'] for obs in obs_list])
            delta = np.array([obs['delta'] for obs in obs_list])
            try:
                a_fit = np.polyfit(t, alpha, 1)
                d_fit = np.polyfit(t, delta, 1)
                alpha_dot = a_fit[0]
                delta_dot = d_fit[0]
            except Exception as fit_err:
                print(f"Linear fit error in night {night_index}: {fit_err}")
                a_fit, d_fit = None, None
                alpha_dot, delta_dot = 0.0, 0.0

        row = {
            'object': neo_name, 'night': night_index, 't_fit': t_fit,
            'alpha': mid_obs.get('alpha', 0.0), 'delta': mid_obs.get('delta', 0.0),
            'alpha_dot': alpha_dot, 'delta_dot': delta_dot, 
            **kep_elements, **eq0_elements
        }

        if (-ALPHA_DOT_THRESHOLD < alpha_dot < ALPHA_DOT_THRESHOLD and 
            -DELTA_DOT_THRESHOLD < delta_dot < DELTA_DOT_THRESHOLD and
             ALPHA_MIN <= row['alpha'] <= ALPHA_MAX and
            DELTA_MIN <= row['delta'] <= DELTA_MAX ):

            object_rows.append(row)
        else:
            print(f"Skipping night {night_index} for {neo_name} due to non-physical fit estimations")
            continue

    if not object_rows:
        print(f"REJECTED: No valid nights with enough observations for {neo_name}")
        return [], neo_name, 'rejected'

    return object_rows, neo_name, 'processed'

# %%
def get_content(url, timeout=30, max_retries=3):
    """
    Fetches content from a URL with improved error handling and retries.
    Updated with robust session configuration to avoid HTTP 403 errors.
    """
    session = requests.Session()
    
    # Configure retry strategy
    retry_strategy = Retry(
        total=max_retries,
        backoff_factor=2,
        status_forcelist=[403, 429, 500, 502, 503, 504],
        allowed_methods=["HEAD", "GET", "OPTIONS"]
    )
    
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    
    # Enhanced headers to mimic real browser behavior (fixes 403 errors)
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'none',
        'Sec-Fetch-User': '?1',
        'Cache-Control': 'max-age=0',
        'DNT': '1',
        'Sec-CH-UA': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
        'Sec-CH-UA-Mobile': '?0',
        'Sec-CH-UA-Platform': '"Linux"'
    })
    
    try:
        response = session.get(url, timeout=timeout)  # Removed verify=False
        response.raise_for_status()
        return response.text
    except requests.exceptions.Timeout:
        return None
    except requests.exceptions.ConnectionError:
        return None
    except requests.exceptions.HTTPError as e:
        if e.response.status_code != 404:
            print(f"🔥 HTTP error {e.response.status_code} fetching {url}")
        return None
    except Exception:
        return None
    finally:
        session.close()

def is_valid_neo_name(name):
    """Validate NEO object names to filter out invalid entries."""
    if not name or len(name) < 4:
        return False
    
    # Clean the name
    name = name.strip()
    
    # More precise patterns for NEO names
    patterns = [
        r'^\d{4}\s+[A-Z]{1,3}\d*$',     # e.g., "2023 BU", "1991 VG"
        r'^\d{4}[A-Z]{1,3}\d*$',        # e.g., "2015RN35", "2019EA2" (no space)
        r'^\(\d+\)\s*[A-Za-z\s]*$',     # e.g., "(433) Eros", "(1) Ceres"
        r'^[A-Z]{2,}\d+$',              # e.g., "AA29", "BD", etc.
    ]
    
    # Check if it matches any valid pattern
    if not any(re.match(pattern, name) for pattern in patterns):
        return False
    
    # Additional filters to exclude obviously invalid names
    invalid_keywords = [
        'object', 'name', 'http', 'www', 'com', 'neodys', 'spacedys',
        'index', 'php', 'table', 'cell', 'row', 'column', 'data',
        'the', 'and', 'or', 'but', 'for', 'with', 'without'
    ]
    
    name_lower = name.lower()
    if any(keyword in name_lower for keyword in invalid_keywords):
        return False
    
    # Must contain at least one digit and one letter
    has_digit = any(c.isdigit() for c in name)
    has_letter = any(c.isalpha() for c in name)
    
    return has_digit and has_letter

def get_all_prefixes(page_url):
    """Fetch the list of all NEO objects from the main NeoDyS-2 page."""
    url = page_url
    html_content = get_content(url)
    
    if html_content:
        soup = BeautifulSoup(html_content, 'html.parser')
        neo_objects = []
        
        # Strategy 1: Look for links containing object names
        for link in soup.find_all('a', href=True):
            if 'pc=1.1.1&n=' in link.get('href', ''):
                # Extract the object name from the URL parameter
                href = link.get('href', '')
                if '&n=' in href:
                    name = href.split('&n=')[1].split('&')[0]  # Get name from URL
                    name = name.replace('%20', ' ')  # Decode URL encoding
                    if is_valid_neo_name(name):
                        neo_objects.append(name)
        
        # Strategy 2: Look for text patterns that match NEO names
        page_text = soup.get_text()
        # Find year-letter-number patterns (e.g., 2015 RN35, 2019EA2)
        neo_patterns = [
            r'\b(\d{4}\s+[A-Z]{1,3}\d+)\b',  # 2015 RN35
            r'\b(\d{4}[A-Z]{1,3}\d+)\b',     # 2015RN35
            r'\b(\(\d+\)\s*[A-Za-z\s]*)\b'   # (433) Eros
        ]
        
        for pattern in neo_patterns:
            matches = re.findall(pattern, page_text)
            for match in matches:
                name = match.strip()
                if is_valid_neo_name(name):
                    neo_objects.append(name)
        
        if neo_objects:
            unique_neos = list(set(neo_objects))
            print(f"Successfully extracted {len(unique_neos)} NEOs from the website.")
            return unique_neos  # Return all extracted NEOs, not limited
    
    # Fallback: try a different page or approach
    print("Primary extraction failed. Trying alternative approach...")
    
    # Try the main NEA list page
    alt_url = "https://newton.spacedys.com/neodys/index.php?pc=1.1.0"
    html_content = get_content(alt_url)
    
    if html_content:
        soup = BeautifulSoup(html_content, 'html.parser')
        neo_objects = []
        
        # Look for any NEO-like patterns in the text
        page_text = soup.get_text()
        neo_patterns = [
            r'\b(\d{4}\s+[A-Z]{1,3}\d+)\b',
            r'\b(\d{4}[A-Z]{1,3}\d+)\b'
        ]
        
        for pattern in neo_patterns:
            matches = re.findall(pattern, page_text)
            for match in matches:
                name = match.strip()
                if is_valid_neo_name(name):
                    neo_objects.append(name)
        
        if neo_objects:
            unique_neos = list(set(neo_objects))
            print(f"Alternative extraction found {len(unique_neos)} NEOs.")
            return unique_neos  # Return all found NEOs, not limited
    
    print("❌ Could not extract NEO names from website. Please check the NeoDyS-2 site structure.")
    return []

def fetch_rwo(object_name):
    """Fetch RWO file content from NeoDyS-2."""
    # URL encode the object name to handle spaces and special characters
    encoded_name = urllib.parse.quote(object_name.replace(" ", "%20"))
    url = f"https://newton.spacedys.com/~neodys2/mpcobs/{encoded_name}.rwo"
    content = get_content(url)
    if content and not content.lower().startswith('<html>'):
        return {'content': content}
    else:
        return None

def fetch_equ0_elements(object_name):
    """Fetch EQU elements from .eq0 file.
    Returns exactly 6 equinoctial elements: a_equ, h, k, p, q, lambda
    """
    encoded_name = urllib.parse.quote(object_name.replace(" ", "%20"))
    url = f"https://newton.spacedys.com/~neodys2/epoch/{encoded_name}.eq0"
    response_text = get_content(url)
    if not response_text: 
        return {}
    try:
        for line in response_text.strip().split('\n'):
            if line.strip().startswith('EQU'):
                parts = line.split()
                # Extract exactly 6 equinoctial elements: a_equ, h, k, p, q, lambda
                if len(parts) >= 8:  # Has a, h, k, p, q, lambda, plus extra data
                    result = {
                        'a_equ': float(parts[1]),      # Semi-major axis (equinoctial)
                        'h': float(parts[2]),          # h = e * sin(omega + Omega)
                        'k': float(parts[3]),          # k = e * cos(omega + Omega)
                        'p': float(parts[4]),          # p = tan(i/2) * sin(Omega)
                        'q': float(parts[5]),          # q = tan(i/2) * cos(Omega)
                        'lambda': float(parts[6])      # lambda = M + omega + Omega
                    }
                    return result
                elif len(parts) >= 7:  # Missing one element, fill with default
                    result = {
                        'a_equ': float(parts[1]) if len(parts) > 1 else 1.0,
                        'h': float(parts[2]) if len(parts) > 2 else 0.0,
                        'k': float(parts[3]) if len(parts) > 3 else 0.0,
                        'p': float(parts[4]) if len(parts) > 4 else 0.0,
                        'q': float(parts[5]) if len(parts) > 5 else 0.0,
                        'lambda': float(parts[6]) if len(parts) > 6 else 0.0
                    }
                    return result
    except (ValueError, IndexError) as e: 
        pass
    return {}

def create_dataset(neo_list):
    """
    Processes a list of NEO names concurrently to fetch their data, including RWO, 
    Keplerian elements, and corrected equinoctial elements.

    Args:
        neo_list (list): A list of NEO names to process.

    Returns:
        tuple: A tuple containing:
            - list: A list of dictionaries, where each dictionary represents a row in the final dataset.
            - int: The number of objects that were rejected due to missing data.
    """
    all_rows = []
    rejected_count = 0
    
    # Use ThreadPoolExecutor to process objects in parallel
    with ThreadPoolExecutor(max_workers=20) as executor:
        # Create a future for each NEO object processing task
        future_to_neo = {executor.submit(process_object, neo_name): neo_name for neo_name in neo_list}
        
        # Use tqdm to create a progress bar for the concurrent tasks
        pbar = tqdm(as_completed(future_to_neo), total=len(neo_list), desc="Processing NEOs")
        
        for future in pbar:
            try:
                # Get the result from the completed future
                object_rows, neo_name, status = future.result()
                
                if status == 'processed' and object_rows:
                    all_rows.extend(object_rows)
                else:
                    rejected_count += 1
            except Exception as e:
                # Handle exceptions that might occur within the thread
                neo_name = future_to_neo[future]
                rejected_count += 1

    return all_rows, rejected_count

def check_data_availability(neo_name):
    """
    Lightweight check to verify only if all three data sources (RWO, Keplerian, EQU) are available,
    but not their quality. Uses HEAD requests or minimal content fetching for efficiency.
    Updated with robust session to avoid HTTP 403 errors.
    
    Args:
        neo_name (str): The NEO name to check
        
    Returns:
        bool: True if all three data sources are available, False otherwise
    """
	    
    # Prepare URLs for all three data sources
    encoded_name = urllib.parse.quote(neo_name.replace(" ", "%20"))
    
    urls_to_check = {
        'rwo': f"https://newton.spacedys.com/~neodys2/mpcobs/{encoded_name}.rwo",
        'equ': f"https://newton.spacedys.com/~neodys2/epoch/{encoded_name}.eq0",
        'kep': f"https://newton.spacedys.com/neodys/index.php?pc=1.1.1&n={urllib.parse.quote(neo_name)}"
    }
    
    session = requests.Session()
    # Use the same robust headers that fixed the 403 errors
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'none',
        'Sec-Fetch-User': '?1',
        'Cache-Control': 'max-age=0'
    })
    
    available_sources = 0
    
    try:
        # Check RWO file availability (HEAD request is faster)
        try:
            response = session.head(urls_to_check['rwo'], timeout=5)  # Removed verify=False
            if response.status_code == 200:
                available_sources += 1
        except:
            pass
            
        # Check EQU file availability (HEAD request is faster)
        try:
            response = session.head(urls_to_check['equ'], timeout=5)  # Removed verify=False
            if response.status_code == 200:
                available_sources += 1
        except:
            pass
            
        # Check Keplerian elements page (need to GET to check content)
        try:
            response = session.get(urls_to_check['kep'], timeout=5)  # Removed verify=False
            if response.status_code == 200 and 'keplerian' in response.text.lower():
                available_sources += 1
        except:
            pass
            
    except Exception:
        pass
    finally:
        session.close()
    
    # Return True only if all 3 sources are available
    return available_sources >= 3

def validate_object(all_neo_names, target_count, use_random_sampling=True, random_seed=None):
    """
    Validates NEO names and checks data availability to ensure exactly target_count 
    valid NEOs with complete data are selected.
    
    Args:
        all_neo_names (list): List of all NEO names from the website
        target_count (int): Number of validated NEOs needed
        use_random_sampling (bool): Whether to randomly sample or take first N objects
        random_seed (int): Random seed for reproducible results (None for true randomness)
        
    Returns:
        list: List of exactly target_count NEO names with complete data available
    """
    sampling_method = "random sampling" if use_random_sampling else "sequential selection"
    print(f"🔍 Validating NEOs with data availability check (target: {target_count}, method: {sampling_method})...")
    
    # Step 1: Filter for valid NEO names first
    valid_names = [name for name in all_neo_names if is_valid_neo_name(name)]
    print(f"📋 Found {len(valid_names)} NEOs with valid name patterns")
    
    # Step 2: Apply sampling strategy
    if use_random_sampling:
        # Set random seed for reproducibility if provided
        if random_seed is not None:
            random.seed(random_seed)
            print(f"🎲 Using random seed {random_seed} for reproducible sampling")
        
        # Randomly shuffle the valid names for diverse sampling
        random.shuffle(valid_names)
        print(f"🎲 Randomly shuffled NEO list for diverse sampling")
        
        # Check more NEOs than needed to account for failures (random sampling)
        check_limit = min(len(valid_names), target_count * 5)
    else:
        # Sequential selection - take first N objects
        print(f"📝 Using sequential selection (first {target_count} valid NEOs)")
        check_limit = min(len(valid_names), target_count * 3)  # Smaller buffer for sequential
    
    validated_neos = []
    checked_count = 0
    
    # Step 3: Use ThreadPoolExecutor for concurrent validation
    with ThreadPoolExecutor(max_workers=10) as executor:
        # Create futures for validation tasks
        future_to_name = {}
        
        for name in valid_names[:check_limit]:
            future = executor.submit(check_data_availability, name)
            future_to_name[future] = name
        
        print(f"🚀 Started validation of {len(future_to_name)} NEOs using {sampling_method}...")
        
        # Process completed validation tasks
        for future in as_completed(future_to_name):
            name = future_to_name[future]
            checked_count += 1
            
            try:
                has_complete_data = future.result()
                if has_complete_data:
                    validated_neos.append(name)
                    print(f"✅ {len(validated_neos)}/{target_count}: {name} (checked {checked_count})")
                    
                    # Stop when we have enough validated NEOs
                    if len(validated_neos) >= target_count:
                        # Cancel remaining futures to save resources
                        for remaining_future in future_to_name:
                            if not remaining_future.done():
                                remaining_future.cancel()
                        break
                else:
                    print(f"❌ {name}: Missing data sources (checked {checked_count})")
                    
            except Exception as e:
                print(f"⚠️ {name}: Validation error - {str(e)[:50]}...")
                
    print(f"🎯 Validation complete: Found {len(validated_neos)} NEOs with complete data (checked {checked_count} total)")
    return validated_neos

# %%
# FINAL PIPELINE RUN

# --- Configuration ---
N_OBJECTS = 4000 # Number of objects to process
RANDOM_SAMPLING = True # Use random sampling instead of first N_OBJECTS
RANDOM_SEED = 42 # Random seed for reproducible results (set to None for true randomness)

# t0 = 60800.0 #[MJD] Initial time for the database, according to NeoDys-2 website

# NeoDys-2 query url f
page_url = "https://newton.spacedys.com/neodys/index.php?pc=3.2.1&pc0=3.2&lra=&ura=&lde=&ude=&lvm=&uvm=&lel=&uel=&lph=&uph=&lgl=&ugl=&ldfe=&udfe=&ldfs=&udfs=&lmo=&umo=&lspu=&uspu=&ldu=&udu=&lal=1&ual=3"

# 1. Get all NEO names from the website
print("🛰️ Fetching all NEO names from NeoDyS-2...")
all_neo_names = get_all_prefixes(page_url)
print(f"🌍 Found {len(all_neo_names)} total NEOs.")

# 2. Validate NEOs to get a list of N_OBJECTS with all required data
print(f"\n🔍 Validating NEOs to find {N_OBJECTS} objects with complete data...")
validated_neo_names = validate_object(
    all_neo_names, 
    N_OBJECTS, 
    use_random_sampling=RANDOM_SAMPLING,
    random_seed=RANDOM_SEED
)
print(f"✅ Validated {len(validated_neo_names)} NEOs.")

# 3. Process the validated NEOs using the corrected pipeline
print(f"\n⚙️ Processing {len(validated_neo_names)} validated NEOs in parallel...")
final_dataset_rows, rejected_count = create_dataset(validated_neo_names)

# 4. Create the final DataFrame and save to CSV
print(f"\n💾 Creating final DataFrame and saving to CSV...")
if final_dataset_rows:
    final_df = pd.DataFrame(final_dataset_rows)
    
    # Report results
    successful_count = len(validated_neo_names) - rejected_count
    print(f"\n📊 PROCESSING SUMMARY:")
    print(f"   🎯 Target NEOs: {N_OBJECTS}")
    print(f"   ✅ Successfully processed: {successful_count}")
    print(f"   ❌ Rejected: {rejected_count}")
    print(f"   📊 Total data rows: {len(final_df)}")
    print(f"   🎯 Success rate: {(successful_count/len(validated_neo_names)*100):.1f}%")
    
    # Ensure consistent column order (basic + 6 Keplerian + 6 Equinoctial)
    # Check which equinoctial columns are available
    available_cols = final_df.columns.tolist()
    
    # Define exact column sets as per specification:
    # Keplerian: a_kep, e, i, Omega, omega, M
    # Equinoctial: a_equ, h, k, p, q, lambda
    basic_cols = ['object', 'night', 't_fit', 'alpha', 'delta', 'alpha_dot', 'delta_dot']
    keplerian_cols = ['a_kep', 'e', 'i', 'Omega', 'omega', 'M']
    equinoctial_cols = ['a_equ', 'h', 'k', 'p', 'q', 'lambda']
    
    # Create final column order (now with separate a_kep and a_equ)
    # Format: basic + 6 Keplerian + 6 Equinoctial (no shared columns)
    final_column_order = basic_cols + ['a_kep', 'e', 'i', 'Omega', 'omega', 'M', 'a_equ', 'h', 'k', 'p', 'q', 'lambda']
    
    # Ensure all required columns exist, add missing with default values
    missing_cols = [col for col in final_column_order if col not in available_cols]
    if missing_cols:
        print(f"⚠️  Adding missing columns with default values: {missing_cols}")
        for col in missing_cols:
            final_df[col] = 0.0
    
    final_df = final_df[final_column_order]
    
    print(f"\n📋 Final dataset structure:")
    print(f"   Basic fields: {len(basic_cols)}")
    print(f"   Keplerian elements: 6 (a_kep, e, i, Omega, omega, M)")
    print(f"   Equinoctial elements: 6 (a_equ, h, k, p, q, lambda)")
    print(f"   Total columns: {len(final_column_order)}")
    print(f"   Note: Separate semi-major axes: a_kep (Keplerian) and a_equ (Equinoctial)")
    
    # Save to CSV
    output_path = "./DataSet_NEO_VSA.csv"
    final_df.to_csv(output_path, index=False)
    
    print(f"\n🎉 SUCCESS! Pipeline complete.")
    print(f"Dataset saved to: {output_path}")
    print(f"📋 Columns: {final_column_order}")
else:
    print("❌ No data was processed. The final dataset is empty.")
# Out:
# 🛰️ Fetching all NEO names from NeoDyS-2...
# Successfully extracted 4611 NEOs from the website.
# 🌍 Found 4611 total NEOs.
#
# 🔍 Validating NEOs to find 4000 objects with complete data...
# 🔍 Validating NEOs with data availability check (target: 4000, method: random sampling)...
# 📋 Found 4611 NEOs with valid name patterns
# 🎲 Using random seed 42 for reproducible sampling
# 🎲 Randomly shuffled NEO list for diverse sampling
# 🚀 Started validation of 4611 NEOs using random sampling...
# ✅ 1/4000: 2017VV12 (checked 1)
# ✅ 2/4000: 2021GN10 (checked 2)
# ✅ 3/4000: 2015DO224 (checked 3)
# ✅ 4/4000: 2007EE126 (checked 4)
# ✅ 5/4000: 2012FB14 (checked 5)
# ✅ 6/4000: 2024CT6 (checked 6)
# ✅ 7/4000: 2009BJ2 (checked 7)
# ✅ 8/4000: 2006GU2 (checked 8)
# ✅ 9/4000: 2023KU4 (checked 9)
# ✅ 10/4000: 2011EY11 (checked 10)
# ✅ 11/4000: 2024RW13 (checked 11)
# ✅ 12/4000: 2024SV2 (checked 12)
# ✅ 13/4000: 2015DS198 (checked 13)
# ✅ 14/4000: 2024CY1 (checked 14)
# ✅ 15/4000: 2013VP4 (checked 15)
# ✅ 16/4000: 2022SV7 (checked 16)
# ✅ 17/4000: 2022AQ1 (checked 17)
# ✅ 18/4000: 2005TC51 (checked 18)
# ✅ 19/4000: 2023TY8 (checked 19)
# ✅ 20/4000: 2017PK25 (checked 20)
# ✅ 21/4000: 2022WP9 (checked 21)
# ✅ 22/4000: 2023TX1 (checked 22)
# ✅ 23/4000: 2021TU4 (checked 23)
# ✅ 24/4000: 2014WR7 (checked 24)
# ✅ 25/4000: 2023SR5 (checked 25)
# ✅ 26/4000: 2024XE6 (checked 26)
# ✅ 27/4000: 2014HS196 (checked 27)
# ✅ 28/4000: 2018RM7 (checked 28)
# ✅ 29/4000: 2024XL4 (checked 29)
# ✅ 30/4000: 2013CW129 (checked 30)
# ✅ 31/4000: 2019AT14 (checked 31)
# ✅ 32/4000: 2023CA1 (checked 32)
# ✅ 33/4000: 2015QK9 (checked 33)
# ✅ 34/4000: 2019AJ10 (checked 34)
# ✅ 35/4000: 2025KU1 (checked 35)
# ✅ 36/4000: 2008VT4 (checked 36)
# ✅ 37/4000: 2020YG1 (checked 37)
# ✅ 38/4000: 2024RR8 (checked 38)
# ✅ 39/4000: 2020KG5 (checked 39)
# ✅ 40/4000: 2013JH22 (checked 40)
# ✅ 41/4000: 2024AB3 (checked 41)
# ✅ 42/4000: 2014BV43 (checked 42)
# ✅ 43/4000: 2023JA3 (checked 43)
# ✅ 44/4000: 2013PA67 (checked 44)
# ✅ 45/4000: 2022UF16 (checked 45)
# ✅ 402/4000: 2020XT1 (checked 478)
# ✅ 403/4000: 2024BJ4 (checked 479)
# ✅ 404/4000: 2023KV3 (checked 480)
# ❌ 2022QS36: Missing data sources (checked 481)
# ✅ 405/4000: 2022WK3 (checked 482)
# ❌ 2021LU5: Missing data sources (checked 483)
# ❌ 2017WE15: Missing data sources (checked 484)
# ✅ 406/4000: 2024GL2 (checked 485)
# ❌ 2022BL2: Missing data sources (checked 486)
# ❌ 2018RN7: Missing data sources (checked 487)
# ❌ 2024PE2: Missing data sources (checked 488)
# ✅ 407/4000: 2024JR3 (checked 489)
# ❌ 2021VM22: Missing data sources (checked 490)
# ❌ 2019SG1: Missing data sources (checked 491)
# ❌ 2020BK8: Missing data sources (checked 492)
# ❌ 2019VO3: Missing data sources (checked 493)
# ❌ 2024GB3: Missing data sources (checked 494)
# ✅ 408/4000: 2000JX8 (checked 495)
# ❌ 2022RR1: Missing data sources (checked 496)
# ❌ 2020DP14: Missing data sources (checked 497)
# ❌ 2020SJ2: Missing data sources (checked 498)
# ❌ 2023UM3: Missing data sources (checked 499)
# ❌ 2017AE21: Missing data sources (checked 500)
# ❌ 2019CQ5: Missing data sources (checked 501)
# ❌ 2021RR2: Missing data sources (checked 502)
# ❌ 2017XM61: Missing data sources (checked 503)
# ❌ 2017UO43: Missing data sources (checked 504)
# ✅ 409/4000: 2025HM6 (checked 505)
# ❌ 2019FZ1: Missing data sources (checked 506)
# ❌ 2019NF7: Missing data sources (checked 507)
# ❌ 2021EN4: Missing data sources (checked 508)
# ❌ 2017AH5: Missing data sources (checked 509)
# ❌ 2025CB3: Missing data sources (checked 510)
# ❌ 2022CQ6: Missing data sources (checked 511)
# ❌ 2020PU3: Missing data sources (checked 512)
# ✅ 410/4000: 2018CA15 (checked 513)
# ❌ 2023VP3: Missing data sources (checked 514)
# ❌ 2005UF150: Missing data sources (checked 515)
# ❌ 2024AX3: Missing data sources (checked 516)
# ❌ 2022QH41: Missing data sources (checked 517)
# ❌ 2021VY4: Missing data sources (checked 518)
# ❌ 2022UU15: Missing data sources (checked 519)
# ❌ 2022NT1: Missing data sources (checked 520)
# ✅ 411/4000: 2023UF10 (checked 521)
# ✅ 412/4000: 2022YV2 (checked 522)
# ❌ 2020RG2: Missing data sources (checked 523)
# ❌ 2020PZ3: Missing data sources (checked 524)
# ✅ 413/4000: 2021VL22 (checked 525)
# ❌ 2024RT5: Missing data sources (checked 526)
# ❌ 2025CZ1: Missing data sources (checked 527)
# ❌ 2018PC9: Missing data sources (checked 528)
# ❌ 2022VG1: Missing data sources (checked 529)
# ❌ 2013KT1: Missing data sources (checked 530)
# ❌ 2007UE6: Missing data sources (checked 531)
# ✅ 414/4000: 2019VV5 (checked 532)
# ❌ 2012EM5: Missing data sources (checked 533)
# ❌ 2004FG29: Missing data sources (checked 534)
# ✅ 415/4000: 2020UR3 (checked 535)
# ❌ 2017WL28: Missing data sources (checked 536)
# ❌ 2023SR6: Missing data sources (checked 537)
# ❌ 2018CL2: Missing data sources (checked 538)
# ❌ 2022UC21: Missing data sources (checked 539)
# ❌ 2018QS1: Missing data sources (checked 540)
# ❌ 2009FT23: Missing data sources (checked 541)
# ❌ 2021CC1: Missing data sources (checked 542)
# ✅ 416/4000: 2025EP2 (checked 543)
# ❌ 2021FC2: Missing data sources (checked 544)
# ❌ 2024VG2: Missing data sources (checked 545)
# ❌ 2024SB1: Missing data sources (checked 546)
# ❌ 2025CJ4: Missing data sources (checked 547)
# ❌ 2020BH10: Missing data sources (checked 548)
# ❌ 2019JT5: Missing data sources (checked 549)
# ❌ 2023SB1: Missing data sources (checked 550)
# ❌ 2016GA252: Missing data sources (checked 551)
# ❌ 2024SH2: Missing data sources (checked 552)
# ❌ 2007VF189: Missing data sources (checked 553)
# ❌ 2021CC7: Missing data sources (checked 554)
# ❌ 2020AT1: Missing data sources (checked 555)
# ✅ 417/4000: 2014WR362 (checked 556)
# ❌ 2023JW1: Missing data sources (checked 557)
# ❌ 2001UU16: Missing data sources (checked 558)
# ❌ 2022PY16: Missing data sources (checked 559)
# ❌ 2018TG3: Missing data sources (checked 560)
# ❌ 2019UZ10: Missing data sources (checked 561)
# ❌ 2021PP5: Missing data sources (checked 562)
# ❌ 2023XS10: Missing data sources (checked 563)
# ❌ 2010XV58: Missing data sources (checked 564)
# ❌ 2022PW1: Missing data sources (checked 565)
# ❌ 2024BV1: Missing data sources (checked 566)
# ✅ 418/4000: 2021EZ1 (checked 567)
# ❌ 2020PL1: Missing data sources (checked 568)
# ❌ 2011CJ33: Missing data sources (checked 569)
# ✅ 419/4000: 2022QH3 (checked 570)
# ❌ 2023SB3: Missing data sources (checked 571)
# ❌ 2022CJ3: Missing data sources (checked 572)
# ❌ 2024JP3: Missing data sources (checked 573)
# ✅ 420/4000: 2012FY13 (checked 574)
# ❌ 2013HT25: Missing data sources (checked 575)
# ❌ 2014YK42: Missing data sources (checked 576)
# ❌ 2024UA5: Missing data sources (checked 577)
# ❌ 2025BO1: Missing data sources (checked 578)
# ✅ 421/4000: 2019BL2 (checked 579)
# ❌ 2012HO8: Missing data sources (checked 580)
# ❌ 2021UM4: Missing data sources (checked 581)
# ❌ 2010RD130: Missing data sources (checked 582)
# ❌ 2011LB19: Missing data sources (checked 583)
# ❌ 2022OG3: Missing data sources (checked 584)
# ❌ 2022OC10: Missing data sources (checked 585)
# ❌ 2011EO11: Missing data sources (checked 586)
# ❌ 2017YB15: Missing data sources (checked 587)
# ❌ 2025DN6: Missing data sources (checked 588)
# ❌ 2019RP1: Missing data sources (checked 589)
# ❌ 2022AM3: Missing data sources (checked 590)
# ❌ 2023UQ2: Missing data sources (checked 591)
# ❌ 2017BY6: Missing data sources (checked 592)
# ❌ 2023UL3: Missing data sources (checked 593)
# ✅ 422/4000: 2021CH37 (checked 594)
# ❌ 2017QZ34: Missing data sources (checked 595)
# ❌ 2017BJ32: Missing data sources (checked 596)
# ❌ 2017XZ2: Missing data sources (checked 597)
# ❌ 2005ND63: Missing data sources (checked 598)
# ❌ 2016TS54: Missing data sources (checked 599)
# ❌ 2020BM9: Missing data sources (checked 600)
# ❌ 2015VP64: Missing data sources (checked 601)
# ❌ 2023RM15: Missing data sources (checked 602)
# ❌ 2022PZ16: Missing data sources (checked 603)
# ❌ 2022DM4: Missing data sources (checked 604)
# ❌ 2016EL1: Missing data sources (checked 605)
# ❌ 2020TE5: Missing data sources (checked 606)
# ❌ 2023UG3: Missing data sources (checked 607)
# ❌ 2019WL3: Missing data sources (checked 608)
# ❌ 2022UX20: Missing data sources (checked 609)
# ❌ 2020KW5: Missing data sources (checked 610)
# ❌ 2019XS1: Missing data sources (checked 611)
# ✅ 423/4000: 2014UR34 (checked 612)
# ❌ 2024RF3: Missing data sources (checked 613)
# ❌ 2022CK4: Missing data sources (checked 614)
# ❌ 2019CB5: Missing data sources (checked 615)
# ❌ 2023CL1: Missing data sources (checked 616)
# ❌ 2008TN9: Missing data sources (checked 617)
# ❌ 2022UH11: Missing data sources (checked 618)
# ❌ 2021OT1: Missing data sources (checked 619)
# ❌ 2023SF7: Missing data sources (checked 620)
# ❌ 2024UW2: Missing data sources (checked 621)
# ❌ 2022US24: Missing data sources (checked 622)
# ❌ 2017UW5: Missing data sources (checked 623)
# ❌ 2021WV5: Missing data sources (checked 624)
# ❌ 2019AE9: Missing data sources (checked 625)
# ❌ 2011YD29: Missing data sources (checked 626)
# ❌ 2024XT8: Missing data sources (checked 627)
# ❌ 2021SP2: Missing data sources (checked 628)
# ❌ 2015XT378: Missing data sources (checked 629)
# ❌ 2008YC33: Missing data sources (checked 630)
# ✅ 424/4000: 2023QS2 (checked 631)
# ✅ 425/4000: 2014HE5 (checked 632)
# ❌ 2015KH321: Missing data sources (checked 633)
# ❌ 2022JL2: Missing data sources (checked 634)
# ❌ 2020AA2: Missing data sources (checked 635)
# ❌ 2024FQ1: Missing data sources (checked 636)
# ❌ 2021XJ4: Missing data sources (checked 637)
# ❌ 2009WB54: Missing data sources (checked 638)
# ❌ 2024PD4: Missing data sources (checked 639)
# ❌ 2025DD7: Missing data sources (checked 640)
# ❌ 2016CK31: Missing data sources (checked 641)
# ❌ 2021VP3: Missing data sources (checked 642)
# ❌ 2025HX4: Missing data sources (checked 643)
# ❌ 2022UF9: Missing data sources (checked 644)
# ❌ 2022WN9: Missing data sources (checked 645)
# ❌ 2023VD2: Missing data sources (checked 646)
# ❌ 2023VH9: Missing data sources (checked 647)
# ❌ 2023QM56: Missing data sources (checked 648)
# ❌ 2021TN9: Missing data sources (checked 649)
# ❌ 2023XX1: Missing data sources (checked 650)
# ❌ 2021PS3: Missing data sources (checked 651)
# ❌ 2025AH4: Missing data sources (checked 652)
# ❌ 2012BP123: Missing data sources (checked 653)
# ❌ 2008TE1: Missing data sources (checked 654)
# ❌ 2004SR26: Missing data sources (checked 655)
# ✅ 426/4000: 2014HH199 (checked 656)
# ❌ 2016NJ56: Missing data sources (checked 657)
# ❌ 2018SP2: Missing data sources (checked 658)
# ❌ 1993KA2: Missing data sources (checked 659)
# ❌ 2017GA8: Missing data sources (checked 660)
# ❌ 2005JB46: Missing data sources (checked 661)
# ❌ 2024BA16: Missing data sources (checked 662)
# ❌ 2021UF6: Missing data sources (checked 663)
# ❌ 2007UO6: Missing data sources (checked 664)
# ❌ 2010KV7: Missing data sources (checked 665)
# ❌ 2017BR32: Missing data sources (checked 666)
# ❌ 2015KH160: Missing data sources (checked 667)
# ❌ 2012DM32: Missing data sources (checked 668)
# ❌ 2017SL10: Missing data sources (checked 669)
# ❌ 2011FT9: Missing data sources (checked 670)
# ❌ 2017WC13: Missing data sources (checked 671)
# ❌ 2022BL1: Missing data sources (checked 672)
# ❌ 2009UK1: Missing data sources (checked 673)
# ❌ 2022YC6: Missing data sources (checked 674)
# ❌ 2020BK13: Missing data sources (checked 675)
# ❌ 2012UY136: Missing data sources (checked 676)
# ❌ 2012VD5: Missing data sources (checked 677)
# ❌ 2022QJ41: Missing data sources (checked 678)
# ❌ 2015MA131: Missing data sources (checked 679)
# ❌ 2012SX49: Missing data sources (checked 680)
# ❌ 2024AG4: Missing data sources (checked 681)
# ❌ 2017FV101: Missing data sources (checked 682)
# ❌ 2024RS3: Missing data sources (checked 683)
# ❌ 2025CR1: Missing data sources (checked 684)
# ✅ 427/4000: 2021RV2 (checked 685)
# ❌ 2023GJ2: Missing data sources (checked 686)
# ❌ 2022LM2: Missing data sources (checked 687)
# ❌ 2022SG11: Missing data sources (checked 688)
# ❌ 2019UT2: Missing data sources (checked 689)
# ✅ 428/4000: 2021GQ5 (checked 690)
# ❌ 2021QY4: Missing data sources (checked 691)
# ❌ 2016JA29: Missing data sources (checked 692)
# ❌ 2022GQ1: Missing data sources (checked 693)
# ❌ 2019UW13: Missing data sources (checked 694)
# ✅ 429/4000: 2016JL38 (checked 695)
# ❌ 2010TN55: Missing data sources (checked 696)
# ❌ 2021WY2: Missing data sources (checked 697)
# ✅ 430/4000: 2020YM2 (checked 698)
# ❌ 2007VJ189: Missing data sources (checked 699)
# ❌ 2017FM1: Missing data sources (checked 700)
# ❌ 2021VB2: Missing data sources (checked 701)
# ❌ 2017SD20: Missing data sources (checked 702)
# ❌ 2023UK4: Missing data sources (checked 703)
# ❌ 2025CC2: Missing data sources (checked 704)
# ❌ 2020GN1: Missing data sources (checked 705)
# ❌ 2016CU246: Missing data sources (checked 706)
# ❌ 2024XV4: Missing data sources (checked 707)
# ❌ 2017SO12: Missing data sources (checked 708)
# ❌ 2017AS4: Missing data sources (checked 709)
# ❌ 2023WY1: Missing data sources (checked 710)
# ❌ 2015HQ9: Missing data sources (checked 711)
# ❌ 2021PW210: Missing data sources (checked 712)
# ❌ 2014UK115: Missing data sources (checked 713)
# ❌ 2021BM2: Missing data sources (checked 714)
# ❌ 2019BR3: Missing data sources (checked 715)
# ❌ 2019SD1: Missing data sources (checked 716)
# ❌ 2024VX1: Missing data sources (checked 717)
# ❌ 2022UA4: Missing data sources (checked 718)
# ❌ 2012PY19: Missing data sources (checked 719)
# ❌ 2012CQ46: Missing data sources (checked 720)
# ❌ 2017YN1: Missing data sources (checked 721)
# ❌ 2018TH3: Missing data sources (checked 722)
# ❌ 2023TM27: Missing data sources (checked 723)
# ❌ 2014HK196: Missing data sources (checked 724)
# ❌ 2023GX2: Missing data sources (checked 725)
# ❌ 2008LC2: Missing data sources (checked 726)
# ❌ 2022UX27: Missing data sources (checked 727)
# ❌ 2022EP6: Missing data sources (checked 728)
# ❌ 2011YK6: Missing data sources (checked 729)
# ❌ 2023XD15: Missing data sources (checked 730)
# ❌ 2014GM35: Missing data sources (checked 731)
# ❌ 2012BC14: Missing data sources (checked 732)
# ❌ 2019SR6: Missing data sources (checked 733)
# ❌ 2009WS52: Missing data sources (checked 734)
# ❌ 2016TL17: Missing data sources (checked 735)
# ❌ 2020RE5: Missing data sources (checked 736)
# ❌ 2024UU7: Missing data sources (checked 737)
# ❌ 2021CG10: Missing data sources (checked 738)
# ❌ 2025HO1: Missing data sources (checked 739)
# ❌ 2020UD4: Missing data sources (checked 740)
# ❌ 2014WH368: Missing data sources (checked 741)
# ❌ 2012TQ146: Missing data sources (checked 742)
# ❌ 2024WG12: Missing data sources (checked 743)
# ❌ 2019AU11: Missing data sources (checked 744)
# ❌ 2021GR2: Missing data sources (checked 745)
# ❌ 2022AR2: Missing data sources (checked 746)
# ❌ 2022UT1: Missing data sources (checked 747)
# ❌ 2023SF4: Missing data sources (checked 748)
# ❌ 2024WJ12: Missing data sources (checked 749)
# ❌ 2025FH25: Missing data sources (checked 750)
# ❌ 2020FP5: Missing data sources (checked 751)
# ❌ 2016PW8: Missing data sources (checked 752)
# ❌ 2023OU3: Missing data sources (checked 753)
# ❌ 2022QW33: Missing data sources (checked 754)
# ❌ 2014MH6: Missing data sources (checked 755)
# ❌ 2015HO116: Missing data sources (checked 756)
# ❌ 2022YM6: Missing data sources (checked 757)
# ❌ 2017SQ17: Missing data sources (checked 758)
# ❌ 2021WR6: Missing data sources (checked 759)
# ❌ 2019VN2: Missing data sources (checked 760)
# ❌ 2019TE1: Missing data sources (checked 761)
# ❌ 2019JY2: Missing data sources (checked 762)
# ❌ 2021WB5: Missing data sources (checked 763)
# ❌ 2011GR36: Missing data sources (checked 764)
# ❌ 2024YB1: Missing data sources (checked 765)
# ❌ 2015HC182: Missing data sources (checked 766)
# ❌ 1993FA1: Missing data sources (checked 767)
# ❌ 2024QA2: Missing data sources (checked 768)
# ❌ 2024XF6: Missing data sources (checked 769)
# ❌ 2025HZ2: Missing data sources (checked 770)
# ❌ 2024SF3: Missing data sources (checked 771)
# ❌ 2021PL132: Missing data sources (checked 772)
# ❌ 2024WG11: Missing data sources (checked 773)
# ❌ 2021TN8: Missing data sources (checked 774)
# ❌ 2019UM2: Missing data sources (checked 775)
# ✅ 431/4000: 2014OO392 (checked 776)
# ❌ 2010VM139: Missing data sources (checked 777)
# ❌ 2014HT198: Missing data sources (checked 778)
# ❌ 2016SW1: Missing data sources (checked 779)
# ❌ 2021XZ2: Missing data sources (checked 780)
# ❌ 2024TD2: Missing data sources (checked 781)
# ❌ 2018DQ3: Missing data sources (checked 782)
# ❌ 2018QH1: Missing data sources (checked 783)
# ❌ 2020FF3: Missing data sources (checked 784)
# ❌ 2021TT6: Missing data sources (checked 785)
# ❌ 2007FS3: Missing data sources (checked 786)
# ❌ 2015KB158: Missing data sources (checked 787)
# ❌ 2021TQ8: Missing data sources (checked 788)
# ❌ 2011AB37: Missing data sources (checked 789)
# ❌ 2024FD1: Missing data sources (checked 790)
# ❌ 2021VV2: Missing data sources (checked 791)
# ❌ 2020KF6: Missing data sources (checked 792)
# ❌ 2014JR79: Missing data sources (checked 793)
# ❌ 2007TG71: Missing data sources (checked 794)
# ❌ 2016TZ55: Missing data sources (checked 795)
# ❌ 2023FU6: Missing data sources (checked 796)
# ❌ 2023XC1: Missing data sources (checked 797)
# ❌ 2011AY22: Missing data sources (checked 798)
# ❌ 2017UF3: Missing data sources (checked 799)
# ❌ 2023FS11: Missing data sources (checked 800)
# ❌ 2009DJ46: Missing data sources (checked 801)
# ❌ 2025KG13: Missing data sources (checked 802)
# ❌ 2021FS1: Missing data sources (checked 803)
# ❌ 2020FD5: Missing data sources (checked 804)
# ❌ 2020OA5: Missing data sources (checked 805)
# ❌ 2017UH6: Missing data sources (checked 806)
# ❌ 2013PS13: Missing data sources (checked 807)
# ❌ 2023TR1: Missing data sources (checked 808)
# ❌ 2021AQ6: Missing data sources (checked 809)
# ❌ 2024UK4: Missing data sources (checked 810)
# ❌ 2009TM8: Missing data sources (checked 811)
# ❌ 2017UJ2: Missing data sources (checked 812)
# ❌ 2022BD1: Missing data sources (checked 813)
# ❌ 2021VL19: Missing data sources (checked 814)
# ❌ 2023WF2: Missing data sources (checked 815)
# ❌ 2021KO2: Missing data sources (checked 816)
# ❌ 2018XD4: Missing data sources (checked 817)
# ❌ 2022DV2: Missing data sources (checked 818)
# ❌ 2018FD2: Missing data sources (checked 819)
# ❌ 2022FL2: Missing data sources (checked 820)
# ❌ 2017WW1: Missing data sources (checked 821)
# ❌ 2024XS16: Missing data sources (checked 822)
# ❌ 2022QW5: Missing data sources (checked 823)
# ❌ 2008DF5: Missing data sources (checked 824)
# ❌ 2024UB11: Missing data sources (checked 825)
# ❌ 2007VV7: Missing data sources (checked 826)
# ❌ 2023SU2: Missing data sources (checked 827)
# ❌ 2022SZ11: Missing data sources (checked 828)
# ❌ 2017WK16: Missing data sources (checked 829)
# ❌ 2024WV4: Missing data sources (checked 830)
# ❌ 2024TZ7: Missing data sources (checked 831)
# ❌ 2020FC2: Missing data sources (checked 832)
# ❌ 2022TM1: Missing data sources (checked 833)
# ❌ 2007YH1: Missing data sources (checked 834)
# ❌ 2019VN4: Missing data sources (checked 835)
# ❌ 2023VY2: Missing data sources (checked 836)
# ❌ 2019XE2: Missing data sources (checked 837)
# ❌ 2025MQ1: Missing data sources (checked 838)
# ❌ 2024OZ1: Missing data sources (checked 839)
# ❌ 2019JN3: Missing data sources (checked 840)
# ❌ 2019TV5: Missing data sources (checked 841)
# ❌ 2025MU90: Missing data sources (checked 842)
# ❌ 2017QA3: Missing data sources (checked 843)
# ❌ 2005EM70: Missing data sources (checked 844)
# ❌ 2010KO10: Missing data sources (checked 845)
# ❌ 2022SU4: Missing data sources (checked 846)
# ❌ 2024TW11: Missing data sources (checked 847)
# ❌ 2016FJ60: Missing data sources (checked 848)
# ❌ 2022EH1: Missing data sources (checked 849)
# ❌ 2012TJ53: Missing data sources (checked 850)
# ❌ 2005UH5: Missing data sources (checked 851)
# ❌ 2023RN16: Missing data sources (checked 852)
# ❌ 2015HE1: Missing data sources (checked 853)
# ❌ 2019SH9: Missing data sources (checked 854)
# ❌ 2024XU1: Missing data sources (checked 855)
# ❌ 2020DU1: Missing data sources (checked 856)
# ❌ 2019VM2: Missing data sources (checked 857)
# ❌ 2023XJ1: Missing data sources (checked 858)
# ❌ 2018UL1: Missing data sources (checked 859)
# ❌ 2015AN44: Missing data sources (checked 860)
# ❌ 2007VA138: Missing data sources (checked 861)
# ❌ 2020SN3: Missing data sources (checked 862)
# ❌ 2014YD15: Missing data sources (checked 863)
# ❌ 2014SE145: Missing data sources (checked 864)
# ❌ 2025DY3: Missing data sources (checked 865)
# ❌ 2005VN5: Missing data sources (checked 866)
# ❌ 2022AT5: Missing data sources (checked 867)
# ❌ 2009OY7: Missing data sources (checked 868)
# ❌ 2011TJ5: Missing data sources (checked 869)
# ❌ 2024NW1: Missing data sources (checked 870)
# ❌ 2015HZ181: Missing data sources (checked 871)
# ❌ 2020PV4: Missing data sources (checked 872)
# ❌ 2021CT10: Missing data sources (checked 873)
# ❌ 2021AD5: Missing data sources (checked 874)
# ❌ 2025FP2: Missing data sources (checked 875)
# ❌ 2014JS25: Missing data sources (checked 876)
# ❌ 2024XK9: Missing data sources (checked 877)
# ❌ 2023KQ2: Missing data sources (checked 878)
# ❌ 2022SA5: Missing data sources (checked 879)
# ❌ 2010DY1: Missing data sources (checked 880)
# ❌ 2024TW8: Missing data sources (checked 881)
# ❌ 2023FF7: Missing data sources (checked 882)
# ❌ 2013DS9: Missing data sources (checked 883)
# ✅ 432/4000: 2022EL4 (checked 884)
# ❌ 2017FJ3: Missing data sources (checked 885)
# ❌ 2024BK1: Missing data sources (checked 886)
# ❌ 2006BF99: Missing data sources (checked 887)
# ❌ 2016LT1: Missing data sources (checked 888)
# ❌ 2017AQ4: Missing data sources (checked 889)
# ❌ 2019SE8: Missing data sources (checked 890)
# ❌ 2025FJ2: Missing data sources (checked 891)
# ❌ 2015HC183: Missing data sources (checked 892)
# ❌ 2016VJ3: Missing data sources (checked 893)
# ❌ 2020JR2: Missing data sources (checked 894)
# ❌ 2017TD1: Missing data sources (checked 895)
# ❌ 2014NQ64: Missing data sources (checked 896)
# ❌ 2014WT367: Missing data sources (checked 897)
# ❌ 2023YR1: Missing data sources (checked 898)
# ❌ 2025BB1: Missing data sources (checked 899)
# ❌ 2009WK1: Missing data sources (checked 900)
# ❌ 2020TL3: Missing data sources (checked 901)
# ❌ 2024CE3: Missing data sources (checked 902)
# ❌ 2021WJ6: Missing data sources (checked 903)
# ❌ 2011FF41: Missing data sources (checked 904)
# ❌ 2004JO20: Missing data sources (checked 905)
# ❌ 2020VU3: Missing data sources (checked 906)
# ❌ 2024UU5: Missing data sources (checked 907)
# ❌ 2017SC12: Missing data sources (checked 908)
# ❌ 2020DJ2: Missing data sources (checked 909)
# ❌ 2014HB197: Missing data sources (checked 910)
# ❌ 2019RD2: Missing data sources (checked 911)
# ❌ 2016JJ38: Missing data sources (checked 912)
# ❌ 2017UN43: Missing data sources (checked 913)
# ❌ 2009EX43: Missing data sources (checked 914)
# ❌ 2024XC16: Missing data sources (checked 915)
# ❌ 2009RX4: Missing data sources (checked 916)
# ❌ 2019KX6: Missing data sources (checked 917)
# ❌ 2020FF4: Missing data sources (checked 918)
# ❌ 2020PL7: Missing data sources (checked 919)
# ❌ 2016FP60: Missing data sources (checked 920)
# ❌ 2022CW1: Missing data sources (checked 921)
# ❌ 2014WX497: Missing data sources (checked 922)
# ❌ 2016TG94: Missing data sources (checked 923)
# ❌ 2020SB5: Missing data sources (checked 924)
# ❌ 2015FM118: Missing data sources (checked 925)
# ❌ 2020UD6: Missing data sources (checked 926)
# ❌ 2020BP8: Missing data sources (checked 927)
# ❌ 2025CJ1: Missing data sources (checked 928)
# ❌ 2022AO2: Missing data sources (checked 929)
# ❌ 2013RZ53: Missing data sources (checked 930)
# ✅ 433/4000: 2019QQ6 (checked 931)
# ❌ 2018PM20: Missing data sources (checked 932)
# ❌ 2016FV12: Missing data sources (checked 933)
# ❌ 2022YS1: Missing data sources (checked 934)
# ❌ 2018DL1: Missing data sources (checked 935)
# ❌ 2016QA2: Missing data sources (checked 936)
# ❌ 2025FE18: Missing data sources (checked 937)
# ❌ 2024WQ2: Missing data sources (checked 938)
# ❌ 2022WD1: Missing data sources (checked 939)
# ❌ 2019RO1: Missing data sources (checked 940)
# ❌ 2020FC1: Missing data sources (checked 941)
# ❌ 2021TG1: Missing data sources (checked 942)
# ❌ 2020BB1: Missing data sources (checked 943)
# ❌ 2016VD18: Missing data sources (checked 944)
# ❌ 2006WQ127: Missing data sources (checked 945)
# ❌ 2006SO198: Missing data sources (checked 946)
# ❌ 2019SZ8: Missing data sources (checked 947)
# ❌ 2012EN5: Missing data sources (checked 948)
# ❌ 2014WJ6: Missing data sources (checked 949)
# ❌ 2022UL11: Missing data sources (checked 950)
# ❌ 2025AH1: Missing data sources (checked 951)
# ❌ 2021BO1: Missing data sources (checked 952)
# ❌ 2020YD5: Missing data sources (checked 953)
# ❌ 2004MO1: Missing data sources (checked 954)
# ❌ 2021CZ3: Missing data sources (checked 955)
# ❌ 2024RH7: Missing data sources (checked 956)
# ❌ 2021RY7: Missing data sources (checked 957)
# ❌ 2014EO12: Missing data sources (checked 958)
# ❌ 2020XE1: Missing data sources (checked 959)
# ❌ 2018AG3: Missing data sources (checked 960)
# ❌ 2004FY15: Missing data sources (checked 961)
# ❌ 2024RR16: Missing data sources (checked 962)
# ❌ 2023XQ12: Missing data sources (checked 963)
# ❌ 2022UG28: Missing data sources (checked 964)
# ❌ 2009FP32: Missing data sources (checked 965)
# ❌ 2024XE11: Missing data sources (checked 966)
# ❌ 2018BG11: Missing data sources (checked 967)
# ❌ 2021PA17: Missing data sources (checked 968)
# ❌ 2018CA3: Missing data sources (checked 969)
# ❌ 2023VE3: Missing data sources (checked 970)
# ❌ 2019FS1: Missing data sources (checked 971)
# ❌ 2024BD2: Missing data sources (checked 972)
# ❌ 2021CZ5: Missing data sources (checked 973)
# ❌ 2025MS88: Missing data sources (checked 974)
# ❌ 2014WO365: Missing data sources (checked 975)
# ❌ 2024TW5: Missing data sources (checked 976)
# ❌ 2011CV4: Missing data sources (checked 977)
# ✅ 434/4000: 2017YY4 (checked 978)
# ❌ 2017WN15: Missing data sources (checked 979)
# ❌ 2025AA4: Missing data sources (checked 980)
# ❌ 2024TP1: Missing data sources (checked 981)
# ❌ 2020AO2: Missing data sources (checked 982)
# ❌ 2022QT36: Missing data sources (checked 983)
# ❌ 2019KY6: Missing data sources (checked 984)
# ❌ 2020BL15: Missing data sources (checked 985)
# ❌ 2005VN1: Missing data sources (checked 986)
# ❌ 2006SO77: Missing data sources (checked 987)
# ❌ 2023BH5: Missing data sources (checked 988)
# ❌ 2021JQ2: Missing data sources (checked 989)
# ❌ 2016UP36: Missing data sources (checked 990)
# ❌ 2020OQ6: Missing data sources (checked 991)
# ❌ 2021CW7: Missing data sources (checked 992)
# ❌ 2024BV2: Missing data sources (checked 993)
# ❌ 2022MD3: Missing data sources (checked 994)
# ❌ 2023UJ9: Missing data sources (checked 995)
# ❌ 2024UU11: Missing data sources (checked 996)
# ❌ 2007HY15: Missing data sources (checked 997)
# ❌ 2008UB92: Missing data sources (checked 998)
# ❌ 2021UV5: Missing data sources (checked 999)
# ❌ 2023BH6: Missing data sources (checked 1000)
# ❌ 2013SR19: Missing data sources (checked 1001)
# ❌ 2025KW8: Missing data sources (checked 1002)
# ❌ 2022UJ3: Missing data sources (checked 1003)
# ❌ 2025AX2: Missing data sources (checked 1004)
# ❌ 2019WZ1: Missing data sources (checked 1005)
# ❌ 2017YF8: Missing data sources (checked 1006)
# ❌ 2021VH1: Missing data sources (checked 1007)
# ❌ 2015HU182: Missing data sources (checked 1008)
# ❌ 2018PY23: Missing data sources (checked 1009)
# ❌ 2021RD239: Missing data sources (checked 1010)
# ❌ 2019BS2: Missing data sources (checked 1011)
# ❌ 2023CG4: Missing data sources (checked 1012)
# ❌ 2019GP21: Missing data sources (checked 1013)
# ❌ 2013BQ27: Missing data sources (checked 1014)
# ❌ 2017YL14: Missing data sources (checked 1015)
# ❌ 2020FZ1: Missing data sources (checked 1016)
# ❌ 2013NB15: Missing data sources (checked 1017)
# ❌ 2024SB8: Missing data sources (checked 1018)
# ❌ 2021VS22: Missing data sources (checked 1019)
# ❌ 2015KX157: Missing data sources (checked 1020)
# ❌ 2014HL199: Missing data sources (checked 1021)
# ❌ 1994TE2: Missing data sources (checked 1022)
# ❌ 2025CO2: Missing data sources (checked 1023)
# ❌ 2019JR5: Missing data sources (checked 1024)
# ❌ 2023SA4: Missing data sources (checked 1025)
# ❌ 2017UU2: Missing data sources (checked 1026)
# ✅ 435/4000: 2023UJ6 (checked 1027)
# ✅ 436/4000: 2017TD5 (checked 1028)
# ✅ 437/4000: 2003SM215 (checked 1029)
# ✅ 438/4000: 2024SJ1 (checked 1030)
# ✅ 439/4000: 2014CA13 (checked 1031)
# ❌ 2005XK4: Missing data sources (checked 1151)
# ✅ 511/4000: 2017UC6 (checked 1152)
# ✅ 512/4000: 2021FF2 (checked 1153)
# ❌ 2017FQ146: Missing data sources (checked 1154)
# ✅ 513/4000: 2023VO6 (checked 1155)
# ✅ 514/4000: 2025FB8 (checked 1156)
# ✅ 515/4000: 2005TM173 (checked 1157)
# ...
# ❌ 2020DC4: Missing data sources (checked 4595)
# ❌ 2019YC2: Missing data sources (checked 4596)
# ❌ 2014SO260: Missing data sources (checked 4597)
# ✅ 2360/4000: 2012XB112 (checked 4598)
# ✅ 2361/4000: 2025FC8 (checked 4599)
# ❌ 2022QM7: Missing data sources (checked 4600)
# ❌ 2022SA8: Missing data sources (checked 4601)
# ❌ 2023VJ9: Missing data sources (checked 4602)
# ❌ 2023JS4: Missing data sources (checked 4603)
# ✅ 2362/4000: 2023LE2 (checked 4604)
# ❌ 2024RM16: Missing data sources (checked 4605)
# ✅ 2363/4000: 2024QV1 (checked 4606)
# ✅ 2364/4000: 2022QQ31 (checked 4607)
# ✅ 2365/4000: 2021UR7 (checked 4608)
# ✅ 2366/4000: 2024FR3 (checked 4609)
# ✅ 2367/4000: 2020RY2 (checked 4610)
# ✅ 2368/4000: 2020PA4 (checked 4611)
# 🎯 Validation complete: Found 2368 NEOs with complete data (checked 4611 total)
# ✅ Validated 2368 NEOs.
#
# ⚙️ Processing 2368 validated NEOs in parallel...
# Processing NEOs:   0%|          | 0/2368 [00:00<?, ?it/s]
# Skipping night 3 for 2017PK25 due to non-physical fit estimations
# Skipping night 1 (2021-10-05) due to insufficient observations: 1
# Skipping night 1 for 2014WR7 due to non-physical fit estimations
# REJECTED: Missing data for 2024CT6
# REJECTED: Missing data for 2023KU4
# REJECTED: Missing data for 2005TC51
# REJECTED: Missing data for 2024AB3
# Skipping night 3 for 2023HF4 due to non-physical fit estimations
# Skipping night 3 for 2019BG3 due to non-physical fit estimations
# REJECTED: Missing data for 2011EY11
# REJECTED: Missing data for 2015KE319
# Skipping night 1 (2010-02-18) due to insufficient observations: 1
# Skipping night 3 (2010-02-20) due to insufficient observations: 1
# Skipping night 2 for 2016VZ1 due to non-physical fit estimations
# Skipping night 2 for 2006OK3 due to non-physical fit estimations
# REJECTED: Missing data for 2005NQ1
# REJECTED: Missing data for 2024SV2
# REJECTED: Missing data for 2013VP4
# REJECTED: Missing data for 2015BT516
# REJECTED: Missing data for 2020OH3
# REJECTED: Missing data for 2017QN35
# Skipping night 1 for 2020BZ13 due to non-physical fit estimations
# REJECTED: No valid nights with enough observations for 2020BZ13
# REJECTED: Missing data for 2012TE53
# REJECTED: Missing data for 2021GV6
# REJECTED: Missing data for 2005TQ45
# Skipping night 1 for 2019XL3 due to non-physical fit estimations
# Skipping night 3 for 2016VB1 due to non-physical fit estimations
# REJECTED: Missing data for 2022DA3
# REJECTED: Missing data for 2021FJ2
# Skipping night 1 for 2024TS2 due to non-physical fit estimations
# Skipping night 2 for 2011SM173 due to non-physical fit estimations
# REJECTED: Missing data for 2023TM3
# Skipping night 2 for 2016LE10 due to non-physical fit estimations
# Skipping night 1 (2020-01-23) due to insufficient observations: 1
# Skipping night 3 (2019-11-07) due to insufficient observations: 1
# Skipping night 4 (2019-11-08) due to insufficient observations: 1
# Skipping night 3 (2016-08-10) due to insufficient observations: 1
# Skipping night 3 for 2016TP2 due to non-physical fit estimations
# Skipping night 3 (2022-04-11) due to insufficient observations: 1
# Skipping night 1 for 2015SV6 due to non-physical fit estimations
# REJECTED: Missing data for 2021RE2
# Skipping night 1 for 2020FB7 due to non-physical fit estimations
# Skipping night 3 (2018-02-12) due to insufficient observations: 1
# Skipping night 4 (2010-06-05) due to insufficient observations: 1
# Skipping night 1 for 2020SA2 due to non-physical fit estimations
# REJECTED: Missing data for 2012HE2
# Skipping night 2 for 2022WQ3 due to non-physical fit estimations
# REJECTED: Missing data for 2018HD1
# REJECTED: Missing data for 2021UJ4
# Skipping night 1 for 2018VD7 due to non-physical fit estimations
# Skipping night 2 for 2009WJ6 due to non-physical fit estimations
# Skipping night 3 for 2023VD4 due to non-physical fit estimations
# Skipping night 4 for 2022EU6 due to non-physical fit estimations
# Skipping night 4 (2019-04-15) due to insufficient observations: 1
# Skipping night 2 (2021-08-09) due to insufficient observations: 1
# Skipping night 1 for 2023VK9 due to non-physical fit estimations
# Skipping night 3 (2023-11-17) due to insufficient observations: 1
# Skipping night 1 (2025-02-20) due to insufficient observations: 1
# Skipping night 3 for 2017DG16 due to non-physical fit estimations
# Skipping night 1 for 2021GA168 due to non-physical fit estimations
# REJECTED: No valid nights with enough observations for 2021GA168
# Skipping night 1 (2020-02-13) due to insufficient observations: 1
# Skipping night 4 for 2015YQ1 due to non-physical fit estimations
# Skipping night 3 for 2024WF5 due to non-physical fit estimations
# Skipping night 2 for 2016CM194 due to non-physical fit estimations
# Skipping night 2 for 2021TR3 due to non-physical fit estimations
# Skipping night 3 for 2017FY101 due to non-physical fit estimations
# Skipping night 1 for 2024OG2 due to non-physical fit estimations
# Skipping night 3 for 2021GC8 due to non-physical fit estimations
# Skipping night 1 for 2020YJ2 due to non-physical fit estimations
# REJECTED: Missing data for 2023GG3
# Skipping night 4 for 2012XB112 due to non-physical fit estimations
#
# 💾 Creating final DataFrame and saving to CSV...
#
# 📊 PROCESSING SUMMARY:
#    🎯 Target NEOs: 4000
#    ✅ Successfully processed: 2297
#    ❌ Rejected: 71
#    📊 Total data rows: 6178
#    🎯 Success rate: 97.0%
#
# 📋 Final dataset structure:
#    Basic fields: 7
#    Keplerian elements: 6 (a_kep, e, i, Omega, omega, M)
#    Equinoctial elements: 6 (a_equ, h, k, p, q, lambda)
#    Total columns: 19
#    Note: Separate semi-major axes: a_kep (Keplerian) and a_equ (Equinoctial)
#
# 🎉 SUCCESS! Pipeline complete.
# Dataset saved to: ./DataSet_NEO_VSA.csv
# 📋 Columns: ['object', 'night', 't_fit', 'alpha', 'delta', 'alpha_dot', 'delta_dot', 'a_kep', 'e', 'i', 'Omega', 'omega', 'M', 'a_equ', 'h', 'k', 'p', 'q', 'lambda']
