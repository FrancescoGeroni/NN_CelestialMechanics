# %% [markdown]
# # NEO Data Fetching and Processing Pipeline
#
# This notebook contains a production-ready pipeline to fetch, parse, and process data for Near-Earth Objects (NEOs) from the [NeoDyS-2](https://newton.spacedys.com/neodys/) service.
#
# The pipeline is organized into three main sections:
# 1.  **Configuration & Imports:** Sets the number of objects to process (`N_OBJECTS`) and imports all necessary libraries.
# 2.  **Helper Functions:** Contains all the functions for fetching, parsing, and processing the data.
# 3.  **Execution Pipeline:** Runs the main logic to fetch the object list, verify data, process the objects, and export the final dataset.
#
# The final output is a single CSV file named `DataSet_NEO_VSA.csv` containing the processed data for the specified number of objects.

# %%
# --- Imports ---
import requests
import time
import pandas as pd
import numpy as np
import re
import random
from datetime import datetime
from io import StringIO
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import urllib.parse
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
import traceback
from astropy.time import Time
import re
from numpy.polynomial.polyutils import RankWarning
import warnings
warnings.filterwarnings("ignore", category=RankWarning)

# %%
def parse_rwo(rwo_content):
    """Parse RWO content from NeoDyS-2 format using dynamic field detection for robustness."""
    nights_data = {}
    if not rwo_content: 
        return nights_data

    lines = rwo_content.split('\n')
    for idx, line in enumerate(lines):
        # Skip header and empty lines
        if (line.startswith('!') or not line.strip() or 
            line.startswith('version') or line.startswith('errmod') or 
            line.startswith('RMS') or line.startswith('END_OF_HEADER')):
            continue
        parts = line.split()
        # Find year (4-digit number), month (1-2 digit), day_frac (float)
        year_idx, month_idx, day_frac_idx = None, None, None
        for i, val in enumerate(parts):
            if year_idx is None and re.match(r'^\d{4}$', val):
                year_idx = i
                # Try to get month and day_frac right after year
                if i+2 < len(parts):
                    month_idx = i+1
                    day_frac_idx = i+2
                break
        if year_idx is None or month_idx is None or day_frac_idx is None:
            continue
        year_val = parts[year_idx]
        month_val = parts[month_idx]
        day_frac_val = parts[day_frac_idx]
        # Check if year and month are integers and day_frac is float
        try:
            year = int(year_val) if year_val is not None and year_val.isdigit() else None
            month = int(month_val) if month_val is not None and month_val.isdigit() else None
            day_frac = float(day_frac_val) if day_frac_val is not None else None
        except Exception as e:
            print(f"DEBUG: Line {idx+1} invalid date fields: year={year_val}, month={month_val}, day_frac={day_frac_val} | {e}")
            continue
        if year is None or month is None or day_frac is None:
            print(f"DEBUG: Line {idx+1} missing or invalid date fields: year={year_val}, month={month_val}, day_frac={day_frac_val}")
            continue

        # Dynamically find RA and Dec indices: RA is 3 consecutive fields after day_frac (hours, min, sec), Dec is 3 consecutive fields after RA (deg, min, sec)
        ra_start = day_frac_idx + 2
        dec_start = None
        # Find RA indices (should be float/int values)
        if ra_start + 2 < len(parts):
            ra_h_idx, ra_m_idx, ra_s_idx = ra_start, ra_start+1, ra_start+2
        else:
            continue
        # Find Dec indices: look for first value after RA that matches degree pattern (+/-dd or dd)
        for j in range(ra_s_idx+1, len(parts)-2):
            if re.match(r'^[+-]?\d+$', parts[j]):
                dec_start = j
                break
        if dec_start is not None and dec_start+2 < len(parts):
            dec_d_idx, dec_m_idx, dec_s_idx = dec_start, dec_start+1, dec_start+2
        else:
            continue

        try:
            day_int = int(day_frac)
            frac = day_frac - day_int
            total_seconds = frac * 24 * 3600
            hours = int(total_seconds // 3600)
            minutes = int((total_seconds % 3600) // 60)
            seconds = int(total_seconds % 60)

            ra_h = float(parts[ra_h_idx]) if parts[ra_h_idx] is not None else 0.0
            ra_m = float(parts[ra_m_idx]) if parts[ra_m_idx] is not None else 0.0
            ra_s = float(parts[ra_s_idx]) if parts[ra_s_idx] is not None else 0.0
            alpha = np.deg2rad(15.0 * (ra_h + ra_m / 60.0 + ra_s / 3600.0))

            dec_d = float(parts[dec_d_idx]) if parts[dec_d_idx] is not None else 0.0
            dec_m = float(parts[dec_m_idx]) if parts[dec_m_idx] is not None else 0.0
            dec_s = float(parts[dec_s_idx]) if parts[dec_s_idx] is not None else 0.0
            dec_sign = -1 if str(parts[dec_d_idx]).startswith('-') else 1
            delta_deg = dec_sign * (abs(dec_d) + dec_m / 60.0 + dec_s / 3600.0)
            delta = np.deg2rad(delta_deg)

            iso_str = f"{year:04d}-{month:02d}-{day_int:02d}T{hours:02d}:{minutes:02d}:{seconds:02d}"
            epoch = Time(iso_str, format='isot', scale='utc').mjd
            night_date = f"{year}-{month:02d}-{day_int:02d}"
            if night_date not in nights_data:
                nights_data[night_date] = []
            nights_data[night_date].append({
                'mjd': epoch,
                'alpha': alpha,
                'delta': delta
            })

        except (ValueError, IndexError, KeyError) as e:
            print(f"DEBUG: Line {idx+1} parse error: {repr(line)} | {e}")
            continue

    return nights_data

def fetch_kep_elements(object_name):
    """Fetches and parses real Keplerian elements using table row order and symbol labels."""
    encoded_name = urllib.parse.quote(object_name)
    url = f"https://newton.spacedys.com/neodys/index.php?pc=1.1.1&n={encoded_name}"
    html_content = get_content(url)
    if not html_content:
        return {}
    try:
        soup = BeautifulSoup(html_content, 'html.parser')
        tables = soup.find_all('table')
        for table in tables:
            if "keplerian" in table.get_text(strip=True).lower():
                rows = table.find_all('tr')
                values = []
                for row in rows:
                    cells = row.find_all(['td', 'th'])
                    if len(cells) >= 2:
                        val = cells[1].get_text(strip=True)
                        numeric_match = re.search(r'([-+]?\d*\.?\d+)', val)
                        if numeric_match:
                            values.append(float(numeric_match.group(1)))
                if len(values) >= 6:
                    # Assign by order: a, e, i, Omega (symbol), omega (symbol), M
                    elements = {
                        'a_kep': values[0],
                        'e': values[1],
                        'i': values[2],
                        'Omega': values[3],
                        'omega': values[4],
                        'M': values[5]
                    }
                    return elements
    except Exception as e:
        pass
    return {}

def process_object(neo_name):
    """
    Fetches, parses, and processes all data for a single NEO object and validates
	that the files contain usable data (e.g., RWO has valid nights, elements are present).
    This function is designed to be executed in a concurrent manner.

    Args:
        neo_name (str): The name of the NEO object to process.

    Returns:
        tuple: A tuple containing:
            - list: A list of dictionaries, each representing a processed observation night.
            - str: The name of the object, for tracking.
            - str: The status of the processing ('processed' or 'rejected').
    """
    # Step 1: Fetch all required data for the object
    rwo_result = fetch_rwo(neo_name)
    kep_elements = fetch_kep_elements(neo_name)
    eq0_elements = fetch_equ0_elements(neo_name)

    # Step 2: Validate that ALL required data was fetched successfully
    # Require RWO data AND Keplerian elements AND EQU elements
    if not rwo_result or not rwo_result.get('content') or not kep_elements or not eq0_elements:
        print(f"REJECTED: Missing data for {neo_name}")
        return [], neo_name, 'rejected'

    # Step 3: Parse the RWO data to get observation nights
    nights_data = parse_rwo(rwo_result['content'])
    if not nights_data:
        print(f"REJECTED: No valid nights for {neo_name}")
        return [], neo_name, 'rejected'

    # Step 4: Process each valid night of observation to create data rows
    object_rows = []
    sorted_nights = sorted(nights_data.items())
    for night_index, (night_date, obs_list) in enumerate(sorted_nights, 1):
        alpha_dot, delta_dot = 0.0, 0.0
        a_fit, d_fit = None, None
        if len(obs_list) < 2:
            print(f"Skipping night {night_index} ({night_date}) due to insufficient observations: {len(obs_list)}")
            continue

        obs_list.sort(key=lambda o: o.get('mjd', 0))
        mid_obs = obs_list[len(obs_list) // 2]
        t_fit = mid_obs.get('mjd', 0.0)

        # Calculate alpha_dot and delta_dot using np.polyfit (same as loader)
        if len(obs_list) >= 3:
            t = np.array([obs['mjd'] for obs in obs_list])
            alpha = np.array([obs['alpha'] for obs in obs_list])
            delta = np.array([obs['delta'] for obs in obs_list])

            with warnings.catch_warnings(record=True) as w:
                warnings.simplefilter('always', RankWarning)
                try:
                    a_fit = np.polyfit(t, alpha, 2)
                    d_fit = np.polyfit(t, delta, 2)
                    rankwarn = any(isinstance(warn.message, RankWarning) for warn in w)
                    if rankwarn:
                        a_fit = np.polyfit(t, alpha, 1)
                        d_fit = np.polyfit(t, delta, 1)
                        alpha_dot = a_fit[0]
                        delta_dot = d_fit[0]
                    else:
                        alpha_dot = 2 * a_fit[0] * t_fit + a_fit[1]
                        delta_dot = 2 * d_fit[0] * t_fit + d_fit[1]
                except Exception as fit_err:
                    print(f"Fit error in night {night_index}: {fit_err}")
                    a_fit, d_fit = None, None
                    alpha_dot, delta_dot = 0.0, 0.0
        elif len(obs_list) == 2:
            t = np.array([obs['mjd'] for obs in obs_list])
            alpha = np.array([obs['alpha'] for obs in obs_list])
            delta = np.array([obs['delta'] for obs in obs_list])
            try:
                a_fit = np.polyfit(t, alpha, 1)
                d_fit = np.polyfit(t, delta, 1)
                alpha_dot = a_fit[0]
                delta_dot = d_fit[0]
            except Exception as fit_err:
                print(f"Linear fit error in night {night_index}: {fit_err}")
                a_fit, d_fit = None, None
                alpha_dot, delta_dot = 0.0, 0.0

        row = {
            'object': neo_name, 'night': night_index, 't_fit': t_fit,
            'alpha': mid_obs.get('alpha', 0.0), 'delta': mid_obs.get('delta', 0.0),
            'alpha_dot': alpha_dot, 'delta_dot': delta_dot, 
            **kep_elements, **eq0_elements
        }
        object_rows.append(row)

    if not object_rows:
        print(f"REJECTED: No valid nights with enough observations for {neo_name}")
        return [], neo_name, 'rejected'

    return object_rows, neo_name, 'processed'

# %%
def get_content(url, timeout=30, max_retries=3):
    """
    Fetches content from a URL with improved error handling and retries.
    Updated with robust session configuration to avoid HTTP 403 errors.
    """
    session = requests.Session()
    
    # Configure retry strategy
    retry_strategy = Retry(
        total=max_retries,
        backoff_factor=2,
        status_forcelist=[403, 429, 500, 502, 503, 504],
        allowed_methods=["HEAD", "GET", "OPTIONS"]
    )
    
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    
    # Enhanced headers to mimic real browser behavior (fixes 403 errors)
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'none',
        'Sec-Fetch-User': '?1',
        'Cache-Control': 'max-age=0',
        'DNT': '1',
        'Sec-CH-UA': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
        'Sec-CH-UA-Mobile': '?0',
        'Sec-CH-UA-Platform': '"Linux"'
    })
    
    try:
        response = session.get(url, timeout=timeout)  # Removed verify=False
        response.raise_for_status()
        return response.text
    except requests.exceptions.Timeout:
        return None
    except requests.exceptions.ConnectionError:
        return None
    except requests.exceptions.HTTPError as e:
        if e.response.status_code != 404:
            print(f"🔥 HTTP error {e.response.status_code} fetching {url}")
        return None
    except Exception:
        return None
    finally:
        session.close()

def is_valid_neo_name(name):
    """Validate NEO object names to filter out invalid entries."""
    if not name or len(name) < 4:
        return False
    
    # Clean the name
    name = name.strip()
    
    # More precise patterns for NEO names
    patterns = [
        r'^\d{4}\s+[A-Z]{1,3}\d*$',     # e.g., "2023 BU", "1991 VG"
        r'^\d{4}[A-Z]{1,3}\d*$',        # e.g., "2015RN35", "2019EA2" (no space)
        r'^\(\d+\)\s*[A-Za-z\s]*$',     # e.g., "(433) Eros", "(1) Ceres"
        r'^[A-Z]{2,}\d+$',              # e.g., "AA29", "BD", etc.
    ]
    
    # Check if it matches any valid pattern
    if not any(re.match(pattern, name) for pattern in patterns):
        return False
    
    # Additional filters to exclude obviously invalid names
    invalid_keywords = [
        'object', 'name', 'http', 'www', 'com', 'neodys', 'spacedys',
        'index', 'php', 'table', 'cell', 'row', 'column', 'data',
        'the', 'and', 'or', 'but', 'for', 'with', 'without'
    ]
    
    name_lower = name.lower()
    if any(keyword in name_lower for keyword in invalid_keywords):
        return False
    
    # Must contain at least one digit and one letter
    has_digit = any(c.isdigit() for c in name)
    has_letter = any(c.isalpha() for c in name)
    
    return has_digit and has_letter

def get_all_prefixes(page_url):
    """Fetch the list of all NEO objects from the main NeoDyS-2 page."""
    url = page_url
    html_content = get_content(url)
    
    if html_content:
        soup = BeautifulSoup(html_content, 'html.parser')
        neo_objects = []
        
        # Strategy 1: Look for links containing object names
        for link in soup.find_all('a', href=True):
            if 'pc=1.1.1&n=' in link.get('href', ''):
                # Extract the object name from the URL parameter
                href = link.get('href', '')
                if '&n=' in href:
                    name = href.split('&n=')[1].split('&')[0]  # Get name from URL
                    name = name.replace('%20', ' ')  # Decode URL encoding
                    if is_valid_neo_name(name):
                        neo_objects.append(name)
        
        # Strategy 2: Look for text patterns that match NEO names
        page_text = soup.get_text()
        # Find year-letter-number patterns (e.g., 2015 RN35, 2019EA2)
        neo_patterns = [
            r'\b(\d{4}\s+[A-Z]{1,3}\d+)\b',  # 2015 RN35
            r'\b(\d{4}[A-Z]{1,3}\d+)\b',     # 2015RN35
            r'\b(\(\d+\)\s*[A-Za-z\s]*)\b'   # (433) Eros
        ]
        
        for pattern in neo_patterns:
            matches = re.findall(pattern, page_text)
            for match in matches:
                name = match.strip()
                if is_valid_neo_name(name):
                    neo_objects.append(name)
        
        if neo_objects:
            unique_neos = list(set(neo_objects))
            print(f"Successfully extracted {len(unique_neos)} NEOs from the website.")
            return unique_neos  # Return all extracted NEOs, not limited
    
    # Fallback: try a different page or approach
    print("Primary extraction failed. Trying alternative approach...")
    
    # Try the main NEA list page
    alt_url = "https://newton.spacedys.com/neodys/index.php?pc=1.1.0"
    html_content = get_content(alt_url)
    
    if html_content:
        soup = BeautifulSoup(html_content, 'html.parser')
        neo_objects = []
        
        # Look for any NEO-like patterns in the text
        page_text = soup.get_text()
        neo_patterns = [
            r'\b(\d{4}\s+[A-Z]{1,3}\d+)\b',
            r'\b(\d{4}[A-Z]{1,3}\d+)\b'
        ]
        
        for pattern in neo_patterns:
            matches = re.findall(pattern, page_text)
            for match in matches:
                name = match.strip()
                if is_valid_neo_name(name):
                    neo_objects.append(name)
        
        if neo_objects:
            unique_neos = list(set(neo_objects))
            print(f"Alternative extraction found {len(unique_neos)} NEOs.")
            return unique_neos  # Return all found NEOs, not limited
    
    print("❌ Could not extract NEO names from website. Please check the NeoDyS-2 site structure.")
    return []

def fetch_rwo(object_name):
    """Fetch RWO file content from NeoDyS-2."""
    # URL encode the object name to handle spaces and special characters
    encoded_name = urllib.parse.quote(object_name.replace(" ", "%20"))
    url = f"https://newton.spacedys.com/~neodys2/mpcobs/{encoded_name}.rwo"
    content = get_content(url)
    if content and not content.lower().startswith('<html>'):
        return {'content': content}
    else:
        return None
'''
def fetch_kep_elements(object_name):
    """Fetches and parses real Keplerian elements with improved parsing logic."""
    encoded_name = urllib.parse.quote(object_name)
    url = f"https://newton.spacedys.com/neodys/index.php?pc=1.1.1&n={encoded_name}"
    html_content = get_content(url)
    if not html_content: 
        return {}
    try:
        soup = BeautifulSoup(html_content, 'html.parser')
        tables = soup.find_all('table')
        
        for table in tables:
            if "keplerian" in table.get_text(strip=True).lower():
                rows = table.find_all('tr')
                elements = {}
                
                for row in rows:
                    cells = row.find_all(['td', 'th'])
                    if len(cells) >= 2:
                        key = cells[0].get_text(strip=True).lower()
                        val = cells[1].get_text(strip=True)
                        
                        # Extract numeric value, ignoring timestamps and units
                        try:
                            # Try to extract just the numeric part
                            numeric_match = re.search(r'([-+]?\d*\.?\d+)', val)
                            if numeric_match:
                                numeric_val = float(numeric_match.group(1))
                                
                                # COMPLETE 6-element matching patterns
                                if ('a' in key and ('semi' in key or 'major' in key)) or key.strip() == 'a':
                                    elements['a_kep'] = numeric_val
                                elif ('e' in key and 'ecc' in key) or key.strip() == 'e':
                                    elements['e'] = numeric_val
                                elif ('i' in key and ('incl' in key or 'inclination' in key)) or key.strip() == 'i':
                                    elements['i'] = numeric_val
                                elif ('mean' in key and 'anom' in key) or ('m' in key and 'anom' in key) or key.strip() == 'm':
                                    elements['M'] = numeric_val
                                # ENHANCED omega patterns for argument of perihelion
                                elif (('omega' in key and 'peri' in key) or 
                                      ('w' in key and 'peri' in key) or 
                                      ('argument' in key and 'peri' in key) or 
                                      key.strip() in ['w', 'omega_peri', 'arg_peri', 'peri']):
                                    elements['omega'] = numeric_val
                                # Omega for longitude of ascending node
                                elif ('node' in key or 
                                      ('omega' in key and ('asc' in key or 'cap' in key)) or 
                                      ('longitude' in key and 'asc' in key) or
                                      key.strip() in ['omega', 'cap_omega', 'long_node']):
                                    elements['Omega'] = numeric_val
                        except (ValueError, AttributeError):
                            continue
                            
                # Ensure we have complete 6-element set with fallbacks
                if len(elements) >= 5:  # Allow 5+ elements, fill missing ones
                    # Fill missing elements with defaults if needed
                    standard_elements = ['a_kep', 'e', 'i', 'Omega', 'omega', 'M']
                    for elem in standard_elements:
                        if elem not in elements:
                            elements[elem] = 0.0  # Safe default for missing elements
                    return elements
    except Exception as e: 
        pass
    return {}
'''
def fetch_equ0_elements(object_name):
    """Fetch EQU elements from .eq0 file.
    Returns exactly 6 equinoctial elements: a_equ, h, k, p, q, lambda
    """
    encoded_name = urllib.parse.quote(object_name.replace(" ", "%20"))
    url = f"https://newton.spacedys.com/~neodys2/epoch/{encoded_name}.eq0"
    response_text = get_content(url)
    if not response_text: 
        return {}
    try:
        for line in response_text.strip().split('\n'):
            if line.strip().startswith('EQU'):
                parts = line.split()
                # Extract exactly 6 equinoctial elements: a_equ, h, k, p, q, lambda
                if len(parts) >= 8:  # Has a, h, k, p, q, lambda, plus extra data
                    result = {
                        'a_equ': float(parts[1]),      # Semi-major axis (equinoctial)
                        'h': float(parts[2]),          # h = e * sin(omega + Omega)
                        'k': float(parts[3]),          # k = e * cos(omega + Omega)
                        'p': float(parts[4]),          # p = tan(i/2) * sin(Omega)
                        'q': float(parts[5]),          # q = tan(i/2) * cos(Omega)
                        'lambda': float(parts[6])      # lambda = M + omega + Omega
                    }
                    return result
                elif len(parts) >= 7:  # Missing one element, fill with default
                    result = {
                        'a_equ': float(parts[1]) if len(parts) > 1 else 1.0,
                        'h': float(parts[2]) if len(parts) > 2 else 0.0,
                        'k': float(parts[3]) if len(parts) > 3 else 0.0,
                        'p': float(parts[4]) if len(parts) > 4 else 0.0,
                        'q': float(parts[5]) if len(parts) > 5 else 0.0,
                        'lambda': float(parts[6]) if len(parts) > 6 else 0.0
                    }
                    return result
    except (ValueError, IndexError) as e: 
        pass
    return {}

def create_dataset(neo_list):
    """
    Processes a list of NEO names concurrently to fetch their data, including RWO, 
    Keplerian elements, and corrected equinoctial elements.

    Args:
        neo_list (list): A list of NEO names to process.

    Returns:
        tuple: A tuple containing:
            - list: A list of dictionaries, where each dictionary represents a row in the final dataset.
            - int: The number of objects that were rejected due to missing data.
    """
    all_rows = []
    rejected_count = 0
    
    # Use ThreadPoolExecutor to process objects in parallel
    with ThreadPoolExecutor(max_workers=20) as executor:
        # Create a future for each NEO object processing task
        future_to_neo = {executor.submit(process_object, neo_name): neo_name for neo_name in neo_list}
        
        # Use tqdm to create a progress bar for the concurrent tasks
        pbar = tqdm(as_completed(future_to_neo), total=len(neo_list), desc="Processing NEOs")
        
        for future in pbar:
            try:
                # Get the result from the completed future
                object_rows, neo_name, status = future.result()
                
                if status == 'processed' and object_rows:
                    all_rows.extend(object_rows)
                else:
                    rejected_count += 1
            except Exception as e:
                # Handle exceptions that might occur within the thread
                neo_name = future_to_neo[future]
                rejected_count += 1

    return all_rows, rejected_count

def check_data_availability(neo_name):
    """
    Lightweight check to verify only if all three data sources (RWO, Keplerian, EQU) are available,
    but not their quality. Uses HEAD requests or minimal content fetching for efficiency.
    Updated with robust session to avoid HTTP 403 errors.
    
    Args:
        neo_name (str): The NEO name to check
        
    Returns:
        bool: True if all three data sources are available, False otherwise
    """
	    
    # Prepare URLs for all three data sources
    encoded_name = urllib.parse.quote(neo_name.replace(" ", "%20"))
    
    urls_to_check = {
        'rwo': f"https://newton.spacedys.com/~neodys2/mpcobs/{encoded_name}.rwo",
        'equ': f"https://newton.spacedys.com/~neodys2/epoch/{encoded_name}.eq0",
        'kep': f"https://newton.spacedys.com/neodys/index.php?pc=1.1.1&n={urllib.parse.quote(neo_name)}"
    }
    
    session = requests.Session()
    # Use the same robust headers that fixed the 403 errors
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'none',
        'Sec-Fetch-User': '?1',
        'Cache-Control': 'max-age=0'
    })
    
    available_sources = 0
    
    try:
        # Check RWO file availability (HEAD request is faster)
        try:
            response = session.head(urls_to_check['rwo'], timeout=5)  # Removed verify=False
            if response.status_code == 200:
                available_sources += 1
        except:
            pass
            
        # Check EQU file availability (HEAD request is faster)
        try:
            response = session.head(urls_to_check['equ'], timeout=5)  # Removed verify=False
            if response.status_code == 200:
                available_sources += 1
        except:
            pass
            
        # Check Keplerian elements page (need to GET to check content)
        try:
            response = session.get(urls_to_check['kep'], timeout=5)  # Removed verify=False
            if response.status_code == 200 and 'keplerian' in response.text.lower():
                available_sources += 1
        except:
            pass
            
    except Exception:
        pass
    finally:
        session.close()
    
    # Return True only if all 3 sources are available
    return available_sources >= 3

def validate_object(all_neo_names, target_count, use_random_sampling=True, random_seed=None):
    """
    Validates NEO names and checks data availability to ensure exactly target_count 
    valid NEOs with complete data are selected.
    
    Args:
        all_neo_names (list): List of all NEO names from the website
        target_count (int): Number of validated NEOs needed
        use_random_sampling (bool): Whether to randomly sample or take first N objects
        random_seed (int): Random seed for reproducible results (None for true randomness)
        
    Returns:
        list: List of exactly target_count NEO names with complete data available
    """
    sampling_method = "random sampling" if use_random_sampling else "sequential selection"
    print(f"🔍 Validating NEOs with data availability check (target: {target_count}, method: {sampling_method})...")
    
    # Step 1: Filter for valid NEO names first
    valid_names = [name for name in all_neo_names if is_valid_neo_name(name)]
    print(f"📋 Found {len(valid_names)} NEOs with valid name patterns")
    
    # Step 2: Apply sampling strategy
    if use_random_sampling:
        # Set random seed for reproducibility if provided
        if random_seed is not None:
            random.seed(random_seed)
            print(f"🎲 Using random seed {random_seed} for reproducible sampling")
        
        # Randomly shuffle the valid names for diverse sampling
        random.shuffle(valid_names)
        print(f"🎲 Randomly shuffled NEO list for diverse sampling")
        
        # Check more NEOs than needed to account for failures (random sampling)
        check_limit = min(len(valid_names), target_count * 5)
    else:
        # Sequential selection - take first N objects
        print(f"📝 Using sequential selection (first {target_count} valid NEOs)")
        check_limit = min(len(valid_names), target_count * 3)  # Smaller buffer for sequential
    
    validated_neos = []
    checked_count = 0
    
    # Step 3: Use ThreadPoolExecutor for concurrent validation
    with ThreadPoolExecutor(max_workers=10) as executor:
        # Create futures for validation tasks
        future_to_name = {}
        
        for name in valid_names[:check_limit]:
            future = executor.submit(check_data_availability, name)
            future_to_name[future] = name
        
        print(f"🚀 Started validation of {len(future_to_name)} NEOs using {sampling_method}...")
        
        # Process completed validation tasks
        for future in as_completed(future_to_name):
            name = future_to_name[future]
            checked_count += 1
            
            try:
                has_complete_data = future.result()
                if has_complete_data:
                    validated_neos.append(name)
                    print(f"✅ {len(validated_neos)}/{target_count}: {name} (checked {checked_count})")
                    
                    # Stop when we have enough validated NEOs
                    if len(validated_neos) >= target_count:
                        # Cancel remaining futures to save resources
                        for remaining_future in future_to_name:
                            if not remaining_future.done():
                                remaining_future.cancel()
                        break
                else:
                    print(f"❌ {name}: Missing data sources (checked {checked_count})")
                    
            except Exception as e:
                print(f"⚠️ {name}: Validation error - {str(e)[:50]}...")
                
    print(f"🎯 Validation complete: Found {len(validated_neos)} NEOs with complete data (checked {checked_count} total)")
    return validated_neos
# Out:
# <>:177: SyntaxWarning: invalid escape sequence '\d'
# <>:177: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_463654/3762527708.py:177: SyntaxWarning: invalid escape sequence '\d'
#   '''

# %%
# FINAL PIPELINE RUN

# --- Configuration ---
N_OBJECTS = 4000 # Number of objects to process
RANDOM_SAMPLING = True # Use random sampling instead of first N_OBJECTS
RANDOM_SEED = 42 # Random seed for reproducible results (set to None for true randomness)

# t0 = 60800.0 #[MJD] Initial time for the database, according to NeoDys-2 website

# NeoDys-2 query url f
page_url = "https://newton.spacedys.com/neodys/index.php?pc=3.2.1&pc0=3.2&lra=&ura=&lde=&ude=&lvm=&uvm=&lel=&uel=&lph=&uph=&lgl=&ugl=&ldfe=&udfe=&ldfs=&udfs=&lmo=&umo=&lspu=&uspu=&ldu=&udu=&lal=1&ual=3"

# 1. Get all NEO names from the website
print("🛰️ Fetching all NEO names from NeoDyS-2...")
all_neo_names = get_all_prefixes(page_url)
print(f"🌍 Found {len(all_neo_names)} total NEOs.")

# 2. Validate NEOs to get a list of N_OBJECTS with all required data
print(f"\n🔍 Validating NEOs to find {N_OBJECTS} objects with complete data...")
validated_neo_names = validate_object(
    all_neo_names, 
    N_OBJECTS, 
    use_random_sampling=RANDOM_SAMPLING,
    random_seed=RANDOM_SEED
)
print(f"✅ Validated {len(validated_neo_names)} NEOs.")

# 3. Process the validated NEOs using the corrected pipeline
print(f"\n⚙️ Processing {len(validated_neo_names)} validated NEOs in parallel...")
final_dataset_rows, rejected_count = create_dataset(validated_neo_names)

# 4. Create the final DataFrame and save to CSV
print(f"\n💾 Creating final DataFrame and saving to CSV...")
if final_dataset_rows:
    final_df = pd.DataFrame(final_dataset_rows)
    
    # Report results
    successful_count = len(validated_neo_names) - rejected_count
    print(f"\n📊 PROCESSING SUMMARY:")
    print(f"   🎯 Target NEOs: {N_OBJECTS}")
    print(f"   ✅ Successfully processed: {successful_count}")
    print(f"   ❌ Rejected: {rejected_count}")
    print(f"   📊 Total data rows: {len(final_df)}")
    print(f"   🎯 Success rate: {(successful_count/len(validated_neo_names)*100):.1f}%")
    
    # Ensure consistent column order (basic + 6 Keplerian + 6 Equinoctial)
    # Check which equinoctial columns are available
    available_cols = final_df.columns.tolist()
    
    # Define exact column sets as per specification:
    # Keplerian: a_kep, e, i, Omega, omega, M
    # Equinoctial: a_equ, h, k, p, q, lambda
    basic_cols = ['object', 'night', 't_fit', 'alpha', 'delta', 'alpha_dot', 'delta_dot']
    keplerian_cols = ['a_kep', 'e', 'i', 'Omega', 'omega', 'M']
    equinoctial_cols = ['a_equ', 'h', 'k', 'p', 'q', 'lambda']
    
    # Create final column order (now with separate a_kep and a_equ)
    # Format: basic + 6 Keplerian + 6 Equinoctial (no shared columns)
    final_column_order = basic_cols + ['a_kep', 'e', 'i', 'Omega', 'omega', 'M', 'a_equ', 'h', 'k', 'p', 'q', 'lambda']
    
    # Ensure all required columns exist, add missing with default values
    missing_cols = [col for col in final_column_order if col not in available_cols]
    if missing_cols:
        print(f"⚠️  Adding missing columns with default values: {missing_cols}")
        for col in missing_cols:
            final_df[col] = 0.0
    
    final_df = final_df[final_column_order]
    
    print(f"\n📋 Final dataset structure:")
    print(f"   Basic fields: {len(basic_cols)}")
    print(f"   Keplerian elements: 6 (a_kep, e, i, Omega, omega, M)")
    print(f"   Equinoctial elements: 6 (a_equ, h, k, p, q, lambda)")
    print(f"   Total columns: {len(final_column_order)}")
    print(f"   Note: Separate semi-major axes: a_kep (Keplerian) and a_equ (Equinoctial)")
    
    # Save to CSV
    output_path = "/home/FGeroni/Università/PhD/Code/NN_CelestialMechanics/PINN_DiffCorrections/DataSet_NEO_VSA.csv"
    final_df.to_csv(output_path, index=False)
    
    print(f"\n🎉 SUCCESS! Pipeline complete.")
    print(f"Dataset saved to: {output_path}")
    print(f"📋 Columns: {final_column_order}")
else:
    print("❌ No data was processed. The final dataset is empty.")
# Out:
# 🛰️ Fetching all NEO names from NeoDyS-2...
# Successfully extracted 4611 NEOs from the website.
# 🌍 Found 4611 total NEOs.
#
# 🔍 Validating NEOs to find 4000 objects with complete data...
# 🔍 Validating NEOs with data availability check (target: 4000, method: random sampling)...
# 📋 Found 4611 NEOs with valid name patterns
# 🎲 Using random seed 42 for reproducible sampling
# 🎲 Randomly shuffled NEO list for diverse sampling
# 🚀 Started validation of 4611 NEOs using random sampling...
# Successfully extracted 4611 NEOs from the website.
# 🌍 Found 4611 total NEOs.
#
# 🔍 Validating NEOs to find 4000 objects with complete data...
# 🔍 Validating NEOs with data availability check (target: 4000, method: random sampling)...
# 📋 Found 4611 NEOs with valid name patterns
# 🎲 Using random seed 42 for reproducible sampling
# 🎲 Randomly shuffled NEO list for diverse sampling
# 🚀 Started validation of 4611 NEOs using random sampling...
# ✅ 1/4000: 2020KK6 (checked 1)
# ✅ 2/4000: 2009HF21 (checked 2)
# ✅ 3/4000: 2010RH31 (checked 3)
# ✅ 4/4000: 2021TR1 (checked 4)
# ✅ 5/4000: 2023TE10 (checked 5)
# ✅ 6/4000: 2017DV36 (checked 6)
# ✅ 7/4000: 2021RJ5 (checked 7)
# ✅ 8/4000: 2024UM1 (checked 8)
# ✅ 9/4000: 2024UR7 (checked 9)
# ✅ 10/4000: 2017WQ15 (checked 10)
# ✅ 1/4000: 2020KK6 (checked 1)
# ✅ 2/4000: 2009HF21 (checked 2)
# ✅ 3/4000: 2010RH31 (checked 3)
# ✅ 4/4000: 2021TR1 (checked 4)
# ✅ 5/4000: 2023TE10 (checked 5)
# ✅ 6/4000: 2017DV36 (checked 6)
# ✅ 7/4000: 2021RJ5 (checked 7)
# ✅ 8/4000: 2024UM1 (checked 8)
# ✅ 9/4000: 2024UR7 (checked 9)
# ✅ 10/4000: 2017WQ15 (checked 10)
# ✅ 11/4000: 2019UU8 (checked 11)
# ✅ 12/4000: 2015TO350 (checked 12)
# ✅ 13/4000: 2023BR8 (checked 13)
# ✅ 11/4000: 2019UU8 (checked 11)
# ✅ 12/4000: 2015TO350 (checked 12)
# ✅ 13/4000: 2023BR8 (checked 13)
# ❌ 2015KC57: Missing data sources (checked 14)
# ✅ 14/4000: 2009SY63 (checked 15)
# ✅ 15/4000: 2022QW1 (checked 16)
# ✅ 16/4000: 2024XZ15 (checked 17)
# ✅ 17/4000: 2023VF3 (checked 18)
# ✅ 18/4000: 2024AM3 (checked 19)
# ✅ 19/4000: 2024RO14 (checked 20)
# ✅ 20/4000: 2023UN3 (checked 21)
# ❌ 2015KC57: Missing data sources (checked 14)
# ✅ 14/4000: 2009SY63 (checked 15)
# ✅ 15/4000: 2022QW1 (checked 16)
# ✅ 16/4000: 2024XZ15 (checked 17)
# ✅ 17/4000: 2023VF3 (checked 18)
# ✅ 18/4000: 2024AM3 (checked 19)
# ✅ 19/4000: 2024RO14 (checked 20)
# ✅ 20/4000: 2023UN3 (checked 21)
# ✅ 21/4000: 2019JW7 (checked 22)
# ✅ 22/4000: 2024XO16 (checked 23)
# ✅ 21/4000: 2019JW7 (checked 22)
# ✅ 22/4000: 2024XO16 (checked 23)
# ✅ 23/4000: 2011KG20 (checked 24)
# ✅ 24/4000: 2024XM1 (checked 25)
# ✅ 25/4000: 2021RD16 (checked 26)
# ✅ 26/4000: 2023TD4 (checked 27)
# ✅ 27/4000: 2019QX1 (checked 28)
# ✅ 28/4000: 2021RA6 (checked 29)
# ✅ 29/4000: 2022UO13 (checked 30)
# ✅ 30/4000: 2017UG1 (checked 31)
# ❌ 2019VF3: Missing data sources (checked 32)
# ❌ 2014HJ196: Missing data sources (checked 33)
# ❌ 2019QR3: Missing data sources (checked 34)
# ✅ 23/4000: 2011KG20 (checked 24)
# ✅ 24/4000: 2024XM1 (checked 25)
# ✅ 25/4000: 2021RD16 (checked 26)
# ✅ 26/4000: 2023TD4 (checked 27)
# ✅ 27/4000: 2019QX1 (checked 28)
# ✅ 28/4000: 2021RA6 (checked 29)
# ✅ 29/4000: 2022UO13 (checked 30)
# ✅ 30/4000: 2017UG1 (checked 31)
# ❌ 2019VF3: Missing data sources (checked 32)
# ❌ 2014HJ196: Missing data sources (checked 33)
# ❌ 2019QR3: Missing data sources (checked 34)
# ✅ 31/4000: 2017TS4 (checked 35)
# ✅ 32/4000: 2016AR8 (checked 36)
# ✅ 31/4000: 2017TS4 (checked 35)
# ✅ 32/4000: 2016AR8 (checked 36)
# ✅ 33/4000: 2007FN3 (checked 37)
# ✅ 34/4000: 2017UT1 (checked 38)
# ✅ 35/4000: 2019VE5 (checked 39)
# ✅ 36/4000: 2023DS1 (checked 40)
# ✅ 37/4000: 2017SH20 (checked 41)
# ✅ 38/4000: 2024PV3 (checked 42)
# ❌ 2024CD1: Missing data sources (checked 43)
# ✅ 39/4000: 2019AC9 (checked 44)
# ✅ 40/4000: 2021AO7 (checked 45)
# ✅ 33/4000: 2007FN3 (checked 37)
# ✅ 34/4000: 2017UT1 (checked 38)
# ✅ 35/4000: 2019VE5 (checked 39)
# ✅ 36/4000: 2023DS1 (checked 40)
# ✅ 37/4000: 2017SH20 (checked 41)
# ✅ 38/4000: 2024PV3 (checked 42)
# ❌ 2024CD1: Missing data sources (checked 43)
# ✅ 39/4000: 2019AC9 (checked 44)
# ✅ 40/4000: 2021AO7 (checked 45)
# ✅ 41/4000: 2018PN20 (checked 46)
# ✅ 42/4000: 2019JH6 (checked 47)
# ✅ 41/4000: 2018PN20 (checked 46)
# ✅ 42/4000: 2019JH6 (checked 47)
# ✅ 43/4000: 2016FQ60 (checked 48)
# ✅ 44/4000: 2019LH1 (checked 49)
# ✅ 45/4000: 2021VB2 (checked 50)
# ✅ 46/4000: 2011VT5 (checked 51)
# ✅ 47/4000: 2019AS3 (checked 52)
# ❌ 2012KC45: Missing data sources (checked 53)
# ✅ 48/4000: 2017PW26 (checked 54)
# ✅ 49/4000: 2017GA8 (checked 55)
# ✅ 50/4000: 2007VZ2 (checked 56)
# ✅ 43/4000: 2016FQ60 (checked 48)
# ✅ 44/4000: 2019LH1 (checked 49)
# ✅ 45/4000: 2021VB2 (checked 50)
# ✅ 46/4000: 2011VT5 (checked 51)
# ✅ 47/4000: 2019AS3 (checked 52)
# ❌ 2012KC45: Missing data sources (checked 53)
# ✅ 48/4000: 2017PW26 (checked 54)
# ✅ 49/4000: 2017GA8 (checked 55)
# ✅ 50/4000: 2007VZ2 (checked 56)
# ✅ 51/4000: 2018TG3 (checked 57)
# ✅ 52/4000: 2023UO2 (checked 58)
# ✅ 51/4000: 2018TG3 (checked 57)
# ✅ 52/4000: 2023UO2 (checked 58)
# ✅ 53/4000: 2017RU17 (checked 59)
# ✅ 54/4000: 2023KV3 (checked 60)
# ✅ 55/4000: 2014YW14 (checked 61)
# ✅ 56/4000: 2018VD7 (checked 62)
# ❌ 2021EA2: Missing data sources (checked 63)
# ✅ 57/4000: 2024HQ2 (checked 64)
# ✅ 58/4000: 2022SG18 (checked 65)
# ✅ 59/4000: 2024UM6 (checked 66)
# ✅ 60/4000: 2022UP6 (checked 67)
# ✅ 53/4000: 2017RU17 (checked 59)
# ✅ 54/4000: 2023KV3 (checked 60)
# ✅ 55/4000: 2014YW14 (checked 61)
# ✅ 56/4000: 2018VD7 (checked 62)
# ❌ 2021EA2: Missing data sources (checked 63)
# ✅ 57/4000: 2024HQ2 (checked 64)
# ✅ 58/4000: 2022SG18 (checked 65)
# ✅ 59/4000: 2024UM6 (checked 66)
# ✅ 60/4000: 2022UP6 (checked 67)
# ❌ 2025FY11: Missing data sources (checked 68)
# ✅ 61/4000: 2022WP9 (checked 69)
# ✅ 62/4000: 2024SC1 (checked 70)
# ❌ 2025FY11: Missing data sources (checked 68)
# ✅ 61/4000: 2022WP9 (checked 69)
# ✅ 62/4000: 2024SC1 (checked 70)
# ✅ 63/4000: 2024PF6 (checked 71)
# ✅ 64/4000: 2023XT1 (checked 72)
# ✅ 65/4000: 2021UE6 (checked 73)
# ✅ 66/4000: 2024SS2 (checked 74)
# ✅ 67/4000: 2019XF2 (checked 75)
# ✅ 68/4000: 2008GK20 (checked 76)
# ✅ 69/4000: 2019AV14 (checked 77)
# ✅ 63/4000: 2024PF6 (checked 71)
# ✅ 64/4000: 2023XT1 (checked 72)
# ✅ 65/4000: 2021UE6 (checked 73)
# ✅ 66/4000: 2024SS2 (checked 74)
# ✅ 67/4000: 2019XF2 (checked 75)
# ✅ 68/4000: 2008GK20 (checked 76)
# ✅ 69/4000: 2019AV14 (checked 77)
# ✅ 70/4000: 2024UQ3 (checked 78)
# ✅ 71/4000: 2004BP160 (checked 79)
# ✅ 72/4000: 2024YA9 (checked 80)
# ✅ 70/4000: 2024UQ3 (checked 78)
# ✅ 71/4000: 2004BP160 (checked 79)
# ✅ 72/4000: 2024YA9 (checked 80)
# ✅ 73/4000: 2022EF3 (checked 81)
# ✅ 74/4000: 2021KS1 (checked 82)
# ✅ 75/4000: 2021CO2 (checked 83)
# ✅ 76/4000: 2022SS55 (checked 84)
# ✅ 77/4000: 2012UT18 (checked 85)
# ✅ 78/4000: 2022WT4 (checked 86)
# ✅ 79/4000: 2023TN2 (checked 87)
# ✅ 73/4000: 2022EF3 (checked 81)
# ✅ 74/4000: 2021KS1 (checked 82)
# ✅ 75/4000: 2021CO2 (checked 83)
# ✅ 76/4000: 2022SS55 (checked 84)
# ✅ 77/4000: 2012UT18 (checked 85)
# ✅ 78/4000: 2022WT4 (checked 86)
# ✅ 79/4000: 2023TN2 (checked 87)
# ✅ 80/4000: 2022WE2 (checked 88)
# ✅ 81/4000: 2019DA2 (checked 89)
# ✅ 82/4000: 2019SB2 (checked 90)
# ✅ 80/4000: 2022WE2 (checked 88)
# ✅ 81/4000: 2019DA2 (checked 89)
# ✅ 82/4000: 2019SB2 (checked 90)
# ✅ 83/4000: 2022SX55 (checked 91)
# ✅ 84/4000: 2008GF1 (checked 92)
# ✅ 85/4000: 2011WU74 (checked 93)
# ✅ 86/4000: 2020FC1 (checked 94)
# ✅ 87/4000: 2024VG3 (checked 95)
# ✅ 88/4000: 2020HO5 (checked 96)
# ✅ 89/4000: 2019QD4 (checked 97)
# ✅ 83/4000: 2022SX55 (checked 91)
# ✅ 84/4000: 2008GF1 (checked 92)
# ✅ 85/4000: 2011WU74 (checked 93)
# ✅ 86/4000: 2020FC1 (checked 94)
# ✅ 87/4000: 2024VG3 (checked 95)
# ✅ 88/4000: 2020HO5 (checked 96)
# ✅ 89/4000: 2019QD4 (checked 97)
# ✅ 90/4000: 2021PY4 (checked 98)
# ✅ 91/4000: 2017SD20 (checked 99)
# ✅ 92/4000: 2019CA2 (checked 100)
# ✅ 90/4000: 2021PY4 (checked 98)
# ✅ 91/4000: 2017SD20 (checked 99)
# ✅ 92/4000: 2019CA2 (checked 100)
# ✅ 93/4000: 2011SL173 (checked 101)
# ✅ 94/4000: 2019TE1 (checked 102)
# ✅ 95/4000: 2019FS1 (checked 103)
# ✅ 96/4000: 2013VO11 (checked 104)
# ✅ 97/4000: 2025FU18 (checked 105)
# ✅ 98/4000: 2024EE1 (checked 106)
# ✅ 99/4000: 2021RR2 (checked 107)
# ✅ 93/4000: 2011SL173 (checked 101)
# ✅ 94/4000: 2019TE1 (checked 102)
# ✅ 95/4000: 2019FS1 (checked 103)
# ✅ 96/4000: 2013VO11 (checked 104)
# ✅ 97/4000: 2025FU18 (checked 105)
# ✅ 98/4000: 2024EE1 (checked 106)
# ✅ 99/4000: 2021RR2 (checked 107)
# ✅ 100/4000: 2024UA18 (checked 108)
# ✅ 101/4000: 2024GX3 (checked 109)
# ✅ 102/4000: 2017FQ146 (checked 110)
# ✅ 100/4000: 2024UA18 (checked 108)
# ✅ 101/4000: 2024GX3 (checked 109)
# ✅ 102/4000: 2017FQ146 (checked 110)
# ✅ 103/4000: 2020CR2 (checked 111)
# ✅ 104/4000: 2009CD2 (checked 112)
# ✅ 105/4000: 2004SR26 (checked 113)
# ✅ 106/4000: 2017MS8 (checked 114)
# ✅ 107/4000: 2024XR1 (checked 115)
# ✅ 108/4000: 2024XE11 (checked 116)
# ✅ 103/4000: 2020CR2 (checked 111)
# ✅ 104/4000: 2009CD2 (checked 112)
# ✅ 105/4000: 2004SR26 (checked 113)
# ✅ 106/4000: 2017MS8 (checked 114)
# ✅ 107/4000: 2024XR1 (checked 115)
# ✅ 108/4000: 2024XE11 (checked 116)
# ✅ 109/4000: 2017UR5 (checked 117)
# ✅ 110/4000: 2023UR3 (checked 118)
# ✅ 111/4000: 2019RF2 (checked 119)
# ✅ 112/4000: 2020PK1 (checked 120)
# ❌ 2020WY4: Missing data sources (checked 121)
# ✅ 109/4000: 2017UR5 (checked 117)
# ✅ 110/4000: 2023UR3 (checked 118)
# ✅ 111/4000: 2019RF2 (checked 119)
# ✅ 112/4000: 2020PK1 (checked 120)
# ❌ 2020WY4: Missing data sources (checked 121)
# ✅ 113/4000: 2020UX2 (checked 122)
# ✅ 114/4000: 2018WF2 (checked 123)
# ✅ 115/4000: 2022SQ11 (checked 124)
# ✅ 116/4000: 2007VD191 (checked 125)
# ✅ 117/4000: 2014UR34 (checked 126)
# ✅ 118/4000: 2015XS1 (checked 127)
# ✅ 113/4000: 2020UX2 (checked 122)
# ✅ 114/4000: 2018WF2 (checked 123)
# ✅ 115/4000: 2022SQ11 (checked 124)
# ✅ 116/4000: 2007VD191 (checked 125)
# ✅ 117/4000: 2014UR34 (checked 126)
# ✅ 118/4000: 2015XS1 (checked 127)
# ✅ 119/4000: 2019VO3 (checked 128)
# ✅ 120/4000: 2021VK3 (checked 129)
# ✅ 121/4000: 2019GU1 (checked 130)
# ✅ 122/4000: 2022WS9 (checked 131)
# ✅ 119/4000: 2019VO3 (checked 128)
# ✅ 120/4000: 2021VK3 (checked 129)
# ✅ 121/4000: 2019GU1 (checked 130)
# ✅ 122/4000: 2022WS9 (checked 131)
# ✅ 123/4000: 2012BS1 (checked 132)
# ✅ 124/4000: 2015HO116 (checked 133)
# ✅ 125/4000: 2014GG45 (checked 134)
# ✅ 126/4000: 2024KT1 (checked 135)
# ✅ 127/4000: 2021CW7 (checked 136)
# ✅ 128/4000: 2016AV193 (checked 137)
# ✅ 123/4000: 2012BS1 (checked 132)
# ✅ 124/4000: 2015HO116 (checked 133)
# ✅ 125/4000: 2014GG45 (checked 134)
# ✅ 126/4000: 2024KT1 (checked 135)
# ✅ 127/4000: 2021CW7 (checked 136)
# ✅ 128/4000: 2016AV193 (checked 137)
# ✅ 129/4000: 2013JJ22 (checked 138)
# ✅ 130/4000: 2021RC6 (checked 139)
# ✅ 131/4000: 2021RQ2 (checked 140)
# ❌ 2023XH7: Missing data sources (checked 141)
# ✅ 132/4000: 2022CS4 (checked 142)
# ❌ 2008VA4: Missing data sources (checked 143)
# ✅ 129/4000: 2013JJ22 (checked 138)
# ✅ 130/4000: 2021RC6 (checked 139)
# ✅ 131/4000: 2021RQ2 (checked 140)
# ❌ 2023XH7: Missing data sources (checked 141)
# ✅ 132/4000: 2022CS4 (checked 142)
# ❌ 2008VA4: Missing data sources (checked 143)
# ✅ 133/4000: 2021XC2 (checked 144)
# ✅ 134/4000: 2022AB4 (checked 145)
# ✅ 135/4000: 2025DT5 (checked 146)
# ❌ 2019QU4: Missing data sources (checked 147)
# ✅ 136/4000: 2022EV3 (checked 148)
# ✅ 137/4000: 2018MZ4 (checked 149)
# ✅ 138/4000: 2012FY13 (checked 150)
# ✅ 133/4000: 2021XC2 (checked 144)
# ✅ 134/4000: 2022AB4 (checked 145)
# ✅ 135/4000: 2025DT5 (checked 146)
# ❌ 2019QU4: Missing data sources (checked 147)
# ✅ 136/4000: 2022EV3 (checked 148)
# ✅ 137/4000: 2018MZ4 (checked 149)
# ✅ 138/4000: 2012FY13 (checked 150)
# ✅ 139/4000: 2023US5 (checked 151)
# ✅ 140/4000: 2016LP10 (checked 152)
# ✅ 141/4000: 2018PV24 (checked 153)
# ✅ 142/4000: 2013AR72 (checked 154)
# ❌ 2013RS73: Missing data sources (checked 155)
# ✅ 139/4000: 2023US5 (checked 151)
# ✅ 140/4000: 2016LP10 (checked 152)
# ✅ 141/4000: 2018PV24 (checked 153)
# ✅ 142/4000: 2013AR72 (checked 154)
# ❌ 2013RS73: Missing data sources (checked 155)
# ✅ 143/4000: 2021UC5 (checked 156)
# ✅ 144/4000: 2024FR3 (checked 157)
# ✅ 145/4000: 2025DV2 (checked 158)
# ✅ 146/4000: 2019VS4 (checked 159)
# ✅ 147/4000: 2016QB11 (checked 160)
# ✅ 148/4000: 2020XS1 (checked 161)
# ✅ 143/4000: 2021UC5 (checked 156)
# ✅ 144/4000: 2024FR3 (checked 157)
# ✅ 145/4000: 2025DV2 (checked 158)
# ✅ 146/4000: 2019VS4 (checked 159)
# ✅ 147/4000: 2016QB11 (checked 160)
# ✅ 148/4000: 2020XS1 (checked 161)
# ✅ 149/4000: 2023UR6 (checked 162)
# ✅ 150/4000: 2018XL2 (checked 163)
# ✅ 151/4000: 2021NT5 (checked 164)
# ✅ 152/4000: 2025GL1 (checked 165)
# ✅ 149/4000: 2023UR6 (checked 162)
# ✅ 150/4000: 2018XL2 (checked 163)
# ✅ 151/4000: 2021NT5 (checked 164)
# ✅ 152/4000: 2025GL1 (checked 165)
# ✅ 153/4000: 2023GG2 (checked 166)
# ✅ 154/4000: 2020BQ9 (checked 167)
# ✅ 155/4000: 2018MS8 (checked 168)
# ✅ 156/4000: 2024TM3 (checked 169)
# ✅ 157/4000: 2021ES1 (checked 170)
# ✅ 158/4000: 2006WP1 (checked 171)
# ✅ 153/4000: 2023GG2 (checked 166)
# ✅ 154/4000: 2020BQ9 (checked 167)
# ✅ 155/4000: 2018MS8 (checked 168)
# ✅ 156/4000: 2024TM3 (checked 169)
# ✅ 157/4000: 2021ES1 (checked 170)
# ✅ 158/4000: 2006WP1 (checked 171)
# ✅ 159/4000: 2025HA19 (checked 172)
# ❌ 2017YA1: Missing data sources (checked 173)
# ✅ 160/4000: 2021WM4 (checked 174)
# ✅ 161/4000: 2020BK2 (checked 175)
# ✅ 162/4000: 2022UA14 (checked 176)
# ✅ 159/4000: 2025HA19 (checked 172)
# ❌ 2017YA1: Missing data sources (checked 173)
# ✅ 160/4000: 2021WM4 (checked 174)
# ✅ 161/4000: 2020BK2 (checked 175)
# ✅ 162/4000: 2022UA14 (checked 176)
# ✅ 163/4000: 2019FB1 (checked 177)
# ✅ 164/4000: 2018FC3 (checked 178)
# ✅ 165/4000: 2021VT11 (checked 179)
# ✅ 166/4000: 2009EH1 (checked 180)
# ✅ 167/4000: 2023XO14 (checked 181)
# ✅ 163/4000: 2019FB1 (checked 177)
# ✅ 164/4000: 2018FC3 (checked 178)
# ✅ 165/4000: 2021VT11 (checked 179)
# ✅ 166/4000: 2009EH1 (checked 180)
# ✅ 167/4000: 2023XO14 (checked 181)
# ❌ 2017VN13: Missing data sources (checked 182)
# ✅ 168/4000: 2025FC8 (checked 183)
# ❌ 2024TX6: Missing data sources (checked 184)
# ✅ 169/4000: 2024TB7 (checked 185)
# ✅ 170/4000: 2022QO1 (checked 186)
# ✅ 171/4000: 2018DF1 (checked 187)
# ✅ 172/4000: 2019SM8 (checked 188)
# ❌ 2017VN13: Missing data sources (checked 182)
# ✅ 168/4000: 2025FC8 (checked 183)
# ❌ 2024TX6: Missing data sources (checked 184)
# ✅ 169/4000: 2024TB7 (checked 185)
# ✅ 170/4000: 2022QO1 (checked 186)
# ✅ 171/4000: 2018DF1 (checked 187)
# ✅ 172/4000: 2019SM8 (checked 188)
# ❌ 2009FQ32: Missing data sources (checked 189)
# ✅ 173/4000: 2025DN7 (checked 190)
# ✅ 174/4000: 2019SB5 (checked 191)
# ❌ 2009FQ32: Missing data sources (checked 189)
# ✅ 173/4000: 2025DN7 (checked 190)
# ✅ 174/4000: 2019SB5 (checked 191)
# ✅ 175/4000: 2023CL1 (checked 192)
# ✅ 176/4000: 2021KD16 (checked 193)
# ✅ 177/4000: 2022XP1 (checked 194)
# ✅ 178/4000: 2020HE7 (checked 195)
# ✅ 175/4000: 2023CL1 (checked 192)
# ✅ 176/4000: 2021KD16 (checked 193)
# ✅ 177/4000: 2022XP1 (checked 194)
# ✅ 178/4000: 2020HE7 (checked 195)
# ✅ 179/4000: 2022AM3 (checked 196)
# ✅ 180/4000: 2015TL350 (checked 197)
# ✅ 181/4000: 2021RM3 (checked 198)
# ✅ 182/4000: 2011ER74 (checked 199)
# ❌ 2016JH38: Missing data sources (checked 200)
# ✅ 179/4000: 2022AM3 (checked 196)
# ✅ 180/4000: 2015TL350 (checked 197)
# ✅ 181/4000: 2021RM3 (checked 198)
# ✅ 182/4000: 2011ER74 (checked 199)
# ❌ 2016JH38: Missing data sources (checked 200)
# ✅ 183/4000: 2024BP3 (checked 201)
# ✅ 184/4000: 2022DG2 (checked 202)
# ❌ 2007HV4: Missing data sources (checked 203)
# ✅ 185/4000: 2024BY1 (checked 204)
# ✅ 186/4000: 2018CC3 (checked 205)
# ✅ 183/4000: 2024BP3 (checked 201)
# ✅ 184/4000: 2022DG2 (checked 202)
# ❌ 2007HV4: Missing data sources (checked 203)
# ✅ 185/4000: 2024BY1 (checked 204)
# ✅ 186/4000: 2018CC3 (checked 205)
# ❌ 2018VU2: Missing data sources (checked 206)
# ❌ 2021KN2: Missing data sources (checked 207)
# ✅ 187/4000: 2024LS5 (checked 208)
# ✅ 188/4000: 2019FR1 (checked 209)
# ✅ 189/4000: 2022JT1 (checked 210)
# ❌ 2018VU2: Missing data sources (checked 206)
# ❌ 2021KN2: Missing data sources (checked 207)
# ✅ 187/4000: 2024LS5 (checked 208)
# ✅ 188/4000: 2019FR1 (checked 209)
# ✅ 189/4000: 2022JT1 (checked 210)
# ✅ 190/4000: 2016VO2 (checked 211)
# ✅ 191/4000: 2015TC144 (checked 212)
# ❌ 2008EW84: Missing data sources (checked 213)
# ✅ 192/4000: 2012DM32 (checked 214)
# ✅ 193/4000: 2012TQ5 (checked 215)
# ✅ 190/4000: 2016VO2 (checked 211)
# ✅ 191/4000: 2015TC144 (checked 212)
# ❌ 2008EW84: Missing data sources (checked 213)
# ✅ 192/4000: 2012DM32 (checked 214)
# ✅ 193/4000: 2012TQ5 (checked 215)
# ✅ 194/4000: 2019VW3 (checked 216)
# ✅ 195/4000: 2025KG13 (checked 217)
# ✅ 196/4000: 2022GF17 (checked 218)
# ✅ 197/4000: 2011GW65 (checked 219)
# ❌ 2020DE1: Missing data sources (checked 220)
# ❌ 2013JR17: Missing data sources (checked 221)
# ✅ 198/4000: 2005SK26 (checked 222)
# ✅ 199/4000: 2016JN38 (checked 223)
# ✅ 200/4000: 2017UW5 (checked 224)
# ✅ 194/4000: 2019VW3 (checked 216)
# ✅ 195/4000: 2025KG13 (checked 217)
# ✅ 196/4000: 2022GF17 (checked 218)
# ✅ 197/4000: 2011GW65 (checked 219)
# ❌ 2020DE1: Missing data sources (checked 220)
# ❌ 2013JR17: Missing data sources (checked 221)
# ✅ 198/4000: 2005SK26 (checked 222)
# ✅ 199/4000: 2016JN38 (checked 223)
# ✅ 200/4000: 2017UW5 (checked 224)
# ✅ 201/4000: 2011TH5 (checked 225)
# ✅ 202/4000: 2019FZ1 (checked 226)
# ✅ 203/4000: 2018DV1 (checked 227)
# ❌ 2021HP2: Missing data sources (checked 228)
# ✅ 201/4000: 2011TH5 (checked 225)
# ✅ 202/4000: 2019FZ1 (checked 226)
# ✅ 203/4000: 2018DV1 (checked 227)
# ❌ 2021HP2: Missing data sources (checked 228)
# ✅ 204/4000: 2001BM61 (checked 229)
# ✅ 205/4000: 2023VP1 (checked 230)
# ✅ 206/4000: 2015VP105 (checked 231)
# ✅ 207/4000: 2024RH13 (checked 232)
# ✅ 208/4000: 2014BM62 (checked 233)
# ✅ 209/4000: 2008EC32 (checked 234)
# ✅ 204/4000: 2001BM61 (checked 229)
# ✅ 205/4000: 2023VP1 (checked 230)
# ✅ 206/4000: 2015VP105 (checked 231)
# ✅ 207/4000: 2024RH13 (checked 232)
# ✅ 208/4000: 2014BM62 (checked 233)
# ✅ 209/4000: 2008EC32 (checked 234)
# ✅ 210/4000: 2021GE6 (checked 235)
# ✅ 211/4000: 2023TF3 (checked 236)
# ✅ 212/4000: 2017SA14 (checked 237)
# ✅ 210/4000: 2021GE6 (checked 235)
# ✅ 211/4000: 2023TF3 (checked 236)
# ✅ 212/4000: 2017SA14 (checked 237)
# ✅ 213/4000: 2003DU25 (checked 238)
# ✅ 214/4000: 2020KS5 (checked 239)
# ✅ 215/4000: 2013LR6 (checked 240)
# ✅ 213/4000: 2003DU25 (checked 238)
# ✅ 214/4000: 2020KS5 (checked 239)
# ✅ 215/4000: 2013LR6 (checked 240)
# ✅ 216/4000: 2023VG7 (checked 241)
# ✅ 217/4000: 2022YR4 (checked 242)
# ✅ 218/4000: 2004RN251 (checked 243)
# ✅ 219/4000: 2020OF4 (checked 244)
# ❌ 2015HD1: Missing data sources (checked 245)
# ✅ 220/4000: 2008DU22 (checked 246)
# ✅ 216/4000: 2023VG7 (checked 241)
# ✅ 217/4000: 2022YR4 (checked 242)
# ✅ 218/4000: 2004RN251 (checked 243)
# ✅ 219/4000: 2020OF4 (checked 244)
# ❌ 2015HD1: Missing data sources (checked 245)
# ✅ 220/4000: 2008DU22 (checked 246)
# ✅ 221/4000: 2025AO1 (checked 247)
# ✅ 222/4000: 2022UF9 (checked 248)
# ✅ 223/4000: 2015NR2 (checked 249)
# ✅ 221/4000: 2025AO1 (checked 247)
# ✅ 222/4000: 2022UF9 (checked 248)
# ✅ 223/4000: 2015NR2 (checked 249)
# ✅ 224/4000: 2022SP3 (checked 250)
# ✅ 225/4000: 2011UA64 (checked 251)
# ✅ 226/4000: 2024FV1 (checked 252)
# ✅ 227/4000: 2024RL2 (checked 253)
# ✅ 228/4000: 2019TL3 (checked 254)
# ✅ 224/4000: 2022SP3 (checked 250)
# ✅ 225/4000: 2011UA64 (checked 251)
# ✅ 226/4000: 2024FV1 (checked 252)
# ✅ 227/4000: 2024RL2 (checked 253)
# ✅ 228/4000: 2019TL3 (checked 254)
# ✅ 229/4000: 2009HJ36 (checked 255)
# ✅ 230/4000: 2021OD1 (checked 256)
# ✅ 231/4000: 2023BJ7 (checked 257)
# ✅ 229/4000: 2009HJ36 (checked 255)
# ✅ 230/4000: 2021OD1 (checked 256)
# ✅ 231/4000: 2023BJ7 (checked 257)
# ✅ 232/4000: 2021TP1 (checked 258)
# ✅ 233/4000: 2023XP1 (checked 259)
# ✅ 234/4000: 2016LZ48 (checked 260)
# ✅ 232/4000: 2021TP1 (checked 258)
# ✅ 233/4000: 2023XP1 (checked 259)
# ✅ 234/4000: 2016LZ48 (checked 260)
# ✅ 235/4000: 2023SL43 (checked 261)
# ❌ 2016UR41: Missing data sources (checked 262)
# ✅ 236/4000: 2005GX119 (checked 263)
# ✅ 237/4000: 2023BH1 (checked 264)
# ✅ 238/4000: 2021CC1 (checked 265)
# ✅ 239/4000: 2023VD2 (checked 266)
# ✅ 240/4000: 2015XG55 (checked 267)
# ✅ 235/4000: 2023SL43 (checked 261)
# ❌ 2016UR41: Missing data sources (checked 262)
# ✅ 236/4000: 2005GX119 (checked 263)
# ✅ 237/4000: 2023BH1 (checked 264)
# ✅ 238/4000: 2021CC1 (checked 265)
# ✅ 239/4000: 2023VD2 (checked 266)
# ✅ 240/4000: 2015XG55 (checked 267)
# ✅ 241/4000: 2015HQ9 (checked 268)
# ✅ 242/4000: 2020HY9 (checked 269)
# ✅ 241/4000: 2015HQ9 (checked 268)
# ✅ 242/4000: 2020HY9 (checked 269)
# ✅ 243/4000: 2021JA2 (checked 270)
# ✅ 244/4000: 2021GQ5 (checked 271)
# ✅ 245/4000: 2021CH1 (checked 272)
# ✅ 246/4000: 2024BH1 (checked 273)
# ✅ 247/4000: 2021TL10 (checked 274)
# ✅ 243/4000: 2021JA2 (checked 270)
# ✅ 244/4000: 2021GQ5 (checked 271)
# ✅ 245/4000: 2021CH1 (checked 272)
# ✅ 246/4000: 2024BH1 (checked 273)
# ✅ 247/4000: 2021TL10 (checked 274)
# ✅ 248/4000: 2022GP1 (checked 275)
# ✅ 249/4000: 2014UV56 (checked 276)
# ✅ 250/4000: 2018GP4 (checked 277)
# ❌ 2021NQ2: Missing data sources (checked 278)
# ✅ 251/4000: 2015TU237 (checked 279)
# ❌ 2010VA72: Missing data sources (checked 280)
# ✅ 248/4000: 2022GP1 (checked 275)
# ✅ 249/4000: 2014UV56 (checked 276)
# ✅ 250/4000: 2018GP4 (checked 277)
# ❌ 2021NQ2: Missing data sources (checked 278)
# ✅ 251/4000: 2015TU237 (checked 279)
# ❌ 2010VA72: Missing data sources (checked 280)
# ❌ 2009SL1: Missing data sources (checked 281)
# ✅ 252/4000: 2021VJ5 (checked 282)
# ❌ 2022WF6: Missing data sources (checked 283)
# ❌ 2006BV39: Missing data sources (checked 284)
# ✅ 253/4000: 2019GE1 (checked 285)
# ❌ 2009SL1: Missing data sources (checked 281)
# ✅ 252/4000: 2021VJ5 (checked 282)
# ❌ 2022WF6: Missing data sources (checked 283)
# ❌ 2006BV39: Missing data sources (checked 284)
# ✅ 253/4000: 2019GE1 (checked 285)
# ✅ 254/4000: 2014OB489 (checked 286)
# ✅ 255/4000: 2023XO13 (checked 287)
# ✅ 256/4000: 2015KW56 (checked 288)
# ✅ 257/4000: 2018CE3 (checked 289)
# ✅ 258/4000: 2020WG2 (checked 290)
# ❌ 2020YG3: Missing data sources (checked 291)
# ✅ 259/4000: 2012CL17 (checked 292)
# ✅ 254/4000: 2014OB489 (checked 286)
# ✅ 255/4000: 2023XO13 (checked 287)
# ✅ 256/4000: 2015KW56 (checked 288)
# ✅ 257/4000: 2018CE3 (checked 289)
# ✅ 258/4000: 2020WG2 (checked 290)
# ❌ 2020YG3: Missing data sources (checked 291)
# ✅ 259/4000: 2012CL17 (checked 292)
# ✅ 260/4000: 2020MQ1 (checked 293)
# ✅ 261/4000: 2022UO4 (checked 294)
# ✅ 262/4000: 2014OZ111 (checked 295)
# ✅ 263/4000: 2022CT6 (checked 296)
# ✅ 260/4000: 2020MQ1 (checked 293)
# ✅ 261/4000: 2022UO4 (checked 294)
# ✅ 262/4000: 2014OZ111 (checked 295)
# ✅ 263/4000: 2022CT6 (checked 296)
# ❌ 2024SB1: Missing data sources (checked 297)
# ✅ 264/4000: 2016FP60 (checked 298)
# ✅ 265/4000: 2011CG50 (checked 299)
# ❌ 2020FO4: Missing data sources (checked 300)
# ✅ 266/4000: 2014WM367 (checked 301)
# ✅ 267/4000: 2021NQ3 (checked 302)
# ✅ 268/4000: 2024FQ2 (checked 303)
# ❌ 2018TB5: Missing data sources (checked 304)
# ❌ 2024SB1: Missing data sources (checked 297)
# ✅ 264/4000: 2016FP60 (checked 298)
# ✅ 265/4000: 2011CG50 (checked 299)
# ❌ 2020FO4: Missing data sources (checked 300)
# ✅ 266/4000: 2014WM367 (checked 301)
# ✅ 267/4000: 2021NQ3 (checked 302)
# ✅ 268/4000: 2024FQ2 (checked 303)
# ❌ 2018TB5: Missing data sources (checked 304)
# ❌ 2021AC2: Missing data sources (checked 305)
# ✅ 269/4000: 2023XK16 (checked 306)
# ✅ 270/4000: 2023UJ6 (checked 307)
# ❌ 2025HU2: Missing data sources (checked 308)
# ❌ 2021AC2: Missing data sources (checked 305)
# ✅ 269/4000: 2023XK16 (checked 306)
# ✅ 270/4000: 2023UJ6 (checked 307)
# ❌ 2025HU2: Missing data sources (checked 308)
# ✅ 271/4000: 2021VD19 (checked 309)
# ✅ 272/4000: 2020TT6 (checked 310)
# ✅ 273/4000: 2019UK9 (checked 311)
# ✅ 271/4000: 2021VD19 (checked 309)
# ✅ 272/4000: 2020TT6 (checked 310)
# ✅ 273/4000: 2019UK9 (checked 311)
# ✅ 274/4000: 2022UQ6 (checked 312)
# ✅ 275/4000: 2015BT516 (checked 313)
# ✅ 276/4000: 2020SN3 (checked 314)
# ✅ 277/4000: 2020DP14 (checked 315)
# ✅ 278/4000: 2024FQ1 (checked 316)
# ✅ 279/4000: 2022YX2 (checked 317)
# ❌ 2015KZ56: Missing data sources (checked 318)
# ✅ 280/4000: 2023RX3 (checked 319)
# ✅ 274/4000: 2022UQ6 (checked 312)
# ✅ 275/4000: 2015BT516 (checked 313)
# ✅ 276/4000: 2020SN3 (checked 314)
# ✅ 277/4000: 2020DP14 (checked 315)
# ✅ 278/4000: 2024FQ1 (checked 316)
# ✅ 279/4000: 2022YX2 (checked 317)
# ❌ 2015KZ56: Missing data sources (checked 318)
# ✅ 280/4000: 2023RX3 (checked 319)
# ✅ 281/4000: 2020ON5 (checked 320)
# ✅ 282/4000: 2021FD50 (checked 321)
# ✅ 283/4000: 2015KV157 (checked 322)
# ✅ 281/4000: 2020ON5 (checked 320)
# ✅ 282/4000: 2021FD50 (checked 321)
# ✅ 283/4000: 2015KV157 (checked 322)
# ✅ 284/4000: 2021RK1 (checked 323)
# ✅ 285/4000: 2014QP439 (checked 324)
# ❌ 2021XN2: Missing data sources (checked 325)
# ✅ 286/4000: 2024PM1 (checked 326)
# ✅ 287/4000: 2021RF3 (checked 327)
# ✅ 288/4000: 2023XQ16 (checked 328)
# ✅ 289/4000: 2021SW1 (checked 329)
# ✅ 290/4000: 2023XF1 (checked 330)
# ✅ 284/4000: 2021RK1 (checked 323)
# ✅ 285/4000: 2014QP439 (checked 324)
# ❌ 2021XN2: Missing data sources (checked 325)
# ✅ 286/4000: 2024PM1 (checked 326)
# ✅ 287/4000: 2021RF3 (checked 327)
# ✅ 288/4000: 2023XQ16 (checked 328)
# ✅ 289/4000: 2021SW1 (checked 329)
# ✅ 290/4000: 2023XF1 (checked 330)
# ✅ 291/4000: 2007TB25 (checked 331)
# ✅ 292/4000: 2012UB174 (checked 332)
# ✅ 291/4000: 2007TB25 (checked 331)
# ✅ 292/4000: 2012UB174 (checked 332)
# ✅ 293/4000: 2011FF41 (checked 333)
# ✅ 294/4000: 2021WC1 (checked 334)
# ✅ 295/4000: 2014MH6 (checked 335)
# ✅ 296/4000: 2019KM5 (checked 336)
# ✅ 297/4000: 2008UD202 (checked 337)
# ❌ 2023XH3: Missing data sources (checked 338)
# ✅ 298/4000: 2023LM1 (checked 339)
# ✅ 299/4000: 2003WT153 (checked 340)
# ✅ 300/4000: 2022SG11 (checked 341)
# ✅ 293/4000: 2011FF41 (checked 333)
# ✅ 294/4000: 2021WC1 (checked 334)
# ✅ 295/4000: 2014MH6 (checked 335)
# ✅ 296/4000: 2019KM5 (checked 336)
# ✅ 297/4000: 2008UD202 (checked 337)
# ❌ 2023XH3: Missing data sources (checked 338)
# ✅ 298/4000: 2023LM1 (checked 339)
# ✅ 299/4000: 2003WT153 (checked 340)
# ✅ 300/4000: 2022SG11 (checked 341)
# ❌ 2012RT16: Missing data sources (checked 342)
# ✅ 301/4000: 2024UL13 (checked 343)
# ❌ 2016LE10: Missing data sources (checked 344)
# ✅ 302/4000: 2024AU1 (checked 345)
# ❌ 2012RT16: Missing data sources (checked 342)
# ✅ 301/4000: 2024UL13 (checked 343)
# ❌ 2016LE10: Missing data sources (checked 344)
# ✅ 302/4000: 2024AU1 (checked 345)
# ✅ 303/4000: 2019VE2 (checked 346)
# ✅ 304/4000: 2020HY5 (checked 347)
# ✅ 305/4000: 2020QQ4 (checked 348)
# ✅ 306/4000: 2020XG2 (checked 349)
# ✅ 307/4000: 2005EM70 (checked 350)
# ✅ 308/4000: 2020RV4 (checked 351)
# ✅ 309/4000: 2020BO7 (checked 352)
# ✅ 303/4000: 2019VE2 (checked 346)
# ✅ 304/4000: 2020HY5 (checked 347)
# ✅ 305/4000: 2020QQ4 (checked 348)
# ✅ 306/4000: 2020XG2 (checked 349)
# ✅ 307/4000: 2005EM70 (checked 350)
# ✅ 308/4000: 2020RV4 (checked 351)
# ✅ 309/4000: 2020BO7 (checked 352)
# ❌ 2021EW3: Missing data sources (checked 353)
# ❌ 2017YE7: Missing data sources (checked 354)
# ✅ 310/4000: 2021GN1 (checked 355)
# ✅ 311/4000: 2015KH321 (checked 356)
# ✅ 312/4000: 2012FT23 (checked 357)
# ❌ 2021EW3: Missing data sources (checked 353)
# ❌ 2017YE7: Missing data sources (checked 354)
# ✅ 310/4000: 2021GN1 (checked 355)
# ✅ 311/4000: 2015KH321 (checked 356)
# ✅ 312/4000: 2012FT23 (checked 357)
# ✅ 313/4000: 2023UW1 (checked 358)
# ✅ 314/4000: 2024UZ4 (checked 359)
# ✅ 315/4000: 2017WZ13 (checked 360)
# ✅ 316/4000: 2020AP1 (checked 361)
# ✅ 317/4000: 2023HJ3 (checked 362)
# ✅ 318/4000: 2007VF189 (checked 363)
# ✅ 313/4000: 2023UW1 (checked 358)
# ✅ 314/4000: 2024UZ4 (checked 359)
# ✅ 315/4000: 2017WZ13 (checked 360)
# ✅ 316/4000: 2020AP1 (checked 361)
# ✅ 317/4000: 2023HJ3 (checked 362)
# ✅ 318/4000: 2007VF189 (checked 363)
# ✅ 319/4000: 2018GT11 (checked 364)
# ❌ 2025MQ91: Missing data sources (checked 365)
# ❌ 2021GL1: Missing data sources (checked 366)
# ✅ 320/4000: 2019UA2 (checked 367)
# ✅ 321/4000: 2022UQ9 (checked 368)
# ✅ 322/4000: 2021UR7 (checked 369)
# ✅ 319/4000: 2018GT11 (checked 364)
# ❌ 2025MQ91: Missing data sources (checked 365)
# ❌ 2021GL1: Missing data sources (checked 366)
# ✅ 320/4000: 2019UA2 (checked 367)
# ✅ 321/4000: 2022UQ9 (checked 368)
# ✅ 322/4000: 2021UR7 (checked 369)
# ✅ 323/4000: 2022VM1 (checked 370)
# ✅ 324/4000: 2023DJ1 (checked 371)
# ✅ 325/4000: 2020WS4 (checked 372)
# ✅ 326/4000: 2024YG9 (checked 373)
# ✅ 327/4000: 2017WW1 (checked 374)
# ✅ 323/4000: 2022VM1 (checked 370)
# ✅ 324/4000: 2023DJ1 (checked 371)
# ✅ 325/4000: 2020WS4 (checked 372)
# ✅ 326/4000: 2024YG9 (checked 373)
# ✅ 327/4000: 2017WW1 (checked 374)
# ✅ 328/4000: 2020BE13 (checked 375)
# ✅ 329/4000: 2023FB5 (checked 376)
# ❌ 2010SW3: Missing data sources (checked 377)
# ✅ 330/4000: 2023MW2 (checked 378)
# ✅ 331/4000: 2019UD3 (checked 379)
# ✅ 332/4000: 2012KT42 (checked 380)
# ✅ 328/4000: 2020BE13 (checked 375)
# ✅ 329/4000: 2023FB5 (checked 376)
# ❌ 2010SW3: Missing data sources (checked 377)
# ✅ 330/4000: 2023MW2 (checked 378)
# ✅ 331/4000: 2019UD3 (checked 379)
# ✅ 332/4000: 2012KT42 (checked 380)
# ✅ 333/4000: 2014MW67 (checked 381)
# ✅ 334/4000: 2024QM1 (checked 382)
# ✅ 335/4000: 2022CJ5 (checked 383)
# ✅ 336/4000: 2022UX10 (checked 384)
# ✅ 333/4000: 2014MW67 (checked 381)
# ✅ 334/4000: 2024QM1 (checked 382)
# ✅ 335/4000: 2022CJ5 (checked 383)
# ✅ 336/4000: 2022UX10 (checked 384)
# ✅ 337/4000: 2021TH15 (checked 385)
# ✅ 338/4000: 2019NB7 (checked 386)
# ✅ 339/4000: 2025EN2 (checked 387)
# ✅ 340/4000: 2017DQ34 (checked 388)
# ✅ 341/4000: 2021TM14 (checked 389)
# ✅ 342/4000: 2024XK5 (checked 390)
# ✅ 337/4000: 2021TH15 (checked 385)
# ✅ 338/4000: 2019NB7 (checked 386)
# ✅ 339/4000: 2025EN2 (checked 387)
# ✅ 340/4000: 2017DQ34 (checked 388)
# ✅ 341/4000: 2021TM14 (checked 389)
# ✅ 342/4000: 2024XK5 (checked 390)
# ✅ 343/4000: 2010XA59 (checked 391)
# ✅ 344/4000: 2025CC3 (checked 392)
# ✅ 345/4000: 2019UT1 (checked 393)
# ✅ 346/4000: 2021VL1 (checked 394)
# ❌ 2024AG3: Missing data sources (checked 395)
# ✅ 343/4000: 2010XA59 (checked 391)
# ✅ 344/4000: 2025CC3 (checked 392)
# ✅ 345/4000: 2019UT1 (checked 393)
# ✅ 346/4000: 2021VL1 (checked 394)
# ❌ 2024AG3: Missing data sources (checked 395)
# ✅ 347/4000: 2019SJ9 (checked 396)
# ✅ 348/4000: 2019BV1 (checked 397)
# ✅ 349/4000: 2022TU1 (checked 398)
# ✅ 350/4000: 2022PJ1 (checked 399)
# ✅ 351/4000: 2022YE3 (checked 400)
# ✅ 352/4000: 2021PA17 (checked 401)
# ❌ 2012UL171: Missing data sources (checked 402)
# ❌ 2021CQ7: Missing data sources (checked 403)
# ❌ 2017YM14: Missing data sources (checked 404)
# ✅ 347/4000: 2019SJ9 (checked 396)
# ✅ 348/4000: 2019BV1 (checked 397)
# ✅ 349/4000: 2022TU1 (checked 398)
# ✅ 350/4000: 2022PJ1 (checked 399)
# ✅ 351/4000: 2022YE3 (checked 400)
# ✅ 352/4000: 2021PA17 (checked 401)
# ❌ 2012UL171: Missing data sources (checked 402)
# ❌ 2021CQ7: Missing data sources (checked 403)
# ❌ 2017YM14: Missing data sources (checked 404)
# ✅ 353/4000: 2024TB17 (checked 405)
# ✅ 354/4000: 2019VV5 (checked 406)
# ✅ 355/4000: 2016LT1 (checked 407)
# ✅ 356/4000: 2019RE1 (checked 408)
# ✅ 353/4000: 2024TB17 (checked 405)
# ✅ 354/4000: 2019VV5 (checked 406)
# ✅ 355/4000: 2016LT1 (checked 407)
# ✅ 356/4000: 2019RE1 (checked 408)
# ✅ 357/4000: 2016DY30 (checked 409)
# ✅ 358/4000: 2007VV7 (checked 410)
# ✅ 359/4000: 2017WH13 (checked 411)
# ✅ 360/4000: 2022SK6 (checked 412)
# ✅ 361/4000: 2023HZ5 (checked 413)
# ❌ 2010JM33: Missing data sources (checked 414)
# ✅ 362/4000: 2022PZ16 (checked 415)
# ✅ 357/4000: 2016DY30 (checked 409)
# ✅ 358/4000: 2007VV7 (checked 410)
# ✅ 359/4000: 2017WH13 (checked 411)
# ✅ 360/4000: 2022SK6 (checked 412)
# ✅ 361/4000: 2023HZ5 (checked 413)
# ❌ 2010JM33: Missing data sources (checked 414)
# ✅ 362/4000: 2022PZ16 (checked 415)
# ✅ 363/4000: 2025JP1 (checked 416)
# ✅ 364/4000: 2002XM35 (checked 417)
# ✅ 365/4000: 2017SO12 (checked 418)
# ✅ 366/4000: 2025KW7 (checked 419)
# ✅ 363/4000: 2025JP1 (checked 416)
# ✅ 364/4000: 2002XM35 (checked 417)
# ✅ 365/4000: 2017SO12 (checked 418)
# ✅ 366/4000: 2025KW7 (checked 419)
# ✅ 367/4000: 2011FQ21 (checked 420)
# ✅ 368/4000: 2020AP2 (checked 421)
# ✅ 369/4000: 2023ST6 (checked 422)
# ✅ 370/4000: 2016LW47 (checked 423)
# ✅ 371/4000: 2021RT100 (checked 424)
# ✅ 372/4000: 2023DR1 (checked 425)
# ✅ 367/4000: 2011FQ21 (checked 420)
# ✅ 368/4000: 2020AP2 (checked 421)
# ✅ 369/4000: 2023ST6 (checked 422)
# ✅ 370/4000: 2016LW47 (checked 423)
# ✅ 371/4000: 2021RT100 (checked 424)
# ✅ 372/4000: 2023DR1 (checked 425)
# ❌ 2014MF68: Missing data sources (checked 426)
# ✅ 373/4000: 2021RV2 (checked 427)
# ✅ 374/4000: 2009WD52 (checked 428)
# ✅ 375/4000: 2024JD2 (checked 429)
# ✅ 376/4000: 2024LZ4 (checked 430)
# ❌ 2014MF68: Missing data sources (checked 426)
# ✅ 373/4000: 2021RV2 (checked 427)
# ✅ 374/4000: 2009WD52 (checked 428)
# ✅ 375/4000: 2024JD2 (checked 429)
# ✅ 376/4000: 2024LZ4 (checked 430)
# ✅ 377/4000: 2024XB3 (checked 431)
# ✅ 378/4000: 2019QD1 (checked 432)
# ✅ 379/4000: 2011KK9 (checked 433)
# ✅ 380/4000: 2011HR4 (checked 434)
# ✅ 381/4000: 2022QW5 (checked 435)
# ✅ 377/4000: 2024XB3 (checked 431)
# ✅ 378/4000: 2019QD1 (checked 432)
# ✅ 379/4000: 2011KK9 (checked 433)
# ✅ 380/4000: 2011HR4 (checked 434)
# ✅ 381/4000: 2022QW5 (checked 435)
# ✅ 382/4000: 2021EF1 (checked 436)
# ❌ 2018CK2: Missing data sources (checked 437)
# ✅ 383/4000: 2014QO295 (checked 438)
# ✅ 384/4000: 2021RC2 (checked 439)
# ✅ 385/4000: 2017WE29 (checked 440)
# ✅ 386/4000: 2017SR14 (checked 441)
# ✅ 382/4000: 2021EF1 (checked 436)
# ❌ 2018CK2: Missing data sources (checked 437)
# ✅ 383/4000: 2014QO295 (checked 438)
# ✅ 384/4000: 2021RC2 (checked 439)
# ✅ 385/4000: 2017WE29 (checked 440)
# ✅ 386/4000: 2017SR14 (checked 441)
# ✅ 387/4000: 2021GX1 (checked 442)
# ✅ 388/4000: 2016DK2 (checked 443)
# ✅ 389/4000: 2005TM173 (checked 444)
# ✅ 390/4000: 2020QR1 (checked 445)
# ✅ 387/4000: 2021GX1 (checked 442)
# ✅ 388/4000: 2016DK2 (checked 443)
# ✅ 389/4000: 2005TM173 (checked 444)
# ✅ 390/4000: 2020QR1 (checked 445)
# ✅ 391/4000: 2021WK2 (checked 446)
# ✅ 392/4000: 2024YV10 (checked 447)
# ✅ 393/4000: 2019BR2 (checked 448)
# ✅ 394/4000: 2024SZ2 (checked 449)
# ✅ 395/4000: 2022OW3 (checked 450)
# ✅ 391/4000: 2021WK2 (checked 446)
# ✅ 392/4000: 2024YV10 (checked 447)
# ✅ 393/4000: 2019BR2 (checked 448)
# ✅ 394/4000: 2024SZ2 (checked 449)
# ✅ 395/4000: 2022OW3 (checked 450)
# ✅ 396/4000: 2023VH9 (checked 451)
# ✅ 397/4000: 2023LE2 (checked 452)
# ✅ 398/4000: 2021RN16 (checked 453)
# ✅ 396/4000: 2023VH9 (checked 451)
# ✅ 397/4000: 2023LE2 (checked 452)
# ✅ 398/4000: 2021RN16 (checked 453)
# ✅ 399/4000: 2024JG17 (checked 454)
# ✅ 400/4000: 2022UV12 (checked 455)
# ✅ 401/4000: 2024UG21 (checked 456)
# ✅ 402/4000: 2020UD5 (checked 457)
# ✅ 403/4000: 2025DF4 (checked 458)
# ✅ 404/4000: 2016RZ33 (checked 459)
# ✅ 405/4000: 2023XB13 (checked 460)
# ✅ 399/4000: 2024JG17 (checked 454)
# ✅ 400/4000: 2022UV12 (checked 455)
# ✅ 401/4000: 2024UG21 (checked 456)
# ✅ 402/4000: 2020UD5 (checked 457)
# ✅ 403/4000: 2025DF4 (checked 458)
# ✅ 404/4000: 2016RZ33 (checked 459)
# ✅ 405/4000: 2023XB13 (checked 460)
# ✅ 406/4000: 2018CJ2 (checked 461)
# ✅ 407/4000: 2014LF25 (checked 462)
# ✅ 408/4000: 2019LD42 (checked 463)
# ✅ 406/4000: 2018CJ2 (checked 461)
# ✅ 407/4000: 2014LF25 (checked 462)
# ✅ 408/4000: 2019LD42 (checked 463)
# ✅ 409/4000: 2021VX22 (checked 464)
# ✅ 410/4000: 2021LL5 (checked 465)
# ✅ 411/4000: 2006DD1 (checked 466)
# ✅ 412/4000: 2025HM6 (checked 467)
# ✅ 413/4000: 2017DR34 (checked 468)
# ✅ 414/4000: 2023TY10 (checked 469)
# ✅ 415/4000: 2024UV3 (checked 470)
# ✅ 409/4000: 2021VX22 (checked 464)
# ✅ 410/4000: 2021LL5 (checked 465)
# ✅ 411/4000: 2006DD1 (checked 466)
# ✅ 412/4000: 2025HM6 (checked 467)
# ✅ 413/4000: 2017DR34 (checked 468)
# ✅ 414/4000: 2023TY10 (checked 469)
# ✅ 415/4000: 2024UV3 (checked 470)
# ✅ 416/4000: 2021LS2 (checked 471)
# ✅ 417/4000: 2022LU2 (checked 472)
# ✅ 418/4000: 2018VA7 (checked 473)
# ✅ 416/4000: 2021LS2 (checked 471)
# ✅ 417/4000: 2022LU2 (checked 472)
# ✅ 418/4000: 2018VA7 (checked 473)
# ✅ 419/4000: 2010ER12 (checked 474)
# ✅ 420/4000: 2018VJ10 (checked 475)
# ✅ 421/4000: 2009WV51 (checked 476)
# ✅ 422/4000: 2012DJ14 (checked 477)
# ✅ 423/4000: 2023WY1 (checked 478)
# ✅ 424/4000: 2021UF3 (checked 479)
# ✅ 425/4000: 2011EO11 (checked 480)
# ✅ 419/4000: 2010ER12 (checked 474)
# ✅ 420/4000: 2018VJ10 (checked 475)
# ✅ 421/4000: 2009WV51 (checked 476)
# ✅ 422/4000: 2012DJ14 (checked 477)
# ✅ 423/4000: 2023WY1 (checked 478)
# ✅ 424/4000: 2021UF3 (checked 479)
# ✅ 425/4000: 2011EO11 (checked 480)
# ✅ 426/4000: 2017UD43 (checked 481)
# ✅ 427/4000: 2017QP1 (checked 482)
# ✅ 426/4000: 2017UD43 (checked 481)
# ✅ 427/4000: 2017QP1 (checked 482)
# ✅ 428/4000: 2020OE3 (checked 483)
# ✅ 429/4000: 2013RZ53 (checked 484)
# ✅ 430/4000: 2024VT3 (checked 485)
# ✅ 431/4000: 2024OA2 (checked 486)
# ✅ 432/4000: 2015XM169 (checked 487)
# ✅ 433/4000: 2024TW5 (checked 488)
# ✅ 428/4000: 2020OE3 (checked 483)
# ✅ 429/4000: 2013RZ53 (checked 484)
# ✅ 430/4000: 2024VT3 (checked 485)
# ✅ 431/4000: 2024OA2 (checked 486)
# ✅ 432/4000: 2015XM169 (checked 487)
# ✅ 433/4000: 2024TW5 (checked 488)
# ❌ 2021KQ2: Missing data sources (checked 489)
# ✅ 434/4000: 2021VA6 (checked 490)
# ✅ 435/4000: 2005UH5 (checked 491)
# ✅ 436/4000: 2023HB4 (checked 492)
# ❌ 2021KQ2: Missing data sources (checked 489)
# ✅ 434/4000: 2021VA6 (checked 490)
# ✅ 435/4000: 2005UH5 (checked 491)
# ✅ 436/4000: 2023HB4 (checked 492)
# ✅ 437/4000: 2011AJ37 (checked 493)
# ✅ 438/4000: 2024TZ1 (checked 494)
# ✅ 439/4000: 2022UG2 (checked 495)
# ✅ 440/4000: 2005NQ1 (checked 496)
# ✅ 441/4000: 2006HS30 (checked 497)
# ✅ 437/4000: 2011AJ37 (checked 493)
# ✅ 438/4000: 2024TZ1 (checked 494)
# ✅ 439/4000: 2022UG2 (checked 495)
# ✅ 440/4000: 2005NQ1 (checked 496)
# ✅ 441/4000: 2006HS30 (checked 497)
# ✅ 442/4000: 2012SL50 (checked 498)
# ✅ 443/4000: 2010SD12 (checked 499)
# ✅ 444/4000: 2008DF5 (checked 500)
# ✅ 445/4000: 2020BH3 (checked 501)
# ❌ 2014QV363: Missing data sources (checked 502)
# ❌ 2024TG11: Missing data sources (checked 503)
# ❌ 2020PU2: Missing data sources (checked 504)
# ✅ 446/4000: 2025FD20 (checked 505)
# ✅ 442/4000: 2012SL50 (checked 498)
# ✅ 443/4000: 2010SD12 (checked 499)
# ✅ 444/4000: 2008DF5 (checked 500)
# ✅ 445/4000: 2020BH3 (checked 501)
# ❌ 2014QV363: Missing data sources (checked 502)
# ❌ 2024TG11: Missing data sources (checked 503)
# ❌ 2020PU2: Missing data sources (checked 504)
# ✅ 446/4000: 2025FD20 (checked 505)
# ✅ 447/4000: 2024RC13 (checked 506)
# ✅ 448/4000: 2023GX2 (checked 507)
# ✅ 449/4000: 2021XC6 (checked 508)
# ✅ 450/4000: 2022GG3 (checked 509)
# ✅ 451/4000: 2021BF1 (checked 510)
# ✅ 447/4000: 2024RC13 (checked 506)
# ✅ 448/4000: 2023GX2 (checked 507)
# ✅ 449/4000: 2021XC6 (checked 508)
# ✅ 450/4000: 2022GG3 (checked 509)
# ✅ 451/4000: 2021BF1 (checked 510)
# ✅ 452/4000: 2014TG35 (checked 511)
# ✅ 453/4000: 2016AF166 (checked 512)
# ✅ 454/4000: 2018GR11 (checked 513)
# ✅ 455/4000: 2019TM4 (checked 514)
# ✅ 456/4000: 2024XS2 (checked 515)
# ✅ 452/4000: 2014TG35 (checked 511)
# ✅ 453/4000: 2016AF166 (checked 512)
# ✅ 454/4000: 2018GR11 (checked 513)
# ✅ 455/4000: 2019TM4 (checked 514)
# ✅ 456/4000: 2024XS2 (checked 515)
# ❌ 2021UU3: Missing data sources (checked 516)
# ✅ 457/4000: 2019AS8 (checked 517)
# ✅ 458/4000: 2013JR7 (checked 518)
# ✅ 459/4000: 2014WR362 (checked 519)
# ✅ 460/4000: 2024JT3 (checked 520)
# ✅ 461/4000: 2023UK3 (checked 521)
# ❌ 2021UU3: Missing data sources (checked 516)
# ✅ 457/4000: 2019AS8 (checked 517)
# ✅ 458/4000: 2013JR7 (checked 518)
# ✅ 459/4000: 2014WR362 (checked 519)
# ✅ 460/4000: 2024JT3 (checked 520)
# ✅ 461/4000: 2023UK3 (checked 521)
# ✅ 462/4000: 2021XF1 (checked 522)
# ✅ 463/4000: 2017UN43 (checked 523)
# ✅ 464/4000: 2021WK4 (checked 524)
# ✅ 465/4000: 2022UQ13 (checked 525)
# ✅ 462/4000: 2021XF1 (checked 522)
# ✅ 463/4000: 2017UN43 (checked 523)
# ✅ 464/4000: 2021WK4 (checked 524)
# ✅ 465/4000: 2022UQ13 (checked 525)
# ✅ 466/4000: 2021LC3 (checked 526)
# ✅ 467/4000: 2019UJ1 (checked 527)
# ✅ 468/4000: 2018XG4 (checked 528)
# ✅ 469/4000: 2023XD15 (checked 529)
# ✅ 470/4000: 2021RU2 (checked 530)
# ✅ 471/4000: 2021AY6 (checked 531)
# ✅ 466/4000: 2021LC3 (checked 526)
# ✅ 467/4000: 2019UJ1 (checked 527)
# ✅ 468/4000: 2018XG4 (checked 528)
# ✅ 469/4000: 2023XD15 (checked 529)
# ✅ 470/4000: 2021RU2 (checked 530)
# ✅ 471/4000: 2021AY6 (checked 531)
# ❌ 2021RA5: Missing data sources (checked 532)
# ✅ 472/4000: 2020PU3 (checked 533)
# ✅ 473/4000: 2021TQ15 (checked 534)
# ❌ 2023QQ2: Missing data sources (checked 535)
# ❌ 2021RA5: Missing data sources (checked 532)
# ✅ 472/4000: 2020PU3 (checked 533)
# ✅ 473/4000: 2021TQ15 (checked 534)
# ❌ 2023QQ2: Missing data sources (checked 535)
# ✅ 474/4000: 2020SN5 (checked 536)
# ✅ 475/4000: 2015FT117 (checked 537)
# ✅ 476/4000: 2025BE1 (checked 538)
# ✅ 474/4000: 2020SN5 (checked 536)
# ✅ 475/4000: 2015FT117 (checked 537)
# ✅ 476/4000: 2025BE1 (checked 538)
# ✅ 477/4000: 2024PS3 (checked 539)
# ✅ 478/4000: 2023TX1 (checked 540)
# ✅ 479/4000: 2022YR5 (checked 541)
# ✅ 480/4000: 2020RF2 (checked 542)
# ✅ 481/4000: 2020XY6 (checked 543)
# ✅ 477/4000: 2024PS3 (checked 539)
# ✅ 478/4000: 2023TX1 (checked 540)
# ✅ 479/4000: 2022YR5 (checked 541)
# ✅ 480/4000: 2020RF2 (checked 542)
# ✅ 481/4000: 2020XY6 (checked 543)
# ✅ 482/4000: 2011LB19 (checked 544)
# ✅ 483/4000: 2023LL1 (checked 545)
# ✅ 482/4000: 2011LB19 (checked 544)
# ✅ 483/4000: 2023LL1 (checked 545)
# ✅ 484/4000: 2023RZ3 (checked 546)
# ✅ 485/4000: 2022AY6 (checked 547)
# ✅ 486/4000: 2025FH21 (checked 548)
# ✅ 487/4000: 2015KO122 (checked 549)
# ✅ 488/4000: 2024CW7 (checked 550)
# ✅ 489/4000: 2012UW158 (checked 551)
# ✅ 490/4000: 2022EO4 (checked 552)
# ✅ 484/4000: 2023RZ3 (checked 546)
# ✅ 485/4000: 2022AY6 (checked 547)
# ✅ 486/4000: 2025FH21 (checked 548)
# ✅ 487/4000: 2015KO122 (checked 549)
# ✅ 488/4000: 2024CW7 (checked 550)
# ✅ 489/4000: 2012UW158 (checked 551)
# ✅ 490/4000: 2022EO4 (checked 552)
# ✅ 491/4000: 2025FC15 (checked 553)
# ✅ 492/4000: 2016NK33 (checked 554)
# ❌ 2024JX14: Missing data sources (checked 555)
# ✅ 493/4000: 2011YC40 (checked 556)
# ✅ 491/4000: 2025FC15 (checked 553)
# ✅ 492/4000: 2016NK33 (checked 554)
# ❌ 2024JX14: Missing data sources (checked 555)
# ✅ 493/4000: 2011YC40 (checked 556)
# ✅ 494/4000: 2019MC3 (checked 557)
# ✅ 495/4000: 2021VY7 (checked 558)
# ✅ 496/4000: 2019SU6 (checked 559)
# ✅ 497/4000: 2020UN4 (checked 560)
# ✅ 498/4000: 2022BP1 (checked 561)
# ✅ 499/4000: 2025FO18 (checked 562)
# ✅ 500/4000: 2020BZ13 (checked 563)
# ✅ 494/4000: 2019MC3 (checked 557)
# ✅ 495/4000: 2021VY7 (checked 558)
# ✅ 496/4000: 2019SU6 (checked 559)
# ✅ 497/4000: 2020UN4 (checked 560)
# ✅ 498/4000: 2022BP1 (checked 561)
# ✅ 499/4000: 2025FO18 (checked 562)
# ✅ 500/4000: 2020BZ13 (checked 563)
# ✅ 501/4000: 2024XT16 (checked 564)
# ✅ 502/4000: 2021RY7 (checked 565)
# ✅ 503/4000: 2020TW1 (checked 566)
# ✅ 501/4000: 2024XT16 (checked 564)
# ✅ 502/4000: 2021RY7 (checked 565)
# ✅ 503/4000: 2020TW1 (checked 566)
# ✅ 504/4000: 2010KV39 (checked 567)
# ✅ 505/4000: 2014OQ392 (checked 568)
# ✅ 506/4000: 2024YR6 (checked 569)
# ✅ 507/4000: 2014HW197 (checked 570)
# ✅ 508/4000: 2018TE2 (checked 571)
# ✅ 509/4000: 2015HQ171 (checked 572)
# ❌ 2021XM6: Missing data sources (checked 573)
# ✅ 510/4000: 2016FL14 (checked 574)
# ✅ 504/4000: 2010KV39 (checked 567)
# ✅ 505/4000: 2014OQ392 (checked 568)
# ✅ 506/4000: 2024YR6 (checked 569)
# ✅ 507/4000: 2014HW197 (checked 570)
# ✅ 508/4000: 2018TE2 (checked 571)
# ✅ 509/4000: 2015HQ171 (checked 572)
# ❌ 2021XM6: Missing data sources (checked 573)
# ✅ 510/4000: 2016FL14 (checked 574)
# ✅ 511/4000: 2021BO1 (checked 575)
# ✅ 512/4000: 2023HC1 (checked 576)
# ✅ 513/4000: 2021RL7 (checked 577)
# ✅ 511/4000: 2021BO1 (checked 575)
# ✅ 512/4000: 2023HC1 (checked 576)
# ✅ 513/4000: 2021RL7 (checked 577)
# ✅ 514/4000: 2020OH3 (checked 578)
# ✅ 515/4000: 2021XX1 (checked 579)
# ✅ 516/4000: 2020QQ2 (checked 580)
# ✅ 517/4000: 2014GR1 (checked 581)
# ✅ 518/4000: 2023UL3 (checked 582)
# ❌ 2018PC9: Missing data sources (checked 583)
# ✅ 519/4000: 2023BG7 (checked 584)
# ✅ 520/4000: 2023FU6 (checked 585)
# ❌ 2022JO1: Missing data sources (checked 586)
# ❌ 2024TW9: Missing data sources (checked 587)
# ✅ 521/4000: 2017BR5 (checked 588)
# ✅ 514/4000: 2020OH3 (checked 578)
# ✅ 515/4000: 2021XX1 (checked 579)
# ✅ 516/4000: 2020QQ2 (checked 580)
# ✅ 517/4000: 2014GR1 (checked 581)
# ✅ 518/4000: 2023UL3 (checked 582)
# ❌ 2018PC9: Missing data sources (checked 583)
# ✅ 519/4000: 2023BG7 (checked 584)
# ✅ 520/4000: 2023FU6 (checked 585)
# ❌ 2022JO1: Missing data sources (checked 586)
# ❌ 2024TW9: Missing data sources (checked 587)
# ✅ 521/4000: 2017BR5 (checked 588)
# ✅ 522/4000: 2023TY2 (checked 589)
# ❌ 2015AO43: Missing data sources (checked 590)
# ❌ 2017UZ5: Missing data sources (checked 591)
# ✅ 523/4000: 2025LD1 (checked 592)
# ✅ 522/4000: 2023TY2 (checked 589)
# ❌ 2015AO43: Missing data sources (checked 590)
# ❌ 2017UZ5: Missing data sources (checked 591)
# ✅ 523/4000: 2025LD1 (checked 592)
# ✅ 524/4000: 2024TK5 (checked 593)
# ✅ 525/4000: 2012TG79 (checked 594)
# ✅ 526/4000: 2022QZ36 (checked 595)
# ✅ 527/4000: 2025DF25 (checked 596)
# ✅ 528/4000: 2024UJ1 (checked 597)
# ✅ 524/4000: 2024TK5 (checked 593)
# ✅ 525/4000: 2012TG79 (checked 594)
# ✅ 526/4000: 2022QZ36 (checked 595)
# ✅ 527/4000: 2025DF25 (checked 596)
# ✅ 528/4000: 2024UJ1 (checked 597)
# ✅ 529/4000: 2019QH2 (checked 598)
# ✅ 530/4000: 2009WP6 (checked 599)
# ✅ 531/4000: 2024XX4 (checked 600)
# ✅ 532/4000: 2018KV2 (checked 601)
# ✅ 533/4000: 2010RE31 (checked 602)
# ❌ 2017SK33: Missing data sources (checked 603)
# ✅ 529/4000: 2019QH2 (checked 598)
# ✅ 530/4000: 2009WP6 (checked 599)
# ✅ 531/4000: 2024XX4 (checked 600)
# ✅ 532/4000: 2018KV2 (checked 601)
# ✅ 533/4000: 2010RE31 (checked 602)
# ❌ 2017SK33: Missing data sources (checked 603)
# ✅ 534/4000: 2012KB6 (checked 604)
# ✅ 535/4000: 2017MF3 (checked 605)
# ❌ 2018MB5: Missing data sources (checked 606)
# ✅ 536/4000: 2019RS1 (checked 607)
# ✅ 537/4000: 2024WX4 (checked 608)
# ✅ 538/4000: 2023HK6 (checked 609)
# ✅ 539/4000: 2016EL1 (checked 610)
# ✅ 534/4000: 2012KB6 (checked 604)
# ✅ 535/4000: 2017MF3 (checked 605)
# ❌ 2018MB5: Missing data sources (checked 606)
# ✅ 536/4000: 2019RS1 (checked 607)
# ✅ 537/4000: 2024WX4 (checked 608)
# ✅ 538/4000: 2023HK6 (checked 609)
# ✅ 539/4000: 2016EL1 (checked 610)
# ✅ 540/4000: 2025FN18 (checked 611)
# ✅ 541/4000: 2020AL2 (checked 612)
# ❌ 2010RO80: Missing data sources (checked 613)
# ❌ 2023TW1: Missing data sources (checked 614)
# ✅ 542/4000: 2022DL1 (checked 615)
# ✅ 543/4000: 2015KZ121 (checked 616)
# ❌ 2020RC8: Missing data sources (checked 617)
# ✅ 540/4000: 2025FN18 (checked 611)
# ✅ 541/4000: 2020AL2 (checked 612)
# ❌ 2010RO80: Missing data sources (checked 613)
# ❌ 2023TW1: Missing data sources (checked 614)
# ✅ 542/4000: 2022DL1 (checked 615)
# ✅ 543/4000: 2015KZ121 (checked 616)
# ❌ 2020RC8: Missing data sources (checked 617)
# ✅ 544/4000: 2009WJ106 (checked 618)
# ❌ 2018FG1: Missing data sources (checked 619)
# ✅ 545/4000: 2024VO2 (checked 620)
# ✅ 546/4000: 2021XE2 (checked 621)
# ✅ 547/4000: 2010VZ201 (checked 622)
# ✅ 548/4000: 2017QZ34 (checked 623)
# ✅ 544/4000: 2009WJ106 (checked 618)
# ❌ 2018FG1: Missing data sources (checked 619)
# ✅ 545/4000: 2024VO2 (checked 620)
# ✅ 546/4000: 2021XE2 (checked 621)
# ✅ 547/4000: 2010VZ201 (checked 622)
# ✅ 548/4000: 2017QZ34 (checked 623)
# ❌ 2021PV1: Missing data sources (checked 624)
# ✅ 549/4000: 2023TO16 (checked 625)
# ❌ 2022EJ4: Missing data sources (checked 626)
# ✅ 550/4000: 2020SJ6 (checked 627)
# ❌ 2020KG5: Missing data sources (checked 628)
# ✅ 551/4000: 2005QK76 (checked 629)
# ✅ 552/4000: 2024XH4 (checked 630)
# ✅ 553/4000: 2015KE158 (checked 631)
# ❌ 2021PV1: Missing data sources (checked 624)
# ✅ 549/4000: 2023TO16 (checked 625)
# ❌ 2022EJ4: Missing data sources (checked 626)
# ✅ 550/4000: 2020SJ6 (checked 627)
# ❌ 2020KG5: Missing data sources (checked 628)
# ✅ 551/4000: 2005QK76 (checked 629)
# ✅ 552/4000: 2024XH4 (checked 630)
# ✅ 553/4000: 2015KE158 (checked 631)
# ❌ 2014UB58: Missing data sources (checked 632)
# ❌ 2022WD8: Missing data sources (checked 633)
# ❌ 2019UD10: Missing data sources (checked 634)
# ❌ 2025BW5: Missing data sources (checked 635)
# ❌ 2014UB58: Missing data sources (checked 632)
# ❌ 2022WD8: Missing data sources (checked 633)
# ❌ 2019UD10: Missing data sources (checked 634)
# ❌ 2025BW5: Missing data sources (checked 635)
# ✅ 554/4000: 2021GC8 (checked 636)
# ✅ 555/4000: 2025FC22 (checked 637)
# ✅ 556/4000: 2017TS6 (checked 638)
# ✅ 557/4000: 2023OU3 (checked 639)
# ❌ 2022KZ1: Missing data sources (checked 640)
# ✅ 558/4000: 2019RZ3 (checked 641)
# ❌ 2020PW1: Missing data sources (checked 642)
# ✅ 554/4000: 2021GC8 (checked 636)
# ✅ 555/4000: 2025FC22 (checked 637)
# ✅ 556/4000: 2017TS6 (checked 638)
# ✅ 557/4000: 2023OU3 (checked 639)
# ❌ 2022KZ1: Missing data sources (checked 640)
# ✅ 558/4000: 2019RZ3 (checked 641)
# ❌ 2020PW1: Missing data sources (checked 642)
# ✅ 559/4000: 2016RY19 (checked 643)
# ✅ 560/4000: 2016PR66 (checked 644)
# ✅ 561/4000: 2022RT2 (checked 645)
# ✅ 562/4000: 2023SJ4 (checked 646)
# ❌ 2019LR1: Missing data sources (checked 647)
# ❌ 2019FF1: Missing data sources (checked 648)
# ✅ 559/4000: 2016RY19 (checked 643)
# ✅ 560/4000: 2016PR66 (checked 644)
# ✅ 561/4000: 2022RT2 (checked 645)
# ✅ 562/4000: 2023SJ4 (checked 646)
# ❌ 2019LR1: Missing data sources (checked 647)
# ❌ 2019FF1: Missing data sources (checked 648)
# ❌ 2017FM1: Missing data sources (checked 649)
# ✅ 563/4000: 2020RG10 (checked 650)
# ❌ 2023CU1: Missing data sources (checked 651)
# ✅ 564/4000: 2025KE4 (checked 652)
# ✅ 565/4000: 2013BQ27 (checked 653)
# ❌ 2017FM1: Missing data sources (checked 649)
# ✅ 563/4000: 2020RG10 (checked 650)
# ❌ 2023CU1: Missing data sources (checked 651)
# ✅ 564/4000: 2025KE4 (checked 652)
# ✅ 565/4000: 2013BQ27 (checked 653)
# ❌ 2023UD4: Missing data sources (checked 654)
# ✅ 566/4000: 2014HD196 (checked 655)
# ✅ 567/4000: 2004DA53 (checked 656)
# ✅ 568/4000: 2024TL2 (checked 657)
# ✅ 569/4000: 2025HO1 (checked 658)
# ❌ 2010TN167: Missing data sources (checked 659)
# ✅ 570/4000: 2019WB5 (checked 660)
# ❌ 2016JA29: Missing data sources (checked 661)
# ❌ 2019GL23: Missing data sources (checked 662)
# ❌ 2023UD4: Missing data sources (checked 654)
# ✅ 566/4000: 2014HD196 (checked 655)
# ...
# Skipping night 1 (2020-02-14) due to insufficient observations: 1
# Skipping night 2 (2020-02-15) due to insufficient observations: 1
# Skipping night 3 (2019-10-22) due to insufficient observations: 1
# Skipping night 3 (2019-10-22) due to insufficient observations: 1
# Skipping night 3 (2010-12-16) due to insufficient observations: 1
# Skipping night 3 (2010-12-16) due to insufficient observations: 1
# Skipping night 3 (2019-10-02) due to insufficient observations: 1
# Skipping night 3 (2019-10-02) due to insufficient observations: 1
# REJECTED: Missing data for 2023DJ1
# REJECTED: Missing data for 2023DJ1
# REJECTED: Missing data for 2016DY30
# REJECTED: Missing data for 2017WH13
# REJECTED: Missing data for 2016DY30
# REJECTED: Missing data for 2017WH13
# REJECTED: Missing data for 2017SO12
# REJECTED: Missing data for 2017SO12
# REJECTED: Missing data for 2024JD2
# REJECTED: Missing data for 2024JD2
# REJECTED: Missing data for 2024LZ4
# REJECTED: Missing data for 2024LZ4
# REJECTED: Missing data for 2020QQ4
# REJECTED: Missing data for 2020QQ4
# REJECTED: Missing data for 2020HY5
# REJECTED: Missing data for 2020HY5
# Skipping night 1 (2020-10-21) due to insufficient observations: 1
# Skipping night 2 (2020-10-22) due to insufficient observations: 1
# Skipping night 1 (2020-10-21) due to insufficient observations: 1
# Skipping night 2 (2020-10-22) due to insufficient observations: 1
# REJECTED: Missing data for 2012KT42
# REJECTED: Missing data for 2012KT42
# REJECTED: Missing data for 2024QM1
# REJECTED: Missing data for 2024QM1
# REJECTED: Missing data for 2023DR1
# REJECTED: Missing data for 2023DR1
# Skipping night 3 (2019-01-13) due to insufficient observations: 1
# Skipping night 3 (2019-01-13) due to insufficient observations: 1
# REJECTED: Missing data for 2019QD1
# REJECTED: Missing data for 2019QD1
# Skipping night 2 (2023-01-30) due to insufficient observations: 1
# Skipping night 2 (2023-01-30) due to insufficient observations: 1
# Skipping night 1 (2017-01-24) due to insufficient observations: 1
# Skipping night 1 (2017-01-24) due to insufficient observations: 1
# REJECTED: Missing data for 2024TZ1
# REJECTED: Missing data for 2024TZ1
# REJECTED: Missing data for 2017UN43
# REJECTED: Missing data for 2017UN43
# REJECTED: Missing data for 2025GA1
# REJECTED: Missing data for 2025GA1
# REJECTED: Missing data for 2021RY7
# REJECTED: Missing data for 2021RY7
# REJECTED: Missing data for 2015KZ121
# REJECTED: Missing data for 2015KZ121
# Skipping night 1 (2025-06-13) due to insufficient observations: 1
# Skipping night 1 (2025-06-13) due to insufficient observations: 1
# REJECTED: Missing data for 2024PC4
# REJECTED: Missing data for 2024PC4
# Skipping night 1 (2020-10-14) due to insufficient observations: 1
# Skipping night 1 (2020-10-14) due to insufficient observations: 1
# Skipping night 1 (2019-01-03) due to insufficient observations: 1
# Skipping night 1 (2019-01-03) due to insufficient observations: 1
# Skipping night 2 (2010-10-07) due to insufficient observations: 1
# Skipping night 2 (2010-10-07) due to insufficient observations: 1
# Skipping night 1 (2023-10-09) due to insufficient observations: 1
# Skipping night 1 (2023-10-09) due to insufficient observations: 1
# Skipping night 1 (2022-10-23) due to insufficient observations: 1
# Skipping night 1 (2022-10-23) due to insufficient observations: 1
# Skipping night 1 (2014-10-23) due to insufficient observations: 1
# Skipping night 1 (2014-10-23) due to insufficient observations: 1
# REJECTED: Missing data for 2021VY7
# REJECTED: Missing data for 2021VY7
# Skipping night 3 (2024-02-03) due to insufficient observations: 1
# Skipping night 4 (2024-02-04) due to insufficient observations: 1
# Skipping night 3 (2024-02-03) due to insufficient observations: 1
# Skipping night 4 (2024-02-04) due to insufficient observations: 1
# REJECTED: Missing data for 2023KJ2
# REJECTED: Missing data for 2023KJ2
# REJECTED: Missing data for 2024RW21
# REJECTED: Missing data for 2024RW21
# REJECTED: Missing data for 2021TF1
# REJECTED: Missing data for 2017BJ30
# REJECTED: Missing data for 2021TF1
# REJECTED: Missing data for 2017BJ30
# REJECTED: Missing data for 2014HE5
# REJECTED: Missing data for 2014HE5
# Skipping night 4 (2018-09-09) due to insufficient observations: 1
# Skipping night 4 (2018-09-09) due to insufficient observations: 1
# REJECTED: Missing data for 2024PZ3
# REJECTED: Missing data for 2024PZ3
# REJECTED: Missing data for 2020QY2
# REJECTED: Missing data for 2020QY2
# Skipping night 1 (2018-10-04) due to insufficient observations: 1
# Skipping night 1 (2018-10-04) due to insufficient observations: 1
# Skipping night 2 (2024-03-12) due to insufficient observations: 1
# Skipping night 2 (2024-03-12) due to insufficient observations: 1
# Skipping night 3 (2025-01-26) due to insufficient observations: 1
# Skipping night 3 (2025-01-26) due to insufficient observations: 1
# Skipping night 3 (2021-03-09) due to insufficient observations: 1
# Skipping night 3 (2021-03-09) due to insufficient observations: 1
# Skipping night 1 (2010-02-18) due to insufficient observations: 1
# Skipping night 3 (2010-02-20) due to insufficient observations: 1
# Skipping night 1 (2010-02-18) due to insufficient observations: 1
# Skipping night 3 (2010-02-20) due to insufficient observations: 1
# Skipping night 3 (2023-09-16) due to insufficient observations: 1
# Skipping night 3 (2023-09-16) due to insufficient observations: 1
# Skipping night 1 (2020-08-15) due to insufficient observations: 1
# Skipping night 1 (2020-08-15) due to insufficient observations: 1
# REJECTED: Missing data for 2024RR8
# REJECTED: Missing data for 2024RR8
# REJECTED: Missing data for 2021GU6
# REJECTED: Missing data for 2021GU6
# REJECTED: Missing data for 2019YY4
# REJECTED: Missing data for 2019YY4
# REJECTED: Missing data for 2022UA15
# REJECTED: Missing data for 2022UA15
# REJECTED: Missing data for 2024BB8
# REJECTED: Missing data for 2024BB8
# REJECTED: Missing data for 2005ND63
# REJECTED: Missing data for 2005ND63
# REJECTED: Missing data for 2022BD5
# REJECTED: Missing data for 2022BD5
# REJECTED: Missing data for 2015HD183
# REJECTED: Missing data for 2015HD183
# Skipping night 3 (2019-01-10) due to insufficient observations: 1
# Skipping night 4 (2019-01-11) due to insufficient observations: 1
# Skipping night 3 (2019-01-10) due to insufficient observations: 1
# Skipping night 4 (2019-01-11) due to insufficient observations: 1
# REJECTED: Missing data for 2021GQ4
# REJECTED: Missing data for 2021GQ4
# REJECTED: Missing data for 2022YW2
# REJECTED: Missing data for 2022YW2
# REJECTED: Missing data for 2025DT14
# REJECTED: Missing data for 2025DT14
# Skipping night 3 (2016-08-10) due to insufficient observations: 1
# Skipping night 3 (2016-08-10) due to insufficient observations: 1
# Skipping night 3 (2012-03-26) due to insufficient observations: 1
# Skipping night 4 (2012-03-27) due to insufficient observations: 1
# Skipping night 3 (2012-03-26) due to insufficient observations: 1
# Skipping night 4 (2012-03-27) due to insufficient observations: 1
# Skipping night 1 (2020-05-14) due to insufficient observations: 1
# Skipping night 1 (2020-05-14) due to insufficient observations: 1
# REJECTED: Missing data for 2022KL1
# REJECTED: Missing data for 2022KL1
# Skipping night 1 (2018-01-22) due to insufficient observations: 1
# Skipping night 1 (2018-01-22) due to insufficient observations: 1
# Skipping night 3 (2022-04-11) due to insufficient observations: 1
# Skipping night 3 (2022-04-11) due to insufficient observations: 1
# Skipping night 1 (2023-01-21) due to insufficient observations: 1
# Skipping night 1 (2023-01-21) due to insufficient observations: 1
# Skipping night 1 (2024-08-27) due to insufficient observations: 1
# Skipping night 1 (2024-08-27) due to insufficient observations: 1
# Skipping night 1 (2018-09-15) due to insufficient observations: 1
# Skipping night 1 (2018-09-15) due to insufficient observations: 1
# Skipping night 2 (2019-10-01) due to insufficient observations: 1
# Skipping night 2 (2019-10-01) due to insufficient observations: 1
# Skipping night 1 (2023-12-03) due to insufficient observations: 1
# Skipping night 1 (2023-12-03) due to insufficient observations: 1
# Skipping night 1 (2019-10-23) due to insufficient observations: 1
# Skipping night 1 (2019-10-23) due to insufficient observations: 1
# Skipping night 1 (2011-12-23) due to insufficient observations: 1
# Skipping night 1 (2011-12-23) due to insufficient observations: 1
# Skipping night 3 (2021-11-12) due to insufficient observations: 1
# Skipping night 3 (2011-03-08) due to insufficient observations: 1
# Skipping night 3 (2021-11-12) due to insufficient observations: 1
# Skipping night 3 (2011-03-08) due to insufficient observations: 1
# Skipping night 1 (2020-01-23) due to insufficient observations: 1
# Skipping night 1 (2020-01-23) due to insufficient observations: 1
# REJECTED: Missing data for 2018PD20
# REJECTED: Missing data for 2018PD20
# REJECTED: Missing data for 2017QQ17
# REJECTED: Missing data for 2017QQ17
# REJECTED: Missing data for 2024YB5
# REJECTED: Missing data for 2024YB5
# REJECTED: Missing data for 2021RA8
# REJECTED: Missing data for 2021RA8
# REJECTED: Missing data for 2015DT198
# REJECTED: Missing data for 2015DT198
# REJECTED: Missing data for 2021BL2
# REJECTED: Missing data for 2021BL2
# REJECTED: Missing data for 2019CC2
# REJECTED: Missing data for 2019CC2
# REJECTED: Missing data for 2019UM2
# REJECTED: Missing data for 2019UM2
# REJECTED: Missing data for 2021WB3
# REJECTED: Missing data for 2021WB3
# REJECTED: Missing data for 2023GQ1
# REJECTED: Missing data for 2023GQ1
# REJECTED: Missing data for 2009HG21
# REJECTED: Missing data for 2009HG21
# REJECTED: Missing data for 2021UW5
# REJECTED: Missing data for 2021UW5
# REJECTED: Missing data for 2018TH3
# REJECTED: Missing data for 2018TH3
# Skipping night 3 (2019-09-07) due to insufficient observations: 1
# Skipping night 3 (2019-09-07) due to insufficient observations: 1
# REJECTED: Missing data for 2023XO10
# REJECTED: Missing data for 2023XO10
# Skipping night 2 (1993-05-22) due to insufficient observations: 1
# Skipping night 2 (1993-05-22) due to insufficient observations: 1
# Skipping night 3 (2016-01-04) due to insufficient observations: 1
# REJECTED: Missing data for 2022UB5
# Skipping night 3 (2016-01-04) due to insufficient observations: 1
# REJECTED: Missing data for 2022UB5
# Skipping night 1 (2024-12-02) due to insufficient observations: 1
# Skipping night 1 (2024-12-02) due to insufficient observations: 1
# REJECTED: Missing data for 2014XG32
# REJECTED: Missing data for 2014XG32
# Skipping night 3 (2010-06-25) due to insufficient observations: 1
# Skipping night 3 (2010-06-25) due to insufficient observations: 1
# Skipping night 4 (2019-04-15) due to insufficient observations: 1
# Skipping night 4 (2019-04-15) due to insufficient observations: 1
# REJECTED: Missing data for 2021TR12
# REJECTED: Missing data for 2024UB11
# REJECTED: Missing data for 2021TF10
# REJECTED: Missing data for 2021TR12
# REJECTED: Missing data for 2024UB11
# REJECTED: Missing data for 2021TF10
# REJECTED: Missing data for 2019OC3
# REJECTED: Missing data for 2019OC3
# REJECTED: Missing data for 2023UQ7
# REJECTED: Missing data for 2023UQ7
# Skipping night 3 (2015-01-23) due to insufficient observations: 1
# Skipping night 3 (2015-01-23) due to insufficient observations: 1
# Skipping night 1 (2010-11-08) due to insufficient observations: 1
# Skipping night 1 (2010-11-08) due to insufficient observations: 1
# Skipping night 2 (2012-12-13) due to insufficient observations: 1
# Skipping night 2 (2012-12-13) due to insufficient observations: 1
# Skipping night 3 (2020-02-19) due to insufficient observations: 1
# Skipping night 3 (2020-02-19) due to insufficient observations: 1
# REJECTED: Missing data for 2014JU79
# REJECTED: Missing data for 2014JU79
# Skipping night 3 (2022-02-08) due to insufficient observations: 1
# Skipping night 3 (2022-02-08) due to insufficient observations: 1
# REJECTED: Missing data for 2016EE27
# REJECTED: Missing data for 2016EE27
# REJECTED: Missing data for 2020UY2
# REJECTED: Missing data for 2020UY2
# Skipping night 2 (2009-08-16) due to insufficient observations: 1
# Skipping night 2 (2009-08-16) due to insufficient observations: 1
# Skipping night 2 (2020-03-23) due to insufficient observations: 1
# Skipping night 2 (2020-03-23) due to insufficient observations: 1
# REJECTED: Missing data for 2010RW30
# REJECTED: Missing data for 2010RW30
# Skipping night 2 (2021-09-01) due to insufficient observations: 1
# Skipping night 2 (2021-09-01) due to insufficient observations: 1
# Skipping night 3 (2010-03-03) due to insufficient observations: 1
# Skipping night 3 (2010-03-03) due to insufficient observations: 1
# REJECTED: Missing data for 2025JV1
# REJECTED: Missing data for 2025JV1
# Skipping night 1 (2023-03-25) due to insufficient observations: 1
# Skipping night 1 (2023-03-25) due to insufficient observations: 1
# REJECTED: Missing data for 2024CA2
# REJECTED: Missing data for 2024CA2
# Skipping night 3 (2012-11-16) due to insufficient observations: 1
# Skipping night 3 (2012-11-16) due to insufficient observations: 1
# REJECTED: Missing data for 2018FK5
# REJECTED: Missing data for 2018FK5
# Skipping night 3 (2022-10-29) due to insufficient observations: 1
# Skipping night 3 (2022-10-29) due to insufficient observations: 1
# REJECTED: Missing data for 2004UH1
# REJECTED: Missing data for 2004UH1
# REJECTED: Missing data for 2024AY2
# REJECTED: Missing data for 2024AY2
# REJECTED: Missing data for 2020SK6
# REJECTED: Missing data for 2020SK6
# REJECTED: Missing data for 2023MO3
# REJECTED: Missing data for 2023MO3
# REJECTED: Missing data for 2025DJ22
# REJECTED: Missing data for 2025DJ22
# Skipping night 4 (2014-10-29) due to insufficient observations: 1
# Skipping night 4 (2014-10-29) due to insufficient observations: 1
# REJECTED: Missing data for 2012XG133
# REJECTED: Missing data for 2012XG133
# REJECTED: Missing data for 2024SH2
# REJECTED: Missing data for 2024SH2
# REJECTED: Missing data for 2004FY15
# REJECTED: Missing data for 2004FY15
# REJECTED: Missing data for 2013GT66
# REJECTED: Missing data for 2023UG3
# REJECTED: Missing data for 2013GT66
# REJECTED: Missing data for 2023UG3
# REJECTED: Missing data for 2020RD8
# REJECTED: Missing data for 2020RD8
# REJECTED: Missing data for 2021UL6
# REJECTED: Missing data for 2021UL6
# REJECTED: Missing data for 2024PR5
# REJECTED: Missing data for 2024PR5
# REJECTED: Missing data for 2011AY22
# REJECTED: Missing data for 2011AY22
# REJECTED: Missing data for 2021RF15
# REJECTED: Missing data for 2021RF15
# REJECTED: Missing data for 2021UP7
# REJECTED: Missing data for 2021UP7
# REJECTED: Missing data for 2009DS43
# REJECTED: Missing data for 2009DS43
# Skipping night 1 (2014-04-23) due to insufficient observations: 1
# Skipping night 1 (2014-04-23) due to insufficient observations: 1
#
# 💾 Creating final DataFrame and saving to CSV...
#
# 📊 PROCESSING SUMMARY:
#    🎯 Target NEOs: 4000
#    ✅ Successfully processed: 2751
#    ❌ Rejected: 89
#    📊 Total data rows: 7498
#    🎯 Success rate: 96.9%
#
# 📋 Final dataset structure:
#    Basic fields: 7
#    Keplerian elements: 6 (a_kep, e, i, Omega, omega, M)
#    Equinoctial elements: 6 (a_equ, h, k, p, q, lambda)
#    Total columns: 19
#    Note: Separate semi-major axes: a_kep (Keplerian) and a_equ (Equinoctial)
#
# 🎉 SUCCESS! Pipeline complete.
# Dataset saved to: /home/FGeroni/Università/PhD/Code/NN_CelestialMechanics/PINN_DiffCorrections/DataSet_NEO_VSA.csv
# 📋 Columns: ['object', 'night', 't_fit', 'alpha', 'delta', 'alpha_dot', 'delta_dot', 'a_kep', 'e', 'i', 'Omega', 'omega', 'M', 'a_equ', 'h', 'k', 'p', 'q', 'lambda']
#
# 💾 Creating final DataFrame and saving to CSV...
#
# 📊 PROCESSING SUMMARY:
#    🎯 Target NEOs: 4000
#    ✅ Successfully processed: 2751
#    ❌ Rejected: 89
#    📊 Total data rows: 7498
#    🎯 Success rate: 96.9%
#
# 📋 Final dataset structure:
#    Basic fields: 7
#    Keplerian elements: 6 (a_kep, e, i, Omega, omega, M)
#    Equinoctial elements: 6 (a_equ, h, k, p, q, lambda)
#    Total columns: 19
#    Note: Separate semi-major axes: a_kep (Keplerian) and a_equ (Equinoctial)
#
# 🎉 SUCCESS! Pipeline complete.
# Dataset saved to: /home/FGeroni/Università/PhD/Code/NN_CelestialMechanics/PINN_DiffCorrections/DataSet_NEO_VSA.csv
# 📋 Columns: ['object', 'night', 't_fit', 'alpha', 'delta', 'alpha_dot', 'delta_dot', 'a_kep', 'e', 'i', 'Omega', 'omega', 'M', 'a_equ', 'h', 'k', 'p', 'q', 'lambda']
