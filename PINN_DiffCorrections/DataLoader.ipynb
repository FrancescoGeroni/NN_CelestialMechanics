# %% [markdown]
# # NEO Data Fetching and Processing Pipeline
#
# This notebook contains a production-ready pipeline to fetch, parse, validate and process data for Near-Earth Objects (NEOs) from the [NeoDyS-2](https://newton.spacedys.com/neodys/) service.
#
# The pipeline is organized into three main sections:
# 1.  **Configuration & Imports:** Sets the number of objects to process (`N_OBJECTS`) and imports all necessary libraries.
# 2.  **Helper Functions:** Contains all the functions for fetching, parsing, and processing the data.
# 3.  **Execution Pipeline:** Runs the main logic to fetch the object list, verify data, process the objects, and export the final dataset.
#
# The final output is a single CSV file named `DataSet_NEO_VSA.csv` containing the processed data for the specified number of objects.

# %%
# --- Imports ---
import requests
import pandas as pd
import numpy as np
import re
import random
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
from astropy.time import Time
import re
from numpy.polynomial.polyutils import RankWarning
import warnings
warnings.filterwarnings("ignore", category=RankWarning)

# --- Configuration ---
N_OBJECTS = 9000 # Number of objects to process
RANDOM_SAMPLING = True # Use random sampling instead of first N_OBJECTS
RANDOM_SEED = 42 # Random seed for reproducible results (set to None for true randomness)

# t0 = 60800.0 #[MJD] Initial time for the database, according to NeoDys-2 website

# NeoDys-2 query url for the databaset extraction
page_url = "https://newton.spacedys.com/neodys/index.php?pc=3.2.1&pc0=3.2&lra=&ura=&lde=&ude=&lvm=&uvm=&lel=&uel=&lph=&uph=&lgl=&ugl=&ldfe=&udfe=&ldfs=&udfs=&lmo=&umo=&lspu=&uspu=&ldu=&udu=&sb=12&lal=1&ual=8"

# %%
def parse_rwo(rwo_content):
    """Parse RWO content from NeoDyS-2 format using dynamic field detection for robustness."""
    nights_data = {}
    if not rwo_content: 
        return nights_data

    lines = rwo_content.split('\n')
    for idx, line in enumerate(lines):
        # Skip header and empty lines
        if (line.startswith('!') or not line.strip() or 
            line.startswith('version') or line.startswith('errmod') or 
            line.startswith('RMS') or line.startswith('END_OF_HEADER')):
            continue
        parts = line.split()
        # Find year (4-digit number), month (1-2 digit), day_frac (float)
        year_idx, month_idx, day_frac_idx = None, None, None
        for i, val in enumerate(parts):
            if year_idx is None and re.match(r'^\d{4}$', val):
                year_idx = i
                # Try to get month and day_frac right after year
                if i+2 < len(parts):
                    month_idx = i+1
                    day_frac_idx = i+2
                break
        if year_idx is None or month_idx is None or day_frac_idx is None:
            continue
        year_val = parts[year_idx]
        month_val = parts[month_idx]
        day_frac_val = parts[day_frac_idx]
        # Check if year and month are integers and day_frac is float
        try:
            year = int(year_val) if year_val is not None and year_val.isdigit() else None
            month = int(month_val) if month_val is not None and month_val.isdigit() else None
            day_frac = float(day_frac_val) if day_frac_val is not None else None
        except Exception as e:
            print(f"DEBUG: Line {idx+1} invalid date fields: year={year_val}, month={month_val}, day_frac={day_frac_val} | {e}")
            continue
        if year is None or month is None or day_frac is None:
            print(f"DEBUG: Line {idx+1} missing or invalid date fields: year={year_val}, month={month_val}, day_frac={day_frac_val}")
            continue

        # Dynamically find RA and Dec indices: RA is 3 consecutive fields after day_frac (hours, min, sec), Dec is 3 consecutive fields after RA (deg, min, sec)
        ra_start = day_frac_idx + 2
        dec_start = None
        # Find RA indices (should be float/int values)
        if ra_start + 2 < len(parts):
            ra_h_idx, ra_m_idx, ra_s_idx = ra_start, ra_start+1, ra_start+2
        else:
            continue
        # Find Dec indices: look for first value after RA that matches degree pattern (+/-dd or dd)
        for j in range(ra_s_idx+1, len(parts)-2):
            if re.match(r'^[+-]?\d+$', parts[j]):
                dec_start = j
                break
        if dec_start is not None and dec_start+2 < len(parts):
            dec_d_idx, dec_m_idx, dec_s_idx = dec_start, dec_start+1, dec_start+2
        else:
            continue

        try:
            day_int = int(day_frac)
            frac = day_frac - day_int
            total_seconds = frac * 24 * 3600
            hours = int(total_seconds // 3600)
            minutes = int((total_seconds % 3600) // 60)
            seconds = int(total_seconds % 60)

            ra_h = float(parts[ra_h_idx]) if parts[ra_h_idx] is not None else 0.0
            ra_m = float(parts[ra_m_idx]) if parts[ra_m_idx] is not None else 0.0
            ra_s = float(parts[ra_s_idx]) if parts[ra_s_idx] is not None else 0.0
            alpha = np.deg2rad(15.0 * (ra_h + ra_m / 60.0 + ra_s / 3600.0))

            dec_d = float(parts[dec_d_idx]) if parts[dec_d_idx] is not None else 0.0
            dec_m = float(parts[dec_m_idx]) if parts[dec_m_idx] is not None else 0.0
            dec_s = float(parts[dec_s_idx]) if parts[dec_s_idx] is not None else 0.0
            dec_sign = -1 if str(parts[dec_d_idx]).startswith('-') else 1
            delta_deg = dec_sign * (abs(dec_d) + dec_m / 60.0 + dec_s / 3600.0)
            delta = np.deg2rad(delta_deg)

            iso_str = f"{year:04d}-{month:02d}-{day_int:02d}T{hours:02d}:{minutes:02d}:{seconds:02d}"
            epoch = Time(iso_str, format='isot', scale='utc').mjd
            night_date = f"{year}-{month:02d}-{day_int:02d}"
            if night_date not in nights_data:
                nights_data[night_date] = []
            nights_data[night_date].append({
                'mjd': epoch,
                'alpha': alpha,
                'delta': delta
            })

        except (ValueError, IndexError, KeyError) as e:
            print(f"DEBUG: Line {idx+1} parse error: {repr(line)} | {e}")
            continue

    return nights_data

def fetch_kep_elements(object_name):
    """Fetches and parses real Keplerian elements using table row order and symbol labels."""
    encoded_name = urllib.parse.quote(object_name)
    url = f"https://newton.spacedys.com/neodys/index.php?pc=1.1.1&n={encoded_name}"
    html_content = get_content(url)
    if not html_content:
        return {}
    try:
        soup = BeautifulSoup(html_content, 'html.parser')
        tables = soup.find_all('table')
        for table in tables:
            if "keplerian" in table.get_text(strip=True).lower():
                rows = table.find_all('tr')
                values = []
                for row in rows:
                    cells = row.find_all(['td', 'th'])
                    if len(cells) >= 2:
                        val = cells[1].get_text(strip=True)
                        numeric_match = re.search(r'([-+]?\d*\.?\d+)', val)
                        if numeric_match:
                            values.append(float(numeric_match.group(1)))
                if len(values) >= 6:
                    # Assign by order: a, e, i, Omega (symbol), omega (symbol), M
                    elements = {
                        'a_kep': values[0],
                        'e': values[1],
                        'i': values[2],
                        'Omega': values[3],
                        'omega': values[4],
                        'M': values[5]
                    }
                    return elements
    except Exception as e:
        pass
    return {}

def process_object(neo_name):
    """
    Fetches, parses, and processes all data for a single NEO object and validates
	that the files contain usable data (e.g., RWO has valid nights, elements are present).
    This function is designed to be executed in a concurrent manner.

    Args:
        neo_name (str): The name of the NEO object to process.

    Returns:
        tuple: A tuple containing:
            - list: A list of dictionaries, each representing a processed observation night.
            - str: The name of the object, for tracking.
            - str: The status of the processing ('processed' or 'rejected').
    """

    ALPHA_DOT_THRESHOLD = np.pi/2  # radians/day
    DELTA_DOT_THRESHOLD = np.pi/2  # radians/day

    ALPHA_MIN, ALPHA_MAX = 0.0, 2 * np.pi
    DELTA_MIN, DELTA_MAX = -np.pi / 2, np.pi / 2

    # Step 1: Fetch all required data for the object
    rwo_result = fetch_rwo(neo_name)
    kep_elements = fetch_kep_elements(neo_name)
    eq0_elements = fetch_equ0_elements(neo_name)

    # Step 2: Validate that ALL required data was fetched successfully
    # Require RWO data AND Keplerian elements AND EQU elements
    if not rwo_result or not rwo_result.get('content') or not kep_elements or not eq0_elements:
        print(f"REJECTED: Missing data for {neo_name}")
        return [], neo_name, 'rejected'

    # Step 3: Parse the RWO data to get observation nights
    nights_data = parse_rwo(rwo_result['content'])
    if not nights_data:
        print(f"REJECTED: No valid nights for {neo_name}")
        return [], neo_name, 'rejected'

    # Step 4: Process each valid night of observation to create data rows
    object_rows = []
    sorted_nights = sorted(nights_data.items())
    for night_index, (night_date, obs_list) in enumerate(sorted_nights, 1):
        alpha_dot, delta_dot = 0.0, 0.0
        a_fit, d_fit = None, None
        if len(obs_list) < 2:
            print(f"Skipping night {night_index} ({night_date}) due to insufficient observations: {len(obs_list)}")
            continue

        obs_list.sort(key=lambda o: o.get('mjd', 0))
        mid_obs = obs_list[len(obs_list) // 2]
        t_fit = mid_obs.get('mjd', 0.0)

        # Calculate alpha_dot and delta_dot using np.polyfit (same as loader)
        if len(obs_list) >= 4:
            t = np.array([obs['mjd'] for obs in obs_list])
            alpha = np.array([obs['alpha'] for obs in obs_list])
            delta = np.array([obs['delta'] for obs in obs_list])

            with warnings.catch_warnings(record=True) as w:
                warnings.simplefilter('always', RankWarning)
                try:
                    a_fit = np.polyfit(t, alpha, 2)
                    d_fit = np.polyfit(t, delta, 2)
                    rankwarn = any(isinstance(warn.message, RankWarning) for warn in w)
                    if rankwarn:
                        a_fit = np.polyfit(t, alpha, 1)
                        d_fit = np.polyfit(t, delta, 1)
                        alpha_dot = a_fit[0]
                        delta_dot = d_fit[0]
                    else:
                        alpha_dot = 2 * a_fit[0] * t_fit + a_fit[1]
                        delta_dot = 2 * d_fit[0] * t_fit + d_fit[1]
                except Exception as fit_err:
                    print(f"Fit error in night {night_index}: {fit_err}")
                    a_fit, d_fit = None, None
                    alpha_dot, delta_dot = 0.0, 0.0

        elif len(obs_list) <= 3:
            t = np.array([obs['mjd'] for obs in obs_list])
            alpha = np.array([obs['alpha'] for obs in obs_list])
            delta = np.array([obs['delta'] for obs in obs_list])
            try:
                a_fit = np.polyfit(t, alpha, 1)
                d_fit = np.polyfit(t, delta, 1)
                alpha_dot = a_fit[0]
                delta_dot = d_fit[0]
            except Exception as fit_err:
                print(f"Linear fit error in night {night_index}: {fit_err}")
                a_fit, d_fit = None, None
                alpha_dot, delta_dot = 0.0, 0.0

        row = {
            'object': neo_name, 'night': night_index, 't_fit': t_fit,
            'alpha': mid_obs.get('alpha', 0.0), 'delta': mid_obs.get('delta', 0.0),
            'alpha_dot': alpha_dot, 'delta_dot': delta_dot, 
            **kep_elements, **eq0_elements
        }

        if (-ALPHA_DOT_THRESHOLD < alpha_dot < ALPHA_DOT_THRESHOLD and 
            -DELTA_DOT_THRESHOLD < delta_dot < DELTA_DOT_THRESHOLD and
            ALPHA_MIN <= row['alpha'] <= ALPHA_MAX and
            DELTA_MIN <= row['delta'] <= DELTA_MAX ):

            object_rows.append(row)
        else:
            print(f"Skipping night {night_index} for {neo_name} due to non-physical fit estimations")
            continue

    if not object_rows:
        print(f"REJECTED: No valid nights with enough observations for {neo_name}")
        return [], neo_name, 'rejected'

    return object_rows, neo_name, 'processed'
def get_content(url, timeout=30, max_retries=3):
    """
    Fetches content from a URL with improved error handling and retries.
    Updated with robust session configuration to avoid HTTP 403 errors.
    """
    session = requests.Session()
    
    # Configure retry strategy
    retry_strategy = Retry(
        total=max_retries,
        backoff_factor=2,
        status_forcelist=[403, 429, 500, 502, 503, 504],
        allowed_methods=["HEAD", "GET", "OPTIONS"]
    )
    
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    
    # Enhanced headers to mimic real browser behavior (fixes 403 errors)
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'none',
        'Sec-Fetch-User': '?1',
        'Cache-Control': 'max-age=0',
        'DNT': '1',
        'Sec-CH-UA': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
        'Sec-CH-UA-Mobile': '?0',
        'Sec-CH-UA-Platform': '"Linux"'
    })
    
    try:
        response = session.get(url, timeout=timeout)  # Removed verify=False
        response.raise_for_status()
        return response.text
    except requests.exceptions.Timeout:
        return None
    except requests.exceptions.ConnectionError:
        return None
    except requests.exceptions.HTTPError as e:
        if e.response.status_code != 404:
            print(f"🔥 HTTP error {e.response.status_code} fetching {url}")
        return None
    except Exception:
        return None
    finally:
        session.close()

def is_valid_neo_name(name):
    """Validate NEO object names to filter out invalid entries."""
    if not name or len(name) < 4:
        return False
    
    # Clean the name
    name = name.strip()
    
    # More precise patterns for NEO names
    patterns = [
        r'^\d{4}\s+[A-Z]{1,3}\d*$',     # e.g., "2023 BU", "1991 VG"
        r'^\d{4}[A-Z]{1,3}\d*$',        # e.g., "2015RN35", "2019EA2" (no space)
        r'^\(\d+\)\s*[A-Za-z\s]*$',     # e.g., "(433) Eros", "(1) Ceres"
        r'^[A-Z]{2,}\d+$',              # e.g., "AA29", "BD", etc.
    ]
    
    # Check if it matches any valid pattern
    if not any(re.match(pattern, name) for pattern in patterns):
        return False
    
    # Additional filters to exclude obviously invalid names
    invalid_keywords = [
        'object', 'name', 'http', 'www', 'com', 'neodys', 'spacedys',
        'index', 'php', 'table', 'cell', 'row', 'column', 'data',
        'the', 'and', 'or', 'but', 'for', 'with', 'without'
    ]
    
    name_lower = name.lower()
    if any(keyword in name_lower for keyword in invalid_keywords):
        return False
    
    # Must contain at least one digit and one letter
    has_digit = any(c.isdigit() for c in name)
    has_letter = any(c.isalpha() for c in name)
    
    return has_digit and has_letter

def get_all_prefixes(page_url):
    """Fetch the list of all NEO objects from the main NeoDyS-2 page."""
    url = page_url
    html_content = get_content(url)
    
    if html_content:
        soup = BeautifulSoup(html_content, 'html.parser')
        neo_objects = []
        
        # Strategy 1: Look for links containing object names
        for link in soup.find_all('a', href=True):
            if 'pc=1.1.1&n=' in link.get('href', ''):
                # Extract the object name from the URL parameter
                href = link.get('href', '')
                if '&n=' in href:
                    name = href.split('&n=')[1].split('&')[0]  # Get name from URL
                    name = name.replace('%20', ' ')  # Decode URL encoding
                    if is_valid_neo_name(name):
                        neo_objects.append(name)
        
        # Strategy 2: Look for text patterns that match NEO names
        page_text = soup.get_text()
        # Find year-letter-number patterns (e.g., 2015 RN35, 2019EA2)
        neo_patterns = [
            r'\b(\d{4}\s+[A-Z]{1,3}\d+)\b',  # 2015 RN35
            r'\b(\d{4}[A-Z]{1,3}\d+)\b',     # 2015RN35
            r'\b(\(\d+\)\s*[A-Za-z\s]*)\b'   # (433) Eros
        ]
        
        for pattern in neo_patterns:
            matches = re.findall(pattern, page_text)
            for match in matches:
                name = match.strip()
                if is_valid_neo_name(name):
                    neo_objects.append(name)
        
        if neo_objects:
            unique_neos = list(set(neo_objects))
            print(f"Successfully extracted {len(unique_neos)} NEOs from the website.")
            return unique_neos  # Return all extracted NEOs, not limited
    
    # Fallback: try a different page or approach
    print("Primary extraction failed. Trying alternative approach...")
    
    # Try the main NEA list page
    alt_url = "https://newton.spacedys.com/neodys/index.php?pc=1.1.0"
    html_content = get_content(alt_url)
    
    if html_content:
        soup = BeautifulSoup(html_content, 'html.parser')
        neo_objects = []
        
        # Look for any NEO-like patterns in the text
        page_text = soup.get_text()
        neo_patterns = [
            r'\b(\d{4}\s+[A-Z]{1,3}\d+)\b',
            r'\b(\d{4}[A-Z]{1,3}\d+)\b'
        ]
        
        for pattern in neo_patterns:
            matches = re.findall(pattern, page_text)
            for match in matches:
                name = match.strip()
                if is_valid_neo_name(name):
                    neo_objects.append(name)
        
        if neo_objects:
            unique_neos = list(set(neo_objects))
            print(f"Alternative extraction found {len(unique_neos)} NEOs.")
            return unique_neos  # Return all found NEOs, not limited
    
    print("❌ Could not extract NEO names from website. Please check the NeoDyS-2 site structure.")
    return []

def fetch_rwo(object_name):
    """Fetch RWO file content from NeoDyS-2."""
    # URL encode the object name to handle spaces and special characters
    encoded_name = urllib.parse.quote(object_name.replace(" ", "%20"))
    url = f"https://newton.spacedys.com/~neodys2/mpcobs/{encoded_name}.rwo"
    content = get_content(url)
    if content and not content.lower().startswith('<html>'):
        return {'content': content}
    else:
        return None

def fetch_equ0_elements(object_name):
    """Fetch EQU elements from .eq0 file.
    Returns exactly 6 equinoctial elements: a_equ, h, k, p, q, lambda
    """
    encoded_name = urllib.parse.quote(object_name.replace(" ", "%20"))
    url = f"https://newton.spacedys.com/~neodys2/epoch/{encoded_name}.eq0"
    response_text = get_content(url)
    if not response_text: 
        return {}
    try:
        for line in response_text.strip().split('\n'):
            if line.strip().startswith('EQU'):
                parts = line.split()
                # Extract exactly 6 equinoctial elements: a_equ, h, k, p, q, lambda
                if len(parts) >= 8:  # Has a, h, k, p, q, lambda, plus extra data
                    result = {
                        'a_equ': float(parts[1]),      # Semi-major axis (equinoctial)
                        'h': float(parts[2]),          # h = e * sin(omega + Omega)
                        'k': float(parts[3]),          # k = e * cos(omega + Omega)
                        'p': float(parts[4]),          # p = tan(i/2) * sin(Omega)
                        'q': float(parts[5]),          # q = tan(i/2) * cos(Omega)
                        'lambda': float(parts[6])      # lambda = M + omega + Omega
                    }
                    return result
                elif len(parts) >= 7:  # Missing one element, fill with default
                    result = {
                        'a_equ': float(parts[1]) if len(parts) > 1 else 1.0,
                        'h': float(parts[2]) if len(parts) > 2 else 0.0,
                        'k': float(parts[3]) if len(parts) > 3 else 0.0,
                        'p': float(parts[4]) if len(parts) > 4 else 0.0,
                        'q': float(parts[5]) if len(parts) > 5 else 0.0,
                        'lambda': float(parts[6]) if len(parts) > 6 else 0.0
                    }
                    return result
    except (ValueError, IndexError) as e: 
        pass
    return {}

def create_dataset(neo_list):
    """
    Processes a list of NEO names concurrently to fetch their data, including RWO, 
    Keplerian elements, and corrected equinoctial elements.

    Args:
        neo_list (list): A list of NEO names to process.

    Returns:
        tuple: A tuple containing:
            - list: A list of dictionaries, where each dictionary represents a row in the final dataset.
            - int: The number of objects that were rejected due to missing data.
    """
    all_rows = []
    rejected_count = 0
    
    # Use ThreadPoolExecutor to process objects in parallel
    with ThreadPoolExecutor(max_workers=20) as executor:
        # Create a future for each NEO object processing task
        future_to_neo = {executor.submit(process_object, neo_name): neo_name for neo_name in neo_list}
        
        # Use tqdm to create a progress bar for the concurrent tasks
        pbar = tqdm(as_completed(future_to_neo), total=len(neo_list), desc="Processing NEOs")
        
        for future in pbar:
            try:
                # Get the result from the completed future
                object_rows, neo_name, status = future.result()
                
                if status == 'processed' and object_rows:
                    all_rows.extend(object_rows)
                else:
                    rejected_count += 1
            except Exception as e:
                # Handle exceptions that might occur within the thread
                neo_name = future_to_neo[future]
                rejected_count += 1

    return all_rows, rejected_count

def check_data_availability(neo_name):
    """
    Lightweight check to verify only if all three data sources (RWO, Keplerian, EQU) are available,
    but not their quality. Uses HEAD requests or minimal content fetching for efficiency.
    Updated with robust session to avoid HTTP 403 errors.
    
    Args:
        neo_name (str): The NEO name to check
        
    Returns:
        bool: True if all three data sources are available, False otherwise
    """
	    
    # Prepare URLs for all three data sources
    encoded_name = urllib.parse.quote(neo_name.replace(" ", "%20"))
    
    urls_to_check = {
        'rwo': f"https://newton.spacedys.com/~neodys2/mpcobs/{encoded_name}.rwo",
        'equ': f"https://newton.spacedys.com/~neodys2/epoch/{encoded_name}.eq0",
        'kep': f"https://newton.spacedys.com/neodys/index.php?pc=1.1.1&n={urllib.parse.quote(neo_name)}"
    }
    
    session = requests.Session()
    # Use the same robust headers that fixed the 403 errors
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'none',
        'Sec-Fetch-User': '?1',
        'Cache-Control': 'max-age=0'
    })
    
    available_sources = 0
    
    try:
        # Check RWO file availability (HEAD request is faster)
        try:
            response = session.head(urls_to_check['rwo'], timeout=5)  # Removed verify=False
            if response.status_code == 200:
                available_sources += 1
        except:
            pass
            
        # Check EQU file availability (HEAD request is faster)
        try:
            response = session.head(urls_to_check['equ'], timeout=5)  # Removed verify=False
            if response.status_code == 200:
                available_sources += 1
        except:
            pass
            
        # Check Keplerian elements page (need to GET to check content)
        try:
            response = session.get(urls_to_check['kep'], timeout=5)  # Removed verify=False
            if response.status_code == 200 and 'keplerian' in response.text.lower():
                available_sources += 1
        except:
            pass
            
    except Exception:
        pass
    finally:
        session.close()
    
    # Return True only if all 3 sources are available
    return available_sources >= 3

def validate_object(all_neo_names, target_count, use_random_sampling=True, random_seed=None):
    """
    Validates NEO names and checks data availability to ensure exactly target_count 
    valid NEOs with complete data are selected.
    
    Args:
        all_neo_names (list): List of all NEO names from the website
        target_count (int): Number of validated NEOs needed
        use_random_sampling (bool): Whether to randomly sample or take first N objects
        random_seed (int): Random seed for reproducible results (None for true randomness)
        
    Returns:
        list: List of exactly target_count NEO names with complete data available
    """
    sampling_method = "random sampling" if use_random_sampling else "sequential selection"
    print(f"🔍 Validating NEOs with data availability check (target: {target_count}, method: {sampling_method})...")
    
    # Step 1: Filter for valid NEO names first
    valid_names = [name for name in all_neo_names if is_valid_neo_name(name)]
    print(f"📋 Found {len(valid_names)} NEOs with valid name patterns")
    
    # Step 2: Apply sampling strategy
    if use_random_sampling:
        # Set random seed for reproducibility if provided
        if random_seed is not None:
            random.seed(random_seed)
            print(f"🎲 Using random seed {random_seed} for reproducible sampling")
        
        # Randomly shuffle the valid names for diverse sampling
        random.shuffle(valid_names)
        print(f"🎲 Randomly shuffled NEO list for diverse sampling")
        
        # Check more NEOs than needed to account for failures (random sampling)
        check_limit = min(len(valid_names), target_count * 5)
    else:
        # Sequential selection - take first N objects
        print(f"📝 Using sequential selection (first {target_count} valid NEOs)")
        check_limit = min(len(valid_names), target_count * 3)  # Smaller buffer for sequential
    
    validated_neos = []
    checked_count = 0
    
    # Step 3: Use ThreadPoolExecutor for concurrent validation
    with ThreadPoolExecutor(max_workers=10) as executor:
        # Create futures for validation tasks
        future_to_name = {}
        
        for name in valid_names[:check_limit]:
            future = executor.submit(check_data_availability, name)
            future_to_name[future] = name
        
        print(f"🚀 Started validation of {len(future_to_name)} NEOs using {sampling_method}...")
        
        # Process completed validation tasks
        for future in as_completed(future_to_name):
            name = future_to_name[future]
            checked_count += 1
            
            try:
                has_complete_data = future.result()
                if has_complete_data:
                    validated_neos.append(name)
                    print(f"✅ {len(validated_neos)}/{target_count}: {name} (checked {checked_count})")
                    
                    # Stop when we have enough validated NEOs
                    if len(validated_neos) >= target_count:
                        # Cancel remaining futures to save resources
                        for remaining_future in future_to_name:
                            if not remaining_future.done():
                                remaining_future.cancel()
                        break
                else:
                    print(f"❌ {name}: Missing data sources (checked {checked_count})")
                    
            except Exception as e:
                print(f"⚠️ {name}: Validation error - {str(e)[:50]}...")
                
    print(f"🎯 Validation complete: Found {len(validated_neos)} NEOs with complete data (checked {checked_count} total)")
    return validated_neos

# %%
# FINAL PIPELINE RUN
# 1. Get all NEO names from the website
print("🛰️ Fetching all NEO names from NeoDyS-2...")
all_neo_names = get_all_prefixes(page_url)
print(f"🌍 Found {len(all_neo_names)} total NEOs.")

# 2. Validate NEOs to get a list of N_OBJECTS with all required data
print(f"\n🔍 Validating NEOs to find {N_OBJECTS} objects with complete data...")
validated_neo_names = validate_object(
    all_neo_names, 
    N_OBJECTS, 
    use_random_sampling=RANDOM_SAMPLING,
    random_seed=RANDOM_SEED
)
print(f"✅ Validated {len(validated_neo_names)} NEOs.")

# 3. Process the validated NEOs using the corrected pipeline
print(f"\n⚙️ Processing {len(validated_neo_names)} validated NEOs in parallel...")
final_dataset_rows, rejected_count = create_dataset(validated_neo_names)

# 4. Create the final DataFrame and save to CSV
print(f"\n💾 Creating final DataFrame and saving to CSV...")
if final_dataset_rows:
    final_df = pd.DataFrame(final_dataset_rows)
    
    # Report results
    successful_count = len(validated_neo_names) - rejected_count
    print(f"\n📊 PROCESSING SUMMARY:")
    print(f"   🎯 Target NEOs: {N_OBJECTS}")
    print(f"   ✅ Successfully processed: {successful_count}")
    print(f"   ❌ Rejected: {rejected_count}")
    print(f"   📊 Total data rows: {len(final_df)}")
    print(f"   🎯 Success rate: {(successful_count/len(validated_neo_names)*100):.1f}%")
    
    # Ensure consistent column order (basic + 6 Keplerian + 6 Equinoctial)
    # Check which equinoctial columns are available
    available_cols = final_df.columns.tolist()
    
    # Define exact column sets as per specification:
    # Keplerian: a_kep, e, i, Omega, omega, M
    # Equinoctial: a_equ, h, k, p, q, lambda
    basic_cols = ['object', 'night', 't_fit', 'alpha', 'delta', 'alpha_dot', 'delta_dot']
    keplerian_cols = ['a_kep', 'e', 'i', 'Omega', 'omega', 'M']
    equinoctial_cols = ['a_equ', 'h', 'k', 'p', 'q', 'lambda']
    
    # Create final column order (now with separate a_kep and a_equ)
    # Format: basic + 6 Keplerian + 6 Equinoctial (no shared columns)
    final_column_order = basic_cols + ['a_kep', 'e', 'i', 'Omega', 'omega', 'M', 'a_equ', 'h', 'k', 'p', 'q', 'lambda']
    
    # Ensure all required columns exist, add missing with default values
    missing_cols = [col for col in final_column_order if col not in available_cols]
    if missing_cols:
        print(f"⚠️  Adding missing columns with default values: {missing_cols}")
        for col in missing_cols:
            final_df[col] = 0.0
    
    final_df = final_df[final_column_order]
    
    print(f"\n📋 Final dataset structure:")
    print(f"   Basic fields: {len(basic_cols)}")
    print(f"   Keplerian elements: 6 (a_kep, e, i, Omega, omega, M)")
    print(f"   Equinoctial elements: 6 (a_equ, h, k, p, q, lambda)")
    print(f"   Total columns: {len(final_column_order)}")
    print(f"   Note: Separate semi-major axes: a_kep (Keplerian) and a_equ (Equinoctial)")
    
    # Save to CSV
    output_path = "./DataSet_NEO_VSA_from1to8nights.csv"
    final_df.to_csv(output_path, index=False)
    
    print(f"\n🎉 SUCCESS! Pipeline complete.")
    print(f"Dataset saved to: {output_path}")
    print(f"📋 Columns: {final_column_order}")
else:
    print("❌ No data was processed. The final dataset is empty.")
# Out:
# 🛰️ Fetching all NEO names from NeoDyS-2...
# Successfully extracted 9859 NEOs from the website.
# 🌍 Found 9859 total NEOs.
#
# 🔍 Validating NEOs to find 9000 objects with complete data...
# 🔍 Validating NEOs with data availability check (target: 9000, method: random sampling)...
# 📋 Found 9859 NEOs with valid name patterns
# 🎲 Using random seed 42 for reproducible sampling
# 🎲 Randomly shuffled NEO list for diverse sampling
# 🚀 Started validation of 9859 NEOs using random sampling...
# ❌ 2022UM4: Missing data sources (checked 1)
# ❌ 2019HS2: Missing data sources (checked 2)
# ❌ 2013PA39: Missing data sources (checked 3)
# ✅ 1/9000: 2014WA5 (checked 4)
# ✅ 2/9000: 2015XQ261 (checked 5)
# ✅ 3/9000: 2023HB4 (checked 6)
# ✅ 4/9000: 2022UA28 (checked 7)
# ✅ 5/9000: 2019YF2 (checked 8)
# ✅ 6/9000: 2025CL1 (checked 9)
# ✅ 7/9000: 2002TA58 (checked 10)
# ✅ 8/9000: 2014JX24 (checked 11)
# ✅ 9/9000: 2015DS198 (checked 12)
# ✅ 10/9000: 2004MN1 (checked 13)
# ❌ 2025FR2: Missing data sources (checked 14)
# ✅ 11/9000: 2021CS1 (checked 15)
# ✅ 12/9000: 2004DF2 (checked 16)
# ✅ 13/9000: 2018AC4 (checked 17)
# ✅ 14/9000: 2023BZ2 (checked 18)
# ✅ 15/9000: 2014HZ196 (checked 19)
# ✅ 16/9000: 2023KF1 (checked 20)
# ✅ 17/9000: 2021TV10 (checked 21)
# ✅ 18/9000: 2023TM3 (checked 22)
# ✅ 19/9000: 2021CC6 (checked 23)
# ✅ 20/9000: 2024RT9 (checked 24)
# ✅ 21/9000: 2024TE1 (checked 25)
# ✅ 22/9000: 2023TD8 (checked 26)
# ✅ 23/9000: 2017BW6 (checked 27)
# ✅ 24/9000: 2021WE4 (checked 28)
# ✅ 25/9000: 2024BE5 (checked 29)
# ✅ 26/9000: 2021CE3 (checked 30)
# ✅ 27/9000: 2022YD3 (checked 31)
# ✅ 28/9000: 2024JX6 (checked 32)
# ✅ 29/9000: 2017XM61 (checked 33)
# ✅ 30/9000: 2017RV17 (checked 34)
# ✅ 31/9000: 2023BW5 (checked 35)
# ✅ 32/9000: 2019JD5 (checked 36)
# ✅ 33/9000: 2025AB1 (checked 37)
# ✅ 34/9000: 2014OM207 (checked 38)
# ✅ 35/9000: 2021EA4 (checked 39)
# ✅ 36/9000: 2009WD7 (checked 40)
# ✅ 37/9000: 2025DY7 (checked 41)
# ✅ 38/9000: 2024SY5 (checked 42)
# ✅ 39/9000: 2012XJ112 (checked 43)
# ✅ 40/9000: 2016GZ220 (checked 44)
# ❌ 2020YL2: Missing data sources (checked 45)
# ✅ 41/9000: 2024UK2 (checked 46)
# ❌ 2015FO34: Missing data sources (checked 47)
# ✅ 42/9000: 2014WT367 (checked 48)
# ✅ 43/9000: 2024YP7 (checked 49)
# ✅ 44/9000: 2024YS6 (checked 50)
# ✅ 45/9000: 2016EG1 (checked 51)
# ✅ 46/9000: 2018BY5 (checked 52)
# ✅ 47/9000: 2021CY8 (checked 53)
# ✅ 48/9000: 2025HA5 (checked 54)
# ✅ 49/9000: 2021WB5 (checked 55)
# ✅ 50/9000: 2020JR1 (checked 56)
# ✅ 51/9000: 2020XQ1 (checked 57)
# ✅ 52/9000: 2021PN4 (checked 58)
# ✅ 53/9000: 2025NJ1 (checked 59)
# ✅ 54/9000: 2013TQ135 (checked 60)
# ✅ 55/9000: 2023RA15 (checked 61)
# ✅ 56/9000: 2023BH2 (checked 62)
# ✅ 57/9000: 2020BM15 (checked 63)
# ✅ 58/9000: 2024YZ8 (checked 64)
# ✅ 59/9000: 2013UJ9 (checked 65)
# ✅ 60/9000: 2020QG1 (checked 66)
# ✅ 61/9000: 2021JY9 (checked 67)
# ✅ 62/9000: 2016JQ38 (checked 68)
# ✅ 63/9000: 2024VX1 (checked 69)
# ✅ 64/9000: 2022UQ12 (checked 70)
# ✅ 65/9000: 2021RY3 (checked 71)
# ✅ 66/9000: 2021XY1 (checked 72)
# ✅ 67/9000: 2022UC7 (checked 73)
# ✅ 68/9000: 2020HW2 (checked 74)
# ✅ 69/9000: 2019BH4 (checked 75)
# ✅ 70/9000: 2007VE138 (checked 76)
# ✅ 71/9000: 2024LS5 (checked 77)
# ✅ 72/9000: 2023JA3 (checked 78)
# ✅ 73/9000: 2017UP5 (checked 79)
# ✅ 74/9000: 2014OQ207 (checked 80)
# ✅ 75/9000: 2024ER4 (checked 81)
# ✅ 76/9000: 2023BY2 (checked 82)
# ✅ 77/9000: 2017GH4 (checked 83)
# ✅ 78/9000: 2025FO7 (checked 84)
# ✅ 79/9000: 2022SM20 (checked 85)
# ❌ 2023TT36: Missing data sources (checked 86)
# ✅ 80/9000: 2020OG1 (checked 87)
# ✅ 81/9000: 2022QO1 (checked 88)
# ✅ 82/9000: 2020FY2 (checked 89)
# ✅ 83/9000: 2018YS2 (checked 90)
# ✅ 84/9000: 2016FX7 (checked 91)
# ✅ 85/9000: 2020BG5 (checked 92)
# ✅ 86/9000: 2020BM12 (checked 93)
# ❌ 2007FC3: Missing data sources (checked 94)
# ❌ 2017LE1: Missing data sources (checked 95)
# ❌ 2019AY2: Missing data sources (checked 96)
# ✅ 87/9000: 2021TU13 (checked 97)
# ✅ 88/9000: 2022WF2 (checked 98)
# ✅ 89/9000: 2016AX64 (checked 99)
# ✅ 90/9000: 2024YV10 (checked 100)
# ✅ 91/9000: 2020FK1 (checked 101)
# ✅ 92/9000: 2009WX7 (checked 102)
# ✅ 93/9000: 2013VP4 (checked 103)
# ❌ 2024TW9: Missing data sources (checked 104)
# ✅ 94/9000: 2019YB2 (checked 105)
# ❌ 2024XB11: Missing data sources (checked 106)
# ✅ 95/9000: 2010XF25 (checked 107)
# ✅ 96/9000: 2022SH12 (checked 108)
# ❌ 2019GL20: Missing data sources (checked 109)
# ✅ 97/9000: 2009WB11 (checked 110)
# ✅ 98/9000: 2021CE1 (checked 111)
# ✅ 99/9000: 2016GV2 (checked 112)
# ❌ 2014HL198: Missing data sources (checked 113)
# ✅ 100/9000: 2018VW3 (checked 114)
# ✅ 101/9000: 2004RU109 (checked 115)
# ✅ 102/9000: 2016PM38 (checked 116)
# ✅ 103/9000: 2009WQ52 (checked 117)
# ✅ 104/9000: 2017DB120 (checked 118)
# ❌ 2018VR5: Missing data sources (checked 119)
# ✅ 105/9000: 2014FA7 (checked 120)
# ✅ 106/9000: 2020FJ4 (checked 121)
# ✅ 107/9000: 2011AO4 (checked 122)
# ❌ 2025GL1: Missing data sources (checked 123)
# ✅ 108/9000: 2013VP13 (checked 124)
# ✅ 109/9000: 2021LN2 (checked 125)
# ❌ 2021RV9: Missing data sources (checked 126)
# ✅ 110/9000: 2005TQ45 (checked 127)
# ✅ 111/9000: 2020UC1 (checked 128)
# ✅ 112/9000: 2024RR1 (checked 129)
# ✅ 113/9000: 2022YY1 (checked 130)
# ✅ 114/9000: 2007EH26 (checked 131)
# ✅ 115/9000: 2023FY6 (checked 132)
# ✅ 116/9000: 2022UN28 (checked 133)
# ✅ 117/9000: 2022FQ2 (checked 134)
# ✅ 118/9000: 2017SN21 (checked 135)
# ✅ 119/9000: 2024YC9 (checked 136)
# ❌ 2007RO17: Missing data sources (checked 137)
# ❌ 2024AT2: Missing data sources (checked 138)
# ❌ 2024BC5: Missing data sources (checked 139)
# ✅ 120/9000: 2021XT3 (checked 140)
# ✅ 121/9000: 2004FY15 (checked 141)
# ✅ 122/9000: 2020PD2 (checked 142)
# ✅ 123/9000: 2012YR3 (checked 143)
# ✅ 124/9000: 2012FA57 (checked 144)
# ❌ 2019GS5: Missing data sources (checked 145)
# ✅ 125/9000: 2019SS2 (checked 146)
# ✅ 126/9000: 2019OM3 (checked 147)
# ✅ 127/9000: 2021XN6 (checked 148)
# ✅ 128/9000: 2023RZ9 (checked 149)
# ✅ 129/9000: 2018DQ3 (checked 150)
# ✅ 130/9000: 2023MM5 (checked 151)
# ✅ 131/9000: 2024BH3 (checked 152)
# ✅ 132/9000: 2022OM6 (checked 153)
# ❌ 2021XH1: Missing data sources (checked 154)
# ❌ 2015HS10: Missing data sources (checked 155)
# ✅ 133/9000: 2023SM3 (checked 156)
# ✅ 134/9000: 2019FR1 (checked 157)
# ✅ 135/9000: 2021GD5 (checked 158)
# ✅ 136/9000: 2020FE3 (checked 159)
# ✅ 137/9000: 2020UO3 (checked 160)
# ✅ 138/9000: 2021ES1 (checked 161)
# ✅ 139/9000: 2015FR517 (checked 162)
# ❌ 2022WQ5: Missing data sources (checked 163)
# ✅ 140/9000: 2017YU4 (checked 164)
# ❌ 2021GN5: Missing data sources (checked 165)
# ✅ 141/9000: 2025HQ5 (checked 166)
# ✅ 142/9000: 2021WA1 (checked 167)
# ✅ 143/9000: 2024UM1 (checked 168)
# ✅ 144/9000: 2023XX1 (checked 169)
# ❌ 2021LY4: Missing data sources (checked 170)
# ✅ 145/9000: 2017FW101 (checked 171)
# ✅ 146/9000: 2024SS4 (checked 172)
# ❌ 2025MA92: Missing data sources (checked 173)
# ✅ 147/9000: 2020WY4 (checked 174)
# ✅ 148/9000: 2024SO1 (checked 175)
# ✅ 149/9000: 2024FO1 (checked 176)
# ✅ 150/9000: 2021UZ4 (checked 177)
# ✅ 151/9000: 2019HF4 (checked 178)
# ✅ 152/9000: 2019RF2 (checked 179)
# ✅ 153/9000: 2010XH3 (checked 180)
# ✅ 154/9000: 2001BB40 (checked 181)
# ✅ 155/9000: 2015HR182 (checked 182)
# ❌ 2010JW34: Missing data sources (checked 183)
# ❌ 2004XH3: Missing data sources (checked 184)
# ✅ 156/9000: 2022UX27 (checked 185)
# ✅ 157/9000: 2020UD2 (checked 186)
# ✅ 158/9000: 2007MJ13 (checked 187)
# ✅ 159/9000: 2022GU1 (checked 188)
# ✅ 160/9000: 2017UJ44 (checked 189)
# ✅ 161/9000: 2023YX1 (checked 190)
# ✅ 162/9000: 2022CO2 (checked 191)
# ✅ 163/9000: 2024UK13 (checked 192)
# ✅ 164/9000: 2011ET20 (checked 193)
# ✅ 165/9000: 2012VT76 (checked 194)
# ✅ 166/9000: 2024HV1 (checked 195)
# ✅ 167/9000: 2015VF150 (checked 196)
# ✅ 168/9000: 2016PJ1 (checked 197)
# ✅ 169/9000: 2019JJ3 (checked 198)
# ✅ 170/9000: 2021NB1 (checked 199)
# ❌ 2021JS3: Missing data sources (checked 200)
# ✅ 171/9000: 2005BM1 (checked 201)
# ✅ 172/9000: 2023QP3 (checked 202)
# ✅ 173/9000: 2015BM509 (checked 203)
# ✅ 174/9000: 2017SK19 (checked 204)
# ✅ 175/9000: 2021PE15 (checked 205)
# ✅ 176/9000: 2004SR26 (checked 206)
# ✅ 177/9000: 2022CK4 (checked 207)
# ❌ 2023VG7: Missing data sources (checked 208)
# ❌ 2021FA1: Missing data sources (checked 209)
# ✅ 178/9000: 2023BX5 (checked 210)
# ❌ 2024UR1: Missing data sources (checked 211)
# ✅ 179/9000: 2017FA159 (checked 212)
# ✅ 180/9000: 2023RK5 (checked 213)
# ✅ 181/9000: 2020PO5 (checked 214)
# ✅ 182/9000: 2016FN56 (checked 215)
# ✅ 183/9000: 2018PN9 (checked 216)
# ✅ 184/9000: 2024AF1 (checked 217)
# ✅ 185/9000: 2009UV87 (checked 218)
# ✅ 186/9000: 2021GC1 (checked 219)
# ✅ 187/9000: 2022GJ4 (checked 220)
# ❌ 2016SP3: Missing data sources (checked 221)
# ✅ 188/9000: 2019NL2 (checked 222)
# ✅ 189/9000: 2005VN5 (checked 223)
# ✅ 190/9000: 2019JN5 (checked 224)
# ✅ 191/9000: 2013SK20 (checked 225)
# ✅ 192/9000: 2025AO3 (checked 226)
# ✅ 193/9000: 2020TW5 (checked 227)
# ❌ 2023RT2: Missing data sources (checked 228)
# ✅ 194/9000: 2021TD13 (checked 229)
# ✅ 195/9000: 2014HP197 (checked 230)
# ✅ 196/9000: 2014HE196 (checked 231)
# ✅ 197/9000: 2010TK6 (checked 232)
# ✅ 198/9000: 2024TZ7 (checked 233)
# ✅ 199/9000: 2024KS1 (checked 234)
# ✅ 200/9000: 2020GH2 (checked 235)
# ✅ 201/9000: 2014AK51 (checked 236)
# ✅ 202/9000: 2017XL61 (checked 237)
# ✅ 203/9000: 2021NY3 (checked 238)
# ✅ 204/9000: 2012KO1 (checked 239)
# ✅ 205/9000: 2020CP2 (checked 240)
# ✅ 206/9000: 2024XO15 (checked 241)
# ✅ 207/9000: 2021UC5 (checked 242)
# ❌ 2009FV23: Missing data sources (checked 243)
# ❌ 2022MP1: Missing data sources (checked 244)
# ✅ 208/9000: 2014HF199 (checked 245)
# ✅ 209/9000: 2020TE6 (checked 246)
# ❌ 2024RG2: Missing data sources (checked 247)
# ✅ 210/9000: 2024PD4 (checked 248)
# ✅ 211/9000: 2018LT2 (checked 249)
# ❌ 2014JR79: Missing data sources (checked 250)
# ✅ 212/9000: 2015DZ180 (checked 251)
# ✅ 213/9000: 2022QT7 (checked 252)
# ✅ 214/9000: 2017WC14 (checked 253)
# ❌ 2025BB1: Missing data sources (checked 254)
# ✅ 215/9000: 2016WV1 (checked 255)
# ❌ 2020XX1: Missing data sources (checked 256)
# ❌ 2020AE1: Missing data sources (checked 257)
# ✅ 216/9000: 2025BY1 (checked 258)
# ✅ 217/9000: 2016FA14 (checked 259)
# ✅ 218/9000: 2020QE2 (checked 260)
# ✅ 219/9000: 2011PN1 (checked 261)
# ✅ 220/9000: 2025BR2 (checked 262)
# ✅ 221/9000: 2020HO4 (checked 263)
# ✅ 222/9000: 2020PW1 (checked 264)
# ✅ 223/9000: 2019EB1 (checked 265)
# ✅ 224/9000: 2019LC6 (checked 266)
# ✅ 225/9000: 2019OW2 (checked 267)
# ✅ 226/9000: 2024BA1 (checked 268)
# ✅ 227/9000: 2024XE4 (checked 269)
# ✅ 228/9000: 2019SW2 (checked 270)
# ✅ 229/9000: 2020TY3 (checked 271)
# ✅ 230/9000: 2023KQ2 (checked 272)
# ✅ 231/9000: 2020RG10 (checked 273)
# ✅ 232/9000: 2023KU4 (checked 274)
# ✅ 233/9000: 2021BC3 (checked 275)
# ✅ 234/9000: 2012EK1 (checked 276)
# ✅ 235/9000: 2014JQ24 (checked 277)
# ✅ 236/9000: 2000JF5 (checked 278)
# ✅ 237/9000: 2024VX3 (checked 279)
# ✅ 238/9000: 2023UU1 (checked 280)
# ✅ 239/9000: 2024YV5 (checked 281)
# ✅ 240/9000: 2015VP64 (checked 282)
# ❌ 2011WB96: Missing data sources (checked 283)
# ✅ 241/9000: 2024JE15 (checked 284)
# ✅ 242/9000: 2012KX41 (checked 285)
# ✅ 243/9000: 2023HT5 (checked 286)
# ✅ 244/9000: 2009WB52 (checked 287)
# ✅ 245/9000: 2016TB11 (checked 288)
# ❌ 2014GM35: Missing data sources (checked 289)
# ✅ 246/9000: 2014WC364 (checked 290)
# ✅ 247/9000: 2017YP6 (checked 291)
# ✅ 248/9000: 2008EG32 (checked 292)
# ✅ 249/9000: 2019VE2 (checked 293)
# ✅ 250/9000: 2019VU3 (checked 294)
# ❌ 2017BY6: Missing data sources (checked 295)
# ✅ 251/9000: 2017XU61 (checked 296)
# ✅ 252/9000: 2020VS4 (checked 297)
# ✅ 253/9000: 2015KV157 (checked 298)
# ✅ 254/9000: 2020XR6 (checked 299)
# ❌ 2016ED1: Missing data sources (checked 300)
# ✅ 255/9000: 2018SH3 (checked 301)
# ✅ 256/9000: 2022RQ1 (checked 302)
# ✅ 257/9000: 2021PZ1 (checked 303)
# ✅ 258/9000: 2018VU3 (checked 304)
# ✅ 259/9000: 2011UO91 (checked 305)
# ✅ 260/9000: 2023JD1 (checked 306)
# ✅ 261/9000: 2021RV1 (checked 307)
# ✅ 262/9000: 2019RE1 (checked 308)
# ✅ 263/9000: 2020XU4 (checked 309)
# ✅ 264/9000: 2020CC1 (checked 310)
# ✅ 265/9000: 2019SD10 (checked 311)
# ✅ 266/9000: 2021HC1 (checked 312)
# ✅ 267/9000: 2017RQ17 (checked 313)
# ❌ 2025HV2: Missing data sources (checked 314)
# ✅ 268/9000: 2014US34 (checked 315)
# ✅ 269/9000: 2020BV8 (checked 316)
# ✅ 270/9000: 2009UM1 (checked 317)
# ✅ 271/9000: 2025FJ2 (checked 318)
# ✅ 272/9000: 2024WT2 (checked 319)
# ✅ 273/9000: 2019JF47 (checked 320)
# ❌ 2022SV12: Missing data sources (checked 321)
# ✅ 274/9000: 2016FF14 (checked 322)
# ✅ 275/9000: 2011YC63 (checked 323)
# ✅ 276/9000: 2017YB6 (checked 324)
# ✅ 277/9000: 2015FK120 (checked 325)
# ✅ 278/9000: 2024XN16 (checked 326)
# ✅ 279/9000: 2024GZ1 (checked 327)
# ✅ 280/9000: 2021AE5 (checked 328)
# ✅ 281/9000: 2025FD20 (checked 329)
# ❌ 2010CQ19: Missing data sources (checked 330)
# ✅ 282/9000: 2021WO6 (checked 331)
# ✅ 283/9000: 2005AU3 (checked 332)
# ✅ 284/9000: 2024EW3 (checked 333)
# ✅ 285/9000: 2023KP5 (checked 334)
# ✅ 286/9000: 2010GF7 (checked 335)
# ✅ 287/9000: 2020GC1 (checked 336)
# ❌ 2018PK8: Missing data sources (checked 337)
# ✅ 288/9000: 2020FV3 (checked 338)
# ✅ 289/9000: 2009TD17 (checked 339)
# ✅ 290/9000: 2019ES2 (checked 340)
# ✅ 291/9000: 2025FP6 (checked 341)
# ✅ 292/9000: 2022UU123 (checked 342)
# ❌ 2023RS29: Missing data sources (checked 343)
# ✅ 293/9000: 2024YV4 (checked 344)
# ✅ 294/9000: 2020DP3 (checked 345)
# ✅ 295/9000: 2006DS62 (checked 346)
# ✅ 296/9000: 2020KQ4 (checked 347)
# ✅ 297/9000: 2024UB8 (checked 348)
# ✅ 298/9000: 2024AX3 (checked 349)
# ✅ 299/9000: 2024PG2 (checked 350)
# ✅ 300/9000: 2023QC2 (checked 351)
# ✅ 301/9000: 2025MB1 (checked 352)
# ✅ 302/9000: 2019UG12 (checked 353)
# ✅ 303/9000: 2012SA3 (checked 354)
# ✅ 304/9000: 2021UU3 (checked 355)
# ❌ 2022WL2: Missing data sources (checked 356)
# ❌ 2024RJ29: Missing data sources (checked 357)
# ✅ 305/9000: 2024RM10 (checked 358)
# ✅ 306/9000: 2024JW16 (checked 359)
# ✅ 307/9000: 2004MV2 (checked 360)
# ❌ 2021VN25: Missing data sources (checked 361)
# ✅ 308/9000: 2008HY1 (checked 362)
# ❌ 2024SV2: Missing data sources (checked 363)
# ✅ 309/9000: 2024XA6 (checked 364)
# ✅ 310/9000: 2013UK9 (checked 365)
# ✅ 311/9000: 2020UY1 (checked 366)
# ✅ 312/9000: 2019KM5 (checked 367)
# ✅ 313/9000: 2019JW6 (checked 368)
# ✅ 314/9000: 2023HU2 (checked 369)
# ✅ 315/9000: 2021RG6 (checked 370)
# ✅ 316/9000: 2012BW61 (checked 371)
# ✅ 317/9000: 2011FF41 (checked 372)
# ✅ 318/9000: 2009UU87 (checked 373)
# ✅ 319/9000: 2022AR1 (checked 374)
# ✅ 320/9000: 2015TQ21 (checked 375)
# ✅ 321/9000: 2023FD5 (checked 376)
# ✅ 322/9000: 2022DL1 (checked 377)
# ✅ 323/9000: 2020TR8 (checked 378)
# ✅ 324/9000: 2014HB197 (checked 379)
# ✅ 325/9000: 2013SD21 (checked 380)
# ✅ 326/9000: 2018AN2 (checked 381)
# ✅ 327/9000: 2021JM7 (checked 382)
# ❌ 2014YK42: Missing data sources (checked 383)
# ✅ 328/9000: 2025CB1 (checked 384)
# ✅ 329/9000: 2017YM5 (checked 385)
# ✅ 330/9000: 2021BH2 (checked 386)
# ✅ 331/9000: 2002PE43 (checked 387)
# ✅ 332/9000: 2024UP11 (checked 388)
# ✅ 333/9000: 2017UK8 (checked 389)
# ✅ 334/9000: 2023TY19 (checked 390)
# ❌ 2003FK1: Missing data sources (checked 391)
# ✅ 335/9000: 2024HO2 (checked 392)
# ❌ 2006WX29: Missing data sources (checked 393)
# ✅ 336/9000: 2010TW54 (checked 394)
# ❌ 2021NX1: Missing data sources (checked 395)
# ✅ 337/9000: 2023PM1 (checked 396)
# ❌ 2025DN6: Missing data sources (checked 397)
# ✅ 338/9000: 2020YJ2 (checked 398)
# ✅ 339/9000: 2023UU4 (checked 399)
# ✅ 340/9000: 2020RB5 (checked 400)
# ✅ 341/9000: 2015CH13 (checked 401)
# ✅ 342/9000: 2024UJ1 (checked 402)
# ❌ 2018RX5: Missing data sources (checked 403)
# ✅ 343/9000: 2023TF8 (checked 404)
# ✅ 344/9000: 2025HR1 (checked 405)
# ✅ 345/9000: 2016RS1 (checked 406)
# ✅ 346/9000: 2018FB4 (checked 407)
# ✅ 347/9000: 2018RC7 (checked 408)
# ✅ 348/9000: 2018VA7 (checked 409)
# ✅ 349/9000: 2021XN2 (checked 410)
# ✅ 350/9000: 2020FC2 (checked 411)
# ✅ 351/9000: 2023XT4 (checked 412)
# ✅ 352/9000: 2008GL20 (checked 413)
# ✅ 353/9000: 2019JM3 (checked 414)
# ✅ 354/9000: 2024FZ1 (checked 415)
# ✅ 355/9000: 2022GW2 (checked 416)
# ✅ 356/9000: 2025ME74 (checked 417)
# ❌ 2017UJ2: Missing data sources (checked 418)
# ✅ 357/9000: 2022RS1 (checked 419)
# ❌ 2005BU1: Missing data sources (checked 420)
# ❌ 2021JS6: Missing data sources (checked 421)
# ✅ 358/9000: 2018KE1 (checked 422)
# ❌ 2024LQ3: Missing data sources (checked 423)
# ✅ 359/9000: 2023BE9 (checked 424)
# ✅ 360/9000: 2013UV3 (checked 425)
# ✅ 361/9000: 2005XZ7 (checked 426)
# ✅ 362/9000: 2023FO4 (checked 427)
# ✅ 363/9000: 2025MX91 (checked 428)
# ✅ 364/9000: 2023HY5 (checked 429)
# ✅ 365/9000: 2018AM2 (checked 430)
# ✅ 366/9000: 2005CP38 (checked 431)
# ✅ 367/9000: 2018FY3 (checked 432)
# ✅ 368/9000: 2021RV2 (checked 433)
# ✅ 369/9000: 2010RE31 (checked 434)
# ✅ 370/9000: 2011SL173 (checked 435)
# ✅ 371/9000: 2021TF1 (checked 436)
# ✅ 372/9000: 2003DY15 (checked 437)
# ✅ 373/9000: 2017DX119 (checked 438)
# ✅ 374/9000: 2019HU2 (checked 439)
# ✅ 375/9000: 2009DT43 (checked 440)
# ✅ 376/9000: 2024YB1 (checked 441)
# ✅ 377/9000: 2005VN1 (checked 442)
# ✅ 378/9000: 2006AB3 (checked 443)
# ✅ 379/9000: 2014HA197 (checked 444)
# ✅ 380/9000: 2020VH2 (checked 445)
# ❌ 2019SH3: Missing data sources (checked 446)
# ✅ 381/9000: 2022DO8 (checked 447)
# ✅ 382/9000: 2012BP123 (checked 448)
# ✅ 383/9000: 2021GQ4 (checked 449)
# ❌ 2020BJ8: Missing data sources (checked 450)
# ❌ 2014HC124: Missing data sources (checked 451)
# ✅ 384/9000: 2024SX9 (checked 452)
# ✅ 385/9000: 2020OU5 (checked 453)
# ❌ 2022UO4: Missing data sources (checked 454)
# ✅ 386/9000: 2023VX7 (checked 455)
# ❌ 2016UR5: Missing data sources (checked 456)
# ✅ 387/9000: 2015KA57 (checked 457)
# ❌ 2020RL9: Missing data sources (checked 458)
# ✅ 388/9000: 2015TN21 (checked 459)
# ✅ 389/9000: 2023UM3 (checked 460)
# ✅ 390/9000: 2024WY14 (checked 461)
# ❌ 2010FW9: Missing data sources (checked 462)
# ✅ 391/9000: 2016TK10 (checked 463)
# ✅ 392/9000: 2021WM4 (checked 464)
# ✅ 393/9000: 2018MU4 (checked 465)
# ✅ 394/9000: 2023HC1 (checked 466)
# ✅ 395/9000: 2021CY4 (checked 467)
# ✅ 396/9000: 2017WH28 (checked 468)
# ✅ 397/9000: 2024CW7 (checked 469)
# ✅ 398/9000: 2025DQ6 (checked 470)
# ✅ 399/9000: 2009HE60 (checked 471)
# ✅ 400/9000: 2024LZ1 (checked 472)
# ✅ 401/9000: 2024SS2 (checked 473)
# ✅ 402/9000: 2019NH6 (checked 474)
# ✅ 403/9000: 2012VJ38 (checked 475)
# ✅ 404/9000: 2017RZ17 (checked 476)
# ✅ 405/9000: 2020TR6 (checked 477)
# ✅ 406/9000: 2022SA12 (checked 478)
# ✅ 407/9000: 2020BO7 (checked 479)
# ✅ 408/9000: 2008EH1 (checked 480)
# ✅ 409/9000: 2024YH7 (checked 481)
# ✅ 410/9000: 2023EA3 (checked 482)
# ✅ 411/9000: 2023KL1 (checked 483)
# ❌ 2014MR5: Missing data sources (checked 484)
# ✅ 412/9000: 2014HJ523 (checked 485)
# ✅ 413/9000: 2017FU2 (checked 486)
# ✅ 414/9000: 2024UD3 (checked 487)
# ✅ 415/9000: 2020FY6 (checked 488)
# ✅ 416/9000: 2025HO1 (checked 489)
# ✅ 417/9000: 2023CG4 (checked 490)
# ✅ 418/9000: 2019YB5 (checked 491)
# ✅ 419/9000: 2014JE57 (checked 492)
# ✅ 420/9000: 2025CA2 (checked 493)
# ✅ 421/9000: 2025BG4 (checked 494)
# ❌ 2008YH30: Missing data sources (checked 495)
# ❌ 2023XJ7: Missing data sources (checked 496)
# ✅ 422/9000: 2020BM1 (checked 497)
# ✅ 423/9000: 2010TN4 (checked 498)
# ✅ 424/9000: 2024JA2 (checked 499)
# ✅ 425/9000: 2017HX4 (checked 500)
# ❌ 2019DE2: Missing data sources (checked 501)
# ❌ 2022RR1: Missing data sources (checked 502)
# ❌ 2019EE1: Missing data sources (checked 503)
# ✅ 426/9000: 2014FH54 (checked 504)
# ✅ 427/9000: 2019YC2 (checked 505)
# ❌ 2023XL2: Missing data sources (checked 506)
# ✅ 428/9000: 2016TX10 (checked 507)
# ✅ 429/9000: 2017FT64 (checked 508)
# ✅ 430/9000: 2024XS8 (checked 509)
# ✅ 431/9000: 2023VT10 (checked 510)
# ✅ 432/9000: 2017UL43 (checked 511)
# ✅ 433/9000: 2016BU39 (checked 512)
# ✅ 434/9000: 2004PZ19 (checked 513)
# ✅ 435/9000: 2008TB1 (checked 514)
# ❌ 2017SE20: Missing data sources (checked 515)
# ✅ 436/9000: 2015KF158 (checked 516)
# ✅ 437/9000: 2014RD17 (checked 517)
# ✅ 438/9000: 2020SG6 (checked 518)
# ❌ 2019SZ9: Missing data sources (checked 519)
# ✅ 439/9000: 2007BY48 (checked 520)
# ✅ 440/9000: 2024PQ5 (checked 521)
# ✅ 441/9000: 2024CB7 (checked 522)
# ✅ 442/9000: 2019HM4 (checked 523)
# ✅ 443/9000: 2016PA79 (checked 524)
# ✅ 444/9000: 2023JZ1 (checked 525)
# ✅ 445/9000: 2023EG2 (checked 526)
# ✅ 446/9000: 2019QX4 (checked 527)
# ✅ 447/9000: 2007AU2 (checked 528)
# ✅ 448/9000: 2017WQ15 (checked 529)
# ✅ 449/9000: 2025EZ1 (checked 530)
# ✅ 450/9000: 2019YR1 (checked 531)
# ✅ 451/9000: 2022WM6 (checked 532)
# ❌ 2020XK1: Missing data sources (checked 533)
# ✅ 452/9000: 2015HD1 (checked 534)
# ✅ 453/9000: 2016SL2 (checked 535)
# ✅ 454/9000: 2022HC4 (checked 536)
# ✅ 455/9000: 2018AY3 (checked 537)
# ✅ 456/9000: 2023TZ8 (checked 538)
# ✅ 457/9000: 2017SA33 (checked 539)
# ✅ 458/9000: 2024NC2 (checked 540)
# ✅ 459/9000: 2018FQ3 (checked 541)
# ✅ 460/9000: 2014EP12 (checked 542)
# ✅ 461/9000: 2020PK6 (checked 543)
# ✅ 462/9000: 2013CM35 (checked 544)
# ✅ 463/9000: 2013CB88 (checked 545)
# ✅ 464/9000: 2005EH94 (checked 546)
# ✅ 465/9000: 2013UM5 (checked 547)
# ✅ 466/9000: 2022WC2 (checked 548)
# ✅ 467/9000: 2017MS8 (checked 549)
# ✅ 468/9000: 2020BK2 (checked 550)
# ✅ 469/9000: 2008UT95 (checked 551)
# ✅ 470/9000: 2024TY21 (checked 552)
# ✅ 471/9000: 2010JL1 (checked 553)
# ✅ 472/9000: 2024XL16 (checked 554)
# ✅ 473/9000: 2007VH189 (checked 555)
# ❌ 2010JM33: Missing data sources (checked 556)
# ✅ 474/9000: 2017YB1 (checked 557)
# ❌ 2016JW28: Missing data sources (checked 558)
# ✅ 475/9000: 2020QV3 (checked 559)
# ✅ 476/9000: 2005JT1 (checked 560)
# ✅ 477/9000: 2014HW196 (checked 561)
# ✅ 478/9000: 2011SN26 (checked 562)
# ✅ 479/9000: 2020QS4 (checked 563)
# ✅ 480/9000: 2024SR3 (checked 564)
# ✅ 481/9000: 2023UH9 (checked 565)
# ❌ 2013KQ1: Missing data sources (checked 566)
# ❌ 2022QB8: Missing data sources (checked 567)
# ✅ 482/9000: 2016AQ164 (checked 568)
# ✅ 483/9000: 2006SS131 (checked 569)
# ✅ 484/9000: 2025HX3 (checked 570)
# ❌ 2018BF6: Missing data sources (checked 571)
# ✅ 485/9000: 2019BL2 (checked 572)
# ✅ 486/9000: 2008TF2 (checked 573)
# ✅ 487/9000: 2022SD9 (checked 574)
# ✅ 488/9000: 2011WU74 (checked 575)
# ✅ 489/9000: 2019BD5 (checked 576)
# ✅ 490/9000: 2005WM3 (checked 577)
# ✅ 491/9000: 2014MG6 (checked 578)
# ✅ 492/9000: 2010GO67 (checked 579)
# ✅ 493/9000: 2022EW4 (checked 580)
# ❌ 2024US2: Missing data sources (checked 581)
# ❌ 2003UB22: Missing data sources (checked 582)
# ✅ 494/9000: 2018RL7 (checked 583)
# ❌ 2024TW5: Missing data sources (checked 584)
# ✅ 495/9000: 2014BM62 (checked 585)
# ✅ 496/9000: 2022WA6 (checked 586)
# ✅ 497/9000: 2014JY79 (checked 587)
# ✅ 498/9000: 2022AV3 (checked 588)
# ❌ 2019BR2: Missing data sources (checked 589)
# ✅ 499/9000: 2015RK35 (checked 590)
# ❌ 1996TC1: Missing data sources (checked 591)
# ✅ 500/9000: 2019SR4 (checked 592)
# ✅ 501/9000: 2021TP8 (checked 593)
# ✅ 502/9000: 2011WF44 (checked 594)
# ✅ 503/9000: 2020BG13 (checked 595)
# ❌ 2024RU3: Missing data sources (checked 596)
# ✅ 504/9000: 2016AX164 (checked 597)
# ❌ 2016RL40: Missing data sources (checked 598)
# ✅ 505/9000: 2024YU7 (checked 599)
# ✅ 506/9000: 2024XT16 (checked 600)
# ✅ 507/9000: 2017QJ2 (checked 601)
# ✅ 508/9000: 2021MT1 (checked 602)
# ✅ 509/9000: 2016WH10 (checked 603)
# ❌ 2008EY84: Missing data sources (checked 604)
# ✅ 510/9000: 2023VR3 (checked 605)
# ✅ 511/9000: 2023CS2 (checked 606)
# ✅ 512/9000: 2021GL1 (checked 607)
# ✅ 513/9000: 1999TV16 (checked 608)
# ✅ 514/9000: 2018TD6 (checked 609)
# ✅ 515/9000: 2019VX3 (checked 610)
# ❌ 2012BH86: Missing data sources (checked 611)
# ✅ 516/9000: 2016CH137 (checked 612)
# ✅ 517/9000: 2012WS10 (checked 613)
# ✅ 518/9000: 2023CF1 (checked 614)
# ✅ 519/9000: 2025BT2 (checked 615)
# ✅ 520/9000: 2016TR2 (checked 616)
# ✅ 521/9000: 2017SB33 (checked 617)
# ✅ 522/9000: 2025MG89 (checked 618)
# ✅ 523/9000: 2025FG6 (checked 619)
# ✅ 524/9000: 2019AJ13 (checked 620)
# ✅ 525/9000: 2022UC21 (checked 621)
# ✅ 526/9000: 2020VS5 (checked 622)
# ✅ 527/9000: 2018BW1 (checked 623)
# ❌ 2022UP6: Missing data sources (checked 624)
# ✅ 528/9000: 2019AN8 (checked 625)
# ✅ 529/9000: 2024XC17 (checked 626)
# ✅ 530/9000: 2019AE3 (checked 627)
# ✅ 531/9000: 2023XE6 (checked 628)
# ✅ 532/9000: 2022WJ11 (checked 629)
# ✅ 533/9000: 2017YP1 (checked 630)
# ❌ 2019WX1: Missing data sources (checked 631)
# ✅ 534/9000: 2020FZ2 (checked 632)
# ✅ 535/9000: 2023HX1 (checked 633)
# ✅ 536/9000: 2019DA2 (checked 634)
# ❌ 2025HL1: Missing data sources (checked 635)
# ✅ 537/9000: 2017YO1 (checked 636)
# ❌ 2020XK5: Missing data sources (checked 637)
# ✅ 538/9000: 2020HD10 (checked 638)
# ✅ 539/9000: 2022JN11 (checked 639)
# ✅ 540/9000: 2023GG3 (checked 640)
# ✅ 541/9000: 2018XF4 (checked 641)
# ✅ 542/9000: 2005EM169 (checked 642)
# ✅ 543/9000: 2021XF5 (checked 643)
# ✅ 544/9000: 2021UF10 (checked 644)
# ✅ 545/9000: 2024JW6 (checked 645)
# ✅ 546/9000: 2011SK189 (checked 646)
# ✅ 547/9000: 2014HA198 (checked 647)
# ✅ 548/9000: 2015KH19 (checked 648)
# ✅ 549/9000: 2023XQ10 (checked 649)
# ✅ 550/9000: 2014HH196 (checked 650)
# ✅ 551/9000: 2019NM4 (checked 651)
# ❌ 2014OB489: Missing data sources (checked 652)
# ✅ 552/9000: 2023RC8 (checked 653)
# ✅ 553/9000: 2022QR36 (checked 654)
# ✅ 554/9000: 2024XL4 (checked 655)
# ✅ 555/9000: 2024QM1 (checked 656)
# ✅ 556/9000: 2014HX2 (checked 657)
# ✅ 557/9000: 2021BV1 (checked 658)
# ❌ 2011AU4: Missing data sources (checked 659)
# ✅ 558/9000: 2024WW2 (checked 660)
# ✅ 559/9000: 2018PK9 (checked 661)
# ✅ 560/9000: 2023MY4 (checked 662)
# ❌ 2019OB1: Missing data sources (checked 663)
# ❌ 2001WM15: Missing data sources (checked 664)
# ✅ 561/9000: 2023BA4 (checked 665)
# ✅ 562/9000: 2016TV19 (checked 666)
# ✅ 563/9000: 2018XX4 (checked 667)
# ✅ 564/9000: 2011KJ20 (checked 668)
# ✅ 565/9000: 2024KT1 (checked 669)
# ✅ 566/9000: 2020WU4 (checked 670)
# ❌ 2015KE57: Missing data sources (checked 671)
# ✅ 567/9000: 2020WN5 (checked 672)
# ✅ 568/9000: 2020KW5 (checked 673)
# ✅ 569/9000: 2000SZ162 (checked 674)
# ✅ 570/9000: 2004BP160 (checked 675)
# ✅ 571/9000: 2021BY1 (checked 676)
# ✅ 572/9000: 2011WS46 (checked 677)
# ✅ 573/9000: 2022HU3 (checked 678)
# ✅ 574/9000: 2025FT2 (checked 679)
# ✅ 575/9000: 2015XS168 (checked 680)
# ✅ 576/9000: 2023BP5 (checked 681)
# ✅ 577/9000: 2022BH9 (checked 682)
# ✅ 578/9000: 2015DC54 (checked 683)
# ✅ 579/9000: 2024WL14 (checked 684)
# ❌ 2020DC1: Missing data sources (checked 685)
# ❌ 2019GM21: Missing data sources (checked 686)
# ✅ 580/9000: 2022QE1 (checked 687)
# ✅ 581/9000: 2022YH5 (checked 688)
# ✅ 582/9000: 2020FD2 (checked 689)
# ✅ 583/9000: 2022SK12 (checked 690)
# ✅ 584/9000: 2024XF2 (checked 691)
# ✅ 585/9000: 2017UM44 (checked 692)
# ✅ 586/9000: 2016AA166 (checked 693)
# ❌ 2022SZ10: Missing data sources (checked 694)
# ✅ 587/9000: 2015FO33 (checked 695)
# ✅ 588/9000: 2024RL1 (checked 696)
# ✅ 589/9000: 2016GB2 (checked 697)
# ✅ 590/9000: 2016TE55 (checked 698)
# ✅ 591/9000: 1999VW25 (checked 699)
# ✅ 592/9000: 2017FQ127 (checked 700)
# ❌ 2017HW2: Missing data sources (checked 701)
# ❌ 2016RY19: Missing data sources (checked 702)
# ✅ 593/9000: 2012GC5 (checked 703)
# ✅ 594/9000: 2018VP5 (checked 704)
# ✅ 595/9000: 2019MD3 (checked 705)
# ✅ 596/9000: 2023VW1 (checked 706)
# ✅ 597/9000: 2016SQ3 (checked 707)
# ❌ 2016JE18: Missing data sources (checked 708)
# ❌ 2024SB2: Missing data sources (checked 709)
# ❌ 2021PK1: Missing data sources (checked 710)
# ✅ 598/9000: 2022BP2 (checked 711)
# ❌ 2019SM8: Missing data sources (checked 712)
# ❌ 2025DN7: Missing data sources (checked 713)
# ❌ 2023BQ1: Missing data sources (checked 714)
# ✅ 599/9000: 2025FS2 (checked 715)
# ✅ 600/9000: 2017AB21 (checked 716)
# ❌ 2024XP4: Missing data sources (checked 717)
# ❌ 2021TX9: Missing data sources (checked 718)
# ✅ 601/9000: 2025HF1 (checked 719)
# ❌ 2022UU9: Missing data sources (checked 720)
# ✅ 602/9000: 2023SF6 (checked 721)
# ✅ 603/9000: 2025FB1 (checked 722)
# ❌ 2013OY3: Missing data sources (checked 723)
# ❌ 2020WD2: Missing data sources (checked 724)
# ❌ 2020QE1: Missing data sources (checked 725)
# ✅ 604/9000: 2024RO13 (checked 726)
# ❌ 2020SZ1: Missing data sources (checked 727)
# ❌ 2017QD2: Missing data sources (checked 728)
# ❌ 2023RH22: Missing data sources (checked 729)
# ❌ 2004LX5: Missing data sources (checked 730)
# ✅ 605/9000: 2024XL6 (checked 731)
# ❌ 2009TM8: Missing data sources (checked 732)
# ❌ 2021XE3: Missing data sources (checked 733)
# ❌ 2016VB1: Missing data sources (checked 734)
# ❌ 2025EF1: Missing data sources (checked 735)
# ❌ 2023SL5: Missing data sources (checked 736)
# ❌ 2017TL6: Missing data sources (checked 737)
# ❌ 2017MA3: Missing data sources (checked 738)
# ❌ 2020ON5: Missing data sources (checked 739)
# ✅ 606/9000: 2022UV1 (checked 740)
# ❌ 2022BP3: Missing data sources (checked 741)
# ❌ 2021XO2: Missing data sources (checked 742)
# ✅ 607/9000: 2023UL9 (checked 743)
# ✅ 608/9000: 2021NR5 (checked 744)
# ✅ 609/9000: 2011TO6 (checked 745)
# ✅ 610/9000: 2005JN3 (checked 746)
# ❌ 2014SV261: Missing data sources (checked 747)
# ❌ 2022CW1: Missing data sources (checked 748)
# ❌ 2022SJ12: Missing data sources (checked 749)
# ❌ 2025DX5: Missing data sources (checked 750)
# ❌ 2024EN4: Missing data sources (checked 751)
# ❌ 2019QV1: Missing data sources (checked 752)
# ❌ 2007UF6: Missing data sources (checked 753)
# ❌ 2025DK3: Missing data sources (checked 754)
# ✅ 611/9000: 2016WR55 (checked 755)
# ❌ 2022DF1: Missing data sources (checked 756)
# ❌ 2018CD3: Missing data sources (checked 757)
# ❌ 2024OB1: Missing data sources (checked 758)
# ❌ 2011BW59: Missing data sources (checked 759)
# ❌ 2009KR21: Missing data sources (checked 760)
# ❌ 2017MG7: Missing data sources (checked 761)
# ❌ 2024EL3: Missing data sources (checked 762)
# ❌ 2022UP13: Missing data sources (checked 763)
# ❌ 2016JM24: Missing data sources (checked 764)
# ❌ 2021AD8: Missing data sources (checked 765)
# ❌ 2022SQ4: Missing data sources (checked 766)
# ✅ 612/9000: 2015VP105 (checked 767)
# ❌ 2022EO4: Missing data sources (checked 768)
# ✅ 613/9000: 2016CP195 (checked 769)
# ✅ 614/9000: 2024YV3 (checked 770)
# ✅ 615/9000: 2010VS71 (checked 771)
# ✅ 616/9000: 2022QJ41 (checked 772)
# ✅ 617/9000: 2016NG22 (checked 773)
# ✅ 618/9000: 2021NV8 (checked 774)
# ✅ 619/9000: 2021GS7 (checked 775)
# ✅ 620/9000: 2017QT32 (checked 776)
# ✅ 621/9000: 2016TL10 (checked 777)
# ✅ 622/9000: 2021RK1 (checked 778)
# ❌ 2017GK6: Missing data sources (checked 779)
# ✅ 623/9000: 2022CE1 (checked 780)
# ❌ 2015TH24: Missing data sources (checked 781)
# ✅ 624/9000: 2004FA5 (checked 782)
# ✅ 625/9000: 2008EG85 (checked 783)
# ❌ 2019UJ1: Missing data sources (checked 784)
# ❌ 2022QJ3: Missing data sources (checked 785)
# ✅ 626/9000: 2023VF2 (checked 786)
# ✅ 627/9000: 2025FO6 (checked 787)
# ❌ 2021RC2: Missing data sources (checked 788)
# ✅ 628/9000: 2014OV299 (checked 789)
# ✅ 629/9000: 2010RO80 (checked 790)
# ✅ 630/9000: 2018PR7 (checked 791)
# ❌ 2024WR1: Missing data sources (checked 792)
# ✅ 631/9000: 2018GQ4 (checked 793)
# ✅ 632/9000: 2021EX3 (checked 794)
# ✅ 633/9000: 2017TE6 (checked 795)
# ✅ 634/9000: 2018VA2 (checked 796)
# ✅ 635/9000: 2013XS21 (checked 797)
# ✅ 636/9000: 2019SJ4 (checked 798)
# ✅ 637/9000: 2024YR6 (checked 799)
# ❌ 2020RF6: Missing data sources (checked 800)
# ❌ 2022WR1: Missing data sources (checked 801)
# ✅ 638/9000: 2016TQ54 (checked 802)
# ✅ 639/9000: 2005VK1 (checked 803)
# ✅ 640/9000: 2025DT1 (checked 804)
# ❌ 2025FL12: Missing data sources (checked 805)
# ✅ 641/9000: 2025HB7 (checked 806)
# ✅ 642/9000: 2012AQ10 (checked 807)
# ✅ 643/9000: 2023VE5 (checked 808)
# ❌ 2014XG32: Missing data sources (checked 809)
# ✅ 644/9000: 2022LE1 (checked 810)
# ✅ 645/9000: 2021PA10 (checked 811)
# ✅ 646/9000: 2019UM9 (checked 812)
# ✅ 647/9000: 2024JN8 (checked 813)
# ✅ 648/9000: 2021AZ3 (checked 814)
# ✅ 649/9000: 2014ME6 (checked 815)
# ✅ 650/9000: 2025HW3 (checked 816)
# ✅ 651/9000: 2025DR6 (checked 817)
# ✅ 652/9000: 2020ST3 (checked 818)
# ✅ 653/9000: 2015XL1 (checked 819)
# ✅ 654/9000: 2011SE58 (checked 820)
# ✅ 655/9000: 2019BK4 (checked 821)
# ✅ 656/9000: 2014WH368 (checked 822)
# ✅ 657/9000: 2023TT19 (checked 823)
# ✅ 658/9000: 2011BA19 (checked 824)
# ✅ 659/9000: 2022WJ3 (checked 825)
# ✅ 660/9000: 2017GM5 (checked 826)
# ✅ 661/9000: 2015HS182 (checked 827)
# ✅ 662/9000: 2020YA2 (checked 828)
# ✅ 663/9000: 2024QR1 (checked 829)
# ✅ 664/9000: 2023XW11 (checked 830)
# ✅ 665/9000: 2024UF4 (checked 831)
# ✅ 666/9000: 2011SG173 (checked 832)
# ✅ 667/9000: 2023VD4 (checked 833)
# ✅ 668/9000: 2024JP10 (checked 834)
# ✅ 669/9000: 2022CH7 (checked 835)
# ✅ 670/9000: 2018SP2 (checked 836)
# ✅ 671/9000: 2024ST1 (checked 837)
# ✅ 672/9000: 2023VP3 (checked 838)
# ✅ 673/9000: 2024TV3 (checked 839)
# ✅ 674/9000: 2021AY3 (checked 840)
# ✅ 675/9000: 2003WT153 (checked 841)
# ✅ 676/9000: 2024BK1 (checked 842)
# ❌ 2017KC36: Missing data sources (checked 843)
# ✅ 677/9000: 2013UU4 (checked 844)
# ✅ 678/9000: 2022UB22 (checked 845)
# ✅ 679/9000: 2015KO122 (checked 846)
# ✅ 680/9000: 2019JE5 (checked 847)
# ✅ 681/9000: 2021RS1 (checked 848)
# ✅ 682/9000: 2021RF10 (checked 849)
# ✅ 683/9000: 2012SJ32 (checked 850)
# ✅ 684/9000: 2022UC34 (checked 851)
# ✅ 685/9000: 2022SW1 (checked 852)
# ✅ 686/9000: 2022SF1 (checked 853)
# ✅ 687/9000: 2019LR6 (checked 854)
# ✅ 688/9000: 2022SY24 (checked 855)
# ✅ 689/9000: 2025NH1 (checked 856)
# ❌ 2010MZ112: Missing data sources (checked 857)
# ❌ 2009RG2: Missing data sources (checked 858)
# ❌ 2014QO433: Missing data sources (checked 859)
# ✅ 690/9000: 2023XQ1 (checked 860)
# ✅ 691/9000: 2020OP2 (checked 861)
# ✅ 692/9000: 2013RR9 (checked 862)
# ✅ 693/9000: 2020RU6 (checked 863)
# ❌ 2018VD5: Missing data sources (checked 864)
# ✅ 694/9000: 2025ML93 (checked 865)
# ✅ 695/9000: 2015KQ18 (checked 866)
# ✅ 696/9000: 2017QM2 (checked 867)
# ✅ 697/9000: 2023XS17 (checked 868)
# ✅ 698/9000: 2016TG10 (checked 869)
# ✅ 699/9000: 2021XJ4 (checked 870)
# ✅ 700/9000: 2017TZ5 (checked 871)
# ✅ 701/9000: 2021VD8 (checked 872)
# ❌ 2024VA1: Missing data sources (checked 873)
# ✅ 702/9000: 2022HQ2 (checked 874)
# ✅ 703/9000: 2023CT1 (checked 875)
# ✅ 704/9000: 2023FP13 (checked 876)
# ✅ 705/9000: 2016DX30 (checked 877)
# ✅ 706/9000: 2017XZ2 (checked 878)
# ❌ 2019KD7: Missing data sources (checked 879)
# ✅ 707/9000: 2015MZ53 (checked 880)
# ✅ 708/9000: 2020DN4 (checked 881)
# ✅ 709/9000: 2007RS9 (checked 882)
# ✅ 710/9000: 2023RM15 (checked 883)
# ✅ 711/9000: 2024WG11 (checked 884)
# ✅ 712/9000: 2010LC64 (checked 885)
# ✅ 713/9000: 2021AC4 (checked 886)
# ✅ 714/9000: 2021RX9 (checked 887)
# ✅ 715/9000: 2022UH9 (checked 888)
# ✅ 716/9000: 2024RQ1 (checked 889)
# ✅ 717/9000: 2013KT1 (checked 890)
# ✅ 718/9000: 2016PR66 (checked 891)
# ❌ 2019UZ10: Missing data sources (checked 892)
# ✅ 719/9000: 2017RR17 (checked 893)
# ✅ 720/9000: 2020HY2 (checked 894)
# ✅ 721/9000: 2017FP127 (checked 895)
# ✅ 722/9000: 2025CP1 (checked 896)
# ✅ 723/9000: 2020FK2 (checked 897)
# ✅ 724/9000: 2018AK12 (checked 898)
# ✅ 725/9000: 2007EK26 (checked 899)
# ✅ 726/9000: 2021LJ6 (checked 900)
# ✅ 727/9000: 2011GP28 (checked 901)
# ✅ 728/9000: 2019UE7 (checked 902)
# ✅ 729/9000: 2023ED1 (checked 903)
# ✅ 730/9000: 2020VR5 (checked 904)
# ✅ 731/9000: 2011BY11 (checked 905)
# ✅ 732/9000: 2017FM1 (checked 906)
# ✅ 733/9000: 2023WT2 (checked 907)
# ✅ 734/9000: 2010SK13 (checked 908)
# ✅ 735/9000: 2023SL43 (checked 909)
# ✅ 736/9000: 2020DO3 (checked 910)
# ✅ 737/9000: 2025JP1 (checked 911)
# ✅ 738/9000: 2024TK1 (checked 912)
# ✅ 739/9000: 2018GW1 (checked 913)
# ✅ 740/9000: 2017VZ13 (checked 914)
# ✅ 741/9000: 2016TA11 (checked 915)
# ✅ 742/9000: 2021CE5 (checked 916)
# ✅ 743/9000: 2024XY15 (checked 917)
# ✅ 744/9000: 2012VZ19 (checked 918)
# ❌ 2024UD1: Missing data sources (checked 919)
# ✅ 745/9000: 2024OO2 (checked 920)
# ✅ 746/9000: 2024FV1 (checked 921)
# ✅ 747/9000: 2024BQ1 (checked 922)
# ❌ 2021LC1: Missing data sources (checked 923)
# ✅ 748/9000: 2023XG1 (checked 924)
# ✅ 749/9000: 2021RS14 (checked 925)
# ✅ 750/9000: 2021TT4 (checked 926)
# ✅ 751/9000: 2019WJ4 (checked 927)
# ✅ 752/9000: 2024CO2 (checked 928)
# ❌ 2024TO6: Missing data sources (checked 929)
# ❌ 2023XS10: Missing data sources (checked 930)
# ✅ 753/9000: 2024XZ3 (checked 931)
# ✅ 754/9000: 2025HR4 (checked 932)
# ✅ 755/9000: 2009BG81 (checked 933)
# ✅ 756/9000: 2019FB2 (checked 934)
# ✅ 757/9000: 2025KP7 (checked 935)
# ✅ 758/9000: 2018VT4 (checked 936)
# ✅ 759/9000: 2011SK68 (checked 937)
# ✅ 760/9000: 2021AW6 (checked 938)
# ✅ 761/9000: 2008FJ7 (checked 939)
# ✅ 762/9000: 2007VJ3 (checked 940)
# ✅ 763/9000: 2019OP3 (checked 941)
# ✅ 764/9000: 2024WL11 (checked 942)
# ✅ 765/9000: 2021TE4 (checked 943)
# ✅ 766/9000: 2024WU24 (checked 944)
# ❌ 2024SY1: Missing data sources (checked 945)
# ✅ 767/9000: 2017ST10 (checked 946)
# ✅ 768/9000: 2014FG33 (checked 947)
# ✅ 769/9000: 2011TH5 (checked 948)
# ✅ 770/9000: 2024AF3 (checked 949)
# ❌ 2024FK1: Missing data sources (checked 950)
# ✅ 771/9000: 2019CF3 (checked 951)
# ✅ 772/9000: 2017YD2 (checked 952)
# ✅ 773/9000: 2010UL7 (checked 953)
# ✅ 774/9000: 2023JO1 (checked 954)
# ❌ 2019YK2: Missing data sources (checked 955)
# ✅ 775/9000: 2014WX4 (checked 956)
# ✅ 776/9000: 2016HX23 (checked 957)
# ✅ 777/9000: 2023XZ11 (checked 958)
# ✅ 778/9000: 2022QK7 (checked 959)
# ❌ 2020TR1: Missing data sources (checked 960)
# ✅ 779/9000: 2021TU12 (checked 961)
# ✅ 780/9000: 2019JG6 (checked 962)
# ✅ 781/9000: 2012KT42 (checked 963)
# ❌ 2017BG136: Missing data sources (checked 964)
# ✅ 782/9000: 2021VZ1 (checked 965)
# ✅ 783/9000: 2006BR98 (checked 966)
# ✅ 784/9000: 2022SB8 (checked 967)
# ❌ 2019WE1: Missing data sources (checked 968)
# ❌ 2005OH3: Missing data sources (checked 969)
# ✅ 785/9000: 2023VP8 (checked 970)
# ✅ 786/9000: 2020XH6 (checked 971)
# ❌ 2021HX2: Missing data sources (checked 972)
# ✅ 787/9000: 2022TK1 (checked 973)
# ❌ 2024TX6: Missing data sources (checked 974)
# ✅ 788/9000: 2021AV6 (checked 975)
# ❌ 2015HT10: Missing data sources (checked 976)
# ✅ 789/9000: 2017KY4 (checked 977)
# ✅ 790/9000: 2016XP1 (checked 978)
# ❌ 2021GC8: Missing data sources (checked 979)
# ✅ 791/9000: 2021AG6 (checked 980)
# ✅ 792/9000: 2008TC3 (checked 981)
# ✅ 793/9000: 2025DV7 (checked 982)
# ❌ 2025MT1: Missing data sources (checked 983)
# ✅ 794/9000: 2023QF6 (checked 984)
# ❌ 2014WE6: Missing data sources (checked 985)
# ✅ 795/9000: 2024YB13 (checked 986)
# ✅ 796/9000: 2020PM2 (checked 987)
# ❌ 2019AX8: Missing data sources (checked 988)
# ✅ 797/9000: 2020JE2 (checked 989)
# ✅ 798/9000: 2020KU2 (checked 990)
# ✅ 799/9000: 2022EL1 (checked 991)
# ✅ 800/9000: 2014US56 (checked 992)
# ✅ 801/9000: 2017CR1 (checked 993)
# ✅ 802/9000: 2017PD25 (checked 994)
# ✅ 803/9000: 2021AT4 (checked 995)
# ✅ 804/9000: 2019AJ14 (checked 996)
# ❌ 2017FQ146: Missing data sources (checked 997)
# ✅ 805/9000: 2024GB1 (checked 998)
# ✅ 806/9000: 2011KY15 (checked 999)
# ✅ 807/9000: 2014UL175 (checked 1000)
# ✅ 808/9000: 2023SL8 (checked 1001)
# ✅ 809/9000: 2012BC62 (checked 1002)
# ✅ 810/9000: 2019GH19 (checked 1003)
# ✅ 811/9000: 2022WP9 (checked 1004)
# ❌ 2010TV54: Missing data sources (checked 1005)
# ✅ 812/9000: 2017FS91 (checked 1006)
# ✅ 813/9000: 2008DH5 (checked 1007)
# ❌ 2021KW1: Missing data sources (checked 1008)
# ✅ 814/9000: 2009WD52 (checked 1009)
# ✅ 815/9000: 2018VV7 (checked 1010)
# ✅ 816/9000: 2020RV4 (checked 1011)
# ❌ 2023VY20: Missing data sources (checked 1012)
# ✅ 817/9000: 2011CE22 (checked 1013)
# ❌ 2021GO10: Missing data sources (checked 1014)
# ❌ 2019BG3: Missing data sources (checked 1015)
# ✅ 818/9000: 2024OS1 (checked 1016)
# ✅ 819/9000: 2019VR3 (checked 1017)
# ✅ 820/9000: 2023LP1 (checked 1018)
# ✅ 821/9000: 2012VD37 (checked 1019)
# ✅ 822/9000: 2022SF10 (checked 1020)
# ❌ 2024AB3: Missing data sources (checked 1021)
# ✅ 823/9000: 2019LW4 (checked 1022)
# ✅ 824/9000: 2018RO8 (checked 1023)
# ✅ 825/9000: 2011CJ33 (checked 1024)
# ✅ 826/9000: 2021TM10 (checked 1025)
# ❌ 2020DJ2: Missing data sources (checked 1026)
# ✅ 827/9000: 2020DQ16 (checked 1027)
# ✅ 828/9000: 2025HW1 (checked 1028)
# ✅ 829/9000: 2022UK11 (checked 1029)
# ✅ 830/9000: 2021NM1 (checked 1030)
# ✅ 831/9000: 2024EM2 (checked 1031)
# ✅ 832/9000: 2019OZ3 (checked 1032)
# ❌ 2021XK4: Missing data sources (checked 1033)
# ✅ 833/9000: 2023PB1 (checked 1034)
# ❌ 2021UF3: Missing data sources (checked 1035)
# ✅ 834/9000: 2022UU12 (checked 1036)
# ✅ 835/9000: 2018FL2 (checked 1037)
# ✅ 836/9000: 2011PC2 (checked 1038)
# ❌ 2023MN1: Missing data sources (checked 1039)
# ✅ 837/9000: 2020SF6 (checked 1040)
# ❌ 2023XO10: Missing data sources (checked 1041)
# ❌ 2020JQ1: Missing data sources (checked 1042)
# ❌ 2025FC1: Missing data sources (checked 1043)
# ✅ 838/9000: 2016GC252 (checked 1044)
# ✅ 839/9000: 2021AC6 (checked 1045)
# ✅ 840/9000: 2021RU5 (checked 1046)
# ✅ 841/9000: 2014UG56 (checked 1047)
# ✅ 842/9000: 2021JA2 (checked 1048)
# ✅ 843/9000: 2024FL5 (checked 1049)
# ✅ 844/9000: 2025DS4 (checked 1050)
# ✅ 845/9000: 2019SV10 (checked 1051)
# ✅ 846/9000: 2007VF184 (checked 1052)
# ❌ 2014BY43: Missing data sources (checked 1053)
# ✅ 847/9000: 2023KD4 (checked 1054)
# ✅ 848/9000: 2015XH55 (checked 1055)
# ✅ 849/9000: 2021VL22 (checked 1056)
# ✅ 850/9000: 2018WC2 (checked 1057)
# ✅ 851/9000: 2020TZ6 (checked 1058)
# ✅ 852/9000: 2013BV2 (checked 1059)
# ✅ 853/9000: 2009FA5 (checked 1060)
# ❌ 2020RO4: Missing data sources (checked 1061)
# ✅ 854/9000: 2020HR8 (checked 1062)
# ✅ 855/9000: 2021EQ3 (checked 1063)
# ❌ 2022QT36: Missing data sources (checked 1064)
# ✅ 856/9000: 2024MB1 (checked 1065)
# ❌ 2005WG4: Missing data sources (checked 1066)
# ✅ 857/9000: 2024SJ1 (checked 1067)
# ✅ 858/9000: 2019DE1 (checked 1068)
# ✅ 859/9000: 2024XX2 (checked 1069)
# ❌ 2024FQ3: Missing data sources (checked 1070)
# ✅ 860/9000: 2023RD15 (checked 1071)
# ✅ 861/9000: 2022SG18 (checked 1072)
# ❌ 2015KC57: Missing data sources (checked 1073)
# ✅ 862/9000: 2023FX13 (checked 1074)
# ❌ 2017UM7: Missing data sources (checked 1075)
# ✅ 863/9000: 2014HO198 (checked 1076)
# ✅ 864/9000: 2024UZ9 (checked 1077)
# ✅ 865/9000: 2023NA1 (checked 1078)
# ✅ 866/9000: 2023EN1 (checked 1079)
# ✅ 867/9000: 2024PC4 (checked 1080)
# ✅ 868/9000: 2015XA169 (checked 1081)
# ✅ 869/9000: 2023SS5 (checked 1082)
# ✅ 870/9000: 2020HF5 (checked 1083)
# ✅ 871/9000: 2019BK2 (checked 1084)
# ✅ 872/9000: 2012BL11 (checked 1085)
# ✅ 873/9000: 2006YX2 (checked 1086)
# ❌ 2013LY28: Missing data sources (checked 1087)
# ✅ 874/9000: 2021XT1 (checked 1088)
# ❌ 2014WQ362: Missing data sources (checked 1089)
# ✅ 875/9000: 2010UM7 (checked 1090)
# ✅ 876/9000: 2025BJ1 (checked 1091)
# ✅ 877/9000: 2024GA6 (checked 1092)
# ✅ 878/9000: 2021QY3 (checked 1093)
# ✅ 879/9000: 2019FX1 (checked 1094)
# ❌ 2023VW7: Missing data sources (checked 1095)
# ✅ 880/9000: 2023TW26 (checked 1096)
# ✅ 881/9000: 2024TU8 (checked 1097)
# ✅ 882/9000: 2015FA117 (checked 1098)
# ✅ 883/9000: 2021QX1 (checked 1099)
# ✅ 884/9000: 2018TV1 (checked 1100)
# ✅ 885/9000: 2009UT19 (checked 1101)
# ✅ 886/9000: 2021RP3 (checked 1102)
# ✅ 887/9000: 2022UQ7 (checked 1103)
# ✅ 888/9000: 2019JT5 (checked 1104)
# ✅ 889/9000: 2022DO3 (checked 1105)
# ✅ 890/9000: 2020UJ4 (checked 1106)
# ✅ 891/9000: 2024EH4 (checked 1107)
# ✅ 892/9000: 2024RL8 (checked 1108)
# ❌ 2023QM2: Missing data sources (checked 1109)
# ✅ 893/9000: 2019EF2 (checked 1110)
# ✅ 894/9000: 2022YU2 (checked 1111)
# ✅ 895/9000: 2019UN10 (checked 1112)
# ❌ 2010PJ9: Missing data sources (checked 1113)
# ❌ 2016ES155: Missing data sources (checked 1114)
# ✅ 896/9000: 2023FD4 (checked 1115)
# ✅ 897/9000: 2021VB7 (checked 1116)
# ❌ 2010RS80: Missing data sources (checked 1117)
# ❌ 2018DD2: Missing data sources (checked 1118)
# ✅ 898/9000: 2006BV39 (checked 1119)
# ✅ 899/9000: 2010RV11 (checked 1120)
# ❌ 2023GF3: Missing data sources (checked 1121)
# ❌ 2015FT117: Missing data sources (checked 1122)
# ✅ 900/9000: 2023XO13 (checked 1123)
# ✅ 901/9000: 2021AC2 (checked 1124)
# ✅ 902/9000: 2011FU9 (checked 1125)
# ✅ 903/9000: 2021VN5 (checked 1126)
# ✅ 904/9000: 2015VT64 (checked 1127)
# ✅ 905/9000: 2021UP3 (checked 1128)
# ✅ 906/9000: 2019AX14 (checked 1129)
# ✅ 907/9000: 2018RF8 (checked 1130)
# ✅ 908/9000: 2012UV158 (checked 1131)
# ✅ 909/9000: 2025DC50 (checked 1132)
# ✅ 910/9000: 2017QO16 (checked 1133)
# ✅ 911/9000: 2020TK3 (checked 1134)
# ✅ 912/9000: 2016WN7 (checked 1135)
# ✅ 913/9000: 2016GO134 (checked 1136)
# ✅ 914/9000: 2017PK25 (checked 1137)
# ✅ 915/9000: 2014HO2 (checked 1138)
# ✅ 916/9000: 2023BK4 (checked 1139)
# ✅ 917/9000: 2024WL2 (checked 1140)
# ✅ 918/9000: 2024TY3 (checked 1141)
# ❌ 2017GT4: Missing data sources (checked 1142)
# ❌ 2025FY1: Missing data sources (checked 1143)
# ✅ 919/9000: 2013EX108 (checked 1144)
# ✅ 920/9000: 2024XG10 (checked 1145)
# ❌ 2022US10: Missing data sources (checked 1146)
# ✅ 921/9000: 2018TG3 (checked 1147)
# ✅ 922/9000: 2023UT7 (checked 1148)
# ✅ 923/9000: 2018PD20 (checked 1149)
# ✅ 924/9000: 2004OD4 (checked 1150)
# ✅ 925/9000: 2017DX35 (checked 1151)
# ✅ 926/9000: 2019UD5 (checked 1152)
# ✅ 927/9000: 2025AY2 (checked 1153)
# ✅ 928/9000: 2023TA5 (checked 1154)
# ✅ 929/9000: 2019UF1 (checked 1155)
# ✅ 930/9000: 2002GM5 (checked 1156)
# ✅ 931/9000: 2011WN2 (checked 1157)
# ✅ 932/9000: 2011EE41 (checked 1158)
# ✅ 933/9000: 2017WA28 (checked 1159)
# ✅ 934/9000: 2014UA58 (checked 1160)
# ✅ 935/9000: 2005EL70 (checked 1161)
# ✅ 936/9000: 2023TE2 (checked 1162)
# ❌ 2023BC2: Missing data sources (checked 1163)
# ❌ 2021LL15: Missing data sources (checked 1164)
# ❌ 2024JH17: Missing data sources (checked 1165)
# ✅ 937/9000: 2014QR363 (checked 1166)
# ✅ 938/9000: 2023BF6 (checked 1167)
# ✅ 939/9000: 2022SV1 (checked 1168)
# ✅ 940/9000: 2022WP3 (checked 1169)
# ❌ 2016JL38: Missing data sources (checked 1170)
# ✅ 941/9000: 2011OY4 (checked 1171)
# ✅ 942/9000: 2024RA7 (checked 1172)
# ✅ 943/9000: 2015JG1 (checked 1173)
# ✅ 944/9000: 2013TA6 (checked 1174)
# ✅ 945/9000: 2025FF2 (checked 1175)
# ✅ 946/9000: 2016BQ15 (checked 1176)
# ✅ 947/9000: 2024XD6 (checked 1177)
# ✅ 948/9000: 2017DF38 (checked 1178)
# ✅ 949/9000: 2022AM1 (checked 1179)
# ✅ 950/9000: 2018FY2 (checked 1180)
# ✅ 951/9000: 2021NB6 (checked 1181)
# ✅ 952/9000: 2019UA2 (checked 1182)
# ✅ 953/9000: 2020HF9 (checked 1183)
# ✅ 954/9000: 2023UO2 (checked 1184)
# ✅ 955/9000: 2012XL55 (checked 1185)
# ✅ 956/9000: 2019LB1 (checked 1186)
# ✅ 957/9000: 2018VU2 (checked 1187)
# ✅ 958/9000: 2019AE9 (checked 1188)
# ❌ 2009QJ2: Missing data sources (checked 1189)
# ✅ 959/9000: 2020DL4 (checked 1190)
# ✅ 960/9000: 2023ST1 (checked 1191)
# ✅ 961/9000: 2013AR72 (checked 1192)
# ✅ 962/9000: 2017YF8 (checked 1193)
# ✅ 963/9000: 2020JV1 (checked 1194)
# ✅ 964/9000: 2017RE15 (checked 1195)
# ✅ 965/9000: 2020VW4 (checked 1196)
# ✅ 966/9000: 2024DC1 (checked 1197)
# ✅ 967/9000: 2008EC32 (checked 1198)
# ✅ 968/9000: 2011EN11 (checked 1199)
# ✅ 969/9000: 2017BH30 (checked 1200)
# ✅ 970/9000: 2008HQ3 (checked 1201)
# ✅ 971/9000: 2022UC13 (checked 1202)
# ✅ 972/9000: 2024SA5 (checked 1203)
# ✅ 973/9000: 2009WE106 (checked 1204)
# ✅ 974/9000: 2023UL1 (checked 1205)
# ❌ 2023TK4: Missing data sources (checked 1206)
# ✅ 975/9000: 2012EP3 (checked 1207)
# ✅ 976/9000: 2016FR60 (checked 1208)
# ✅ 977/9000: 2022GV2 (checked 1209)
# ✅ 978/9000: 2022DX1 (checked 1210)
# ❌ 2009HH21: Missing data sources (checked 1211)
# ✅ 979/9000: 2024XT2 (checked 1212)
# ✅ 980/9000: 2023BB8 (checked 1213)
# ❌ 2006WA30: Missing data sources (checked 1214)
# ❌ 2005US6: Missing data sources (checked 1215)
# ✅ 981/9000: 2023HP5 (checked 1216)
# ✅ 982/9000: 2021LV5 (checked 1217)
# ✅ 983/9000: 2020BX9 (checked 1218)
# ✅ 984/9000: 2023VJ5 (checked 1219)
# ❌ 2010MZ1: Missing data sources (checked 1220)
# ✅ 985/9000: 2022AC4 (checked 1221)
# ❌ 2023TP1: Missing data sources (checked 1222)
# ✅ 986/9000: 2023LQ1 (checked 1223)
# ✅ 987/9000: 2017YC6 (checked 1224)
# ✅ 988/9000: 2021GS16 (checked 1225)
# ✅ 989/9000: 2018AZ3 (checked 1226)
# ✅ 990/9000: 2014HK197 (checked 1227)
# ✅ 991/9000: 2024AR2 (checked 1228)
# ✅ 992/9000: 2019TP3 (checked 1229)
# ✅ 993/9000: 2019BY3 (checked 1230)
# ❌ 2018GC2: Missing data sources (checked 1231)
# ✅ 994/9000: 2012BF27 (checked 1232)
# ✅ 995/9000: 2025MQ1 (checked 1233)
# ✅ 996/9000: 2017UW5 (checked 1234)
# ✅ 997/9000: 2024NJ1 (checked 1235)
# ✅ 998/9000: 2014KW76 (checked 1236)
# ❌ 2019CM2: Missing data sources (checked 1237)
# ❌ 2016PL38: Missing data sources (checked 1238)
# ✅ 999/9000: 2016LQ51 (checked 1239)
# ✅ 1000/9000: 2016VW5 (checked 1240)
# ✅ 1001/9000: 2023SO6 (checked 1241)
# ✅ 1002/9000: 2021VJ5 (checked 1242)
# ✅ 1003/9000: 2016EE27 (checked 1243)
# ✅ 1004/9000: 2016ET1 (checked 1244)
# ✅ 1005/9000: 2024XC15 (checked 1245)
# ❌ 2023UA3: Missing data sources (checked 1246)
# ❌ 2018ST1: Missing data sources (checked 1247)
# ✅ 1006/9000: 2021XF3 (checked 1248)
# ✅ 1007/9000: 2019XO3 (checked 1249)
# ✅ 1008/9000: 2025DA30 (checked 1250)
# ❌ 2007FO3: Missing data sources (checked 1251)
# ❌ 2020VR4: Missing data sources (checked 1252)
# ✅ 1009/9000: 2023XL13 (checked 1253)
# ✅ 1010/9000: 2019KK3 (checked 1254)
# ✅ 1011/9000: 2021LL9 (checked 1255)
# ✅ 1012/9000: 2020VP2 (checked 1256)
# ✅ 1013/9000: 2011SL189 (checked 1257)
# ✅ 1014/9000: 2023QR1 (checked 1258)
# ❌ 2014HY197: Missing data sources (checked 1259)
# ✅ 1015/9000: 2013EY89 (checked 1260)
# ✅ 1016/9000: 2023UK4 (checked 1261)
# ✅ 1017/9000: 2019SD1 (checked 1262)
# ✅ 1018/9000: 2020BZ1 (checked 1263)
# ❌ 2023UZ1: Missing data sources (checked 1264)
# ✅ 1019/9000: 2010GK65 (checked 1265)
# ✅ 1020/9000: 2024LQ5 (checked 1266)
# ✅ 1021/9000: 2021PK5 (checked 1267)
# ✅ 1022/9000: 2022QE2 (checked 1268)
# ✅ 1023/9000: 2014HZ191 (checked 1269)
# ✅ 1024/9000: 2020PE1 (checked 1270)
# ✅ 1025/9000: 2008UD202 (checked 1271)
# ❌ 2022EW2: Missing data sources (checked 1272)
# ✅ 1026/9000: 2021XS4 (checked 1273)
# ✅ 1027/9000: 2022SA8 (checked 1274)
# ✅ 1028/9000: 2010LB67 (checked 1275)
# ✅ 1029/9000: 2011JV10 (checked 1276)
# ❌ 2022AX4: Missing data sources (checked 1277)
# ✅ 1030/9000: 2013VH2 (checked 1278)
# ❌ 2021CU8: Missing data sources (checked 1279)
# ✅ 1031/9000: 2017OA69 (checked 1280)
# ✅ 1032/9000: 2023TY9 (checked 1281)
# ✅ 1033/9000: 2021TQ3 (checked 1282)
# ✅ 1034/9000: 2012DK14 (checked 1283)
# ✅ 1035/9000: 2008DV22 (checked 1284)
# ✅ 1036/9000: 2020ST4 (checked 1285)
# ✅ 1037/9000: 2024BT6 (checked 1286)
# ✅ 1038/9000: 2023VY7 (checked 1287)
# ✅ 1039/9000: 2011BY10 (checked 1288)
# ✅ 1040/9000: 2014HU46 (checked 1289)
# ✅ 1041/9000: 2025KT1 (checked 1290)
# ❌ 2017QN1: Missing data sources (checked 1291)
# ...
# Skipping night 1 (2015-02-18) due to insufficient observations: 1
# Skipping night 2 for 2023TR1 due to non-physical fit estimations
# Skipping night 1 for 2021PA211 due to non-physical fit estimations
# REJECTED: Missing data for 2024JY16
# REJECTED: Missing data for 2022WP6
# Skipping night 4 (2020-03-24) due to insufficient observations: 1
# Skipping night 1 (2024-10-08) due to insufficient observations: 1
# Skipping night 2 (2022-10-18) due to insufficient observations: 1
# Skipping night 1 (2024-11-21) due to insufficient observations: 1
# Skipping night 3 (2022-05-28) due to insufficient observations: 1
# Skipping night 4 (2022-05-29) due to insufficient observations: 1
# Skipping night 4 for 2017QQ17 due to non-physical fit estimations
# Skipping night 2 (2023-05-27) due to insufficient observations: 1
# Skipping night 3 (2023-05-28) due to insufficient observations: 1
# REJECTED: Missing data for 2007FN3
# Skipping night 2 for 2016VZ1 due to non-physical fit estimations
# Skipping night 2 (2025-05-01) due to insufficient observations: 1
# REJECTED: Missing data for 2021AJ3
# Skipping night 5 (2018-03-15) due to insufficient observations: 1
# Skipping night 7 for 2016LJ8 due to non-physical fit estimations
# Skipping night 1 (2020-10-20) due to insufficient observations: 1
# Skipping night 1 (2021-10-24) due to insufficient observations: 1
# REJECTED: Missing data for 2017DS34
# REJECTED: Missing data for 2022YN8
# Skipping night 5 for 2020CY1 due to non-physical fit estimations
# Skipping night 1 (2022-05-22) due to insufficient observations: 1
# Skipping night 2 (2018-01-24) due to insufficient observations: 1
# Skipping night 4 (2018-01-27) due to insufficient observations: 1
# REJECTED: Missing data for 2014AJ51
# Skipping night 3 for 2021JB6 due to non-physical fit estimations
# Skipping night 3 (2021-03-25) due to insufficient observations: 1
# REJECTED: Missing data for 2020BK7
# Skipping night 8 (2024-03-19) due to insufficient observations: 1
# Skipping night 3 (2020-10-16) due to insufficient observations: 1
# Skipping night 3 (2025-03-30) due to insufficient observations: 1
# Skipping night 1 for 2007RC20 due to non-physical fit estimations
# Skipping night 1 (2020-01-23) due to insufficient observations: 1
# Skipping night 1 for 2020RX1 due to non-physical fit estimations
# Skipping night 2 for 2000QX69 due to non-physical fit estimations
# Skipping night 1 (2020-07-20) due to insufficient observations: 1
# Skipping night 3 (2020-07-25) due to insufficient observations: 1
# Skipping night 4 (2024-09-07) due to insufficient observations: 1
# Skipping night 3 for 2023HF4 due to non-physical fit estimations
# Skipping night 1 (2021-07-03) due to insufficient observations: 1
# Skipping night 3 (2018-02-12) due to insufficient observations: 1
# Skipping night 3 for 2025KE1 due to non-physical fit estimations
# Skipping night 2 (2016-10-12) due to insufficient observations: 1
# Skipping night 1 for 2020QY2 due to non-physical fit estimations
# REJECTED: No valid nights with enough observations for 2020QY2
# REJECTED: Missing data for 2021NV5
# REJECTED: Missing data for 2021PN1
# REJECTED: Missing data for 2019UO4
# Skipping night 5 for 2010GA6 due to non-physical fit estimations
# Skipping night 4 (2022-03-05) due to insufficient observations: 1
# Skipping night 1 for 2024TK22 due to non-physical fit estimations
# REJECTED: No valid nights with enough observations for 2024TK22
# Skipping night 7 (2015-11-15) due to insufficient observations: 1
# Skipping night 3 (2010-11-11) due to insufficient observations: 1
# Skipping night 3 for 2011UK21 due to non-physical fit estimations
# REJECTED: Missing data for 2020UD5
# REJECTED: Missing data for 2014UZ57
# Skipping night 4 for 2018EB4 due to non-physical fit estimations
# REJECTED: Missing data for 2006DR62
# Skipping night 1 (2013-04-08) due to insufficient observations: 1
# Skipping night 4 (2013-04-12) due to insufficient observations: 1
# Skipping night 2 for 2018QS1 due to non-physical fit estimations
# Skipping night 1 (2022-08-21) due to insufficient observations: 1
# Skipping night 1 for 2020VH5 due to non-physical fit estimations
# Skipping night 5 (2021-05-20) due to insufficient observations: 1
# Skipping night 5 for 2018CB2 due to non-physical fit estimations
# Skipping night 1 for 2020SA2 due to non-physical fit estimations
# Skipping night 7 for 2024UU1 due to non-physical fit estimations
# Skipping night 3 (2024-09-02) due to insufficient observations: 1
# Skipping night 2 for 2014UF56 due to non-physical fit estimations
# Skipping night 6 for 2017XK1 due to non-physical fit estimations
# Skipping night 2 for 2024RB11 due to non-physical fit estimations
# Skipping night 1 (2021-08-11) due to insufficient observations: 1
# Skipping night 2 (2019-10-25) due to insufficient observations: 1
# Skipping night 4 for 2022SJ9 due to non-physical fit estimations
# Skipping night 5 (2018-11-14) due to insufficient observations: 1
# Skipping night 1 (2021-11-07) due to insufficient observations: 1
# Skipping night 3 (2015-02-24) due to insufficient observations: 1
# REJECTED: Missing data for 2022UA6
# Skipping night 3 (2024-12-30) due to insufficient observations: 1
# Skipping night 4 (2024-12-31) due to insufficient observations: 1
# Skipping night 2 for 2022UD7 due to non-physical fit estimations
# Skipping night 1 (2018-01-22) due to insufficient observations: 1
# Skipping night 2 (2017-08-17) due to insufficient observations: 1
# Skipping night 4 (2023-09-13) due to insufficient observations: 1
# Skipping night 1 (2024-11-21) due to insufficient observations: 1
# REJECTED: Missing data for 2023TF3
# Skipping night 2 (2018-01-29) due to insufficient observations: 1
# Skipping night 3 (2021-02-10) due to insufficient observations: 1
# Skipping night 1 for 2021SW1 due to non-physical fit estimations
# Skipping night 8 (2019-06-08) due to insufficient observations: 1
# REJECTED: Missing data for 2015NR2
# Skipping night 2 (2019-01-07) due to insufficient observations: 1
# Skipping night 3 (2019-01-08) due to insufficient observations: 1
# Skipping night 6 (2010-02-22) due to insufficient observations: 1
# Skipping night 3 (2015-01-29) due to insufficient observations: 1
# Skipping night 4 (2022-04-03) due to insufficient observations: 1
# Skipping night 5 for 2018RA1 due to non-physical fit estimations
# Skipping night 2 for 2013VJ11 due to non-physical fit estimations
# Skipping night 1 (2012-11-02) due to insufficient observations: 1
# REJECTED: Missing data for 2023VG24
# REJECTED: Missing data for 2020BL11
# REJECTED: Missing data for 2025HR3
# REJECTED: Missing data for 2019UO8
# Skipping night 3 (2019-09-30) due to insufficient observations: 1
# Skipping night 2 for 2014AW32 due to non-physical fit estimations
# Skipping night 5 for 2020FF1 due to non-physical fit estimations
# REJECTED: Missing data for 2009SU171
# /tmp/ipykernel_133967/1737075548.py:216: RankWarning: Polyfit may be poorly conditioned
#   a_fit = np.polyfit(t, alpha, 1)
# /tmp/ipykernel_133967/1737075548.py:217: RankWarning: Polyfit may be poorly conditioned
#   d_fit = np.polyfit(t, delta, 1)
# Skipping night 4 for 2014HM4 due to non-physical fit estimations
# Skipping night 3 (2001-11-15) due to insufficient observations: 1
# REJECTED: Missing data for 2025DD15
# Skipping night 1 (2021-08-27) due to insufficient observations: 1
# Skipping night 5 (2021-05-15) due to insufficient observations: 1
# Skipping night 4 for 2017MO8 due to non-physical fit estimations
# Skipping night 3 (2024-03-15) due to insufficient observations: 1
# Skipping night 4 (2024-03-16) due to insufficient observations: 1
# Skipping night 3 (2013-06-12) due to insufficient observations: 1
# Skipping night 5 (2014-08-30) due to insufficient observations: 1
# REJECTED: Missing data for 2025EN2
# Skipping night 2 for 2021SZ1 due to non-physical fit estimations
# REJECTED: Missing data for 2024QK2
# REJECTED: Missing data for 2015YH1
# Skipping night 3 (2023-12-09) due to insufficient observations: 1
# Skipping night 6 (2017-10-23) due to insufficient observations: 1
# Skipping night 4 for 2023VD3 due to non-physical fit estimations
# Skipping night 3 for 2025HP4 due to non-physical fit estimations
# Skipping night 1 for 2024OG2 due to non-physical fit estimations
# Skipping night 2 for 2018WG2 due to non-physical fit estimations
# Skipping night 2 for 2021TG1 due to non-physical fit estimations
# Skipping night 3 for 2021TG1 due to non-physical fit estimations
# Skipping night 1 for 2025FV12 due to non-physical fit estimations
# REJECTED: No valid nights with enough observations for 2025FV12
# Skipping night 2 for 2015VY105 due to non-physical fit estimations
# Skipping night 5 for 2016GP221 due to non-physical fit estimations
# REJECTED: Missing data for 2019MD1
# Skipping night 5 for 2023CG2 due to non-physical fit estimations
# REJECTED: Missing data for 2023QT2
# Skipping night 3 for 2016EV28 due to non-physical fit estimations
# Skipping night 9 (2020-12-18) due to insufficient observations: 1
# Skipping night 5 (2025-06-26) due to insufficient observations: 1
# Skipping night 4 (2025-07-10) due to insufficient observations: 1
# Skipping night 5 (2025-07-11) due to insufficient observations: 1
# Skipping night 4 (2021-10-09) due to insufficient observations: 1
# Skipping night 2 for 2023QT1 due to non-physical fit estimations
# REJECTED: Missing data for 2019CC2
# Skipping night 4 (2015-04-24) due to insufficient observations: 1
# REJECTED: Missing data for 2022GE2
# Skipping night 2 for 2024RL2 due to non-physical fit estimations
# Skipping night 4 for 2014AD16 due to non-physical fit estimations
# Skipping night 1 (2018-11-08) due to insufficient observations: 1
# Skipping night 4 for 2017SM2 due to non-physical fit estimations
# Skipping night 4 (2021-06-17) due to insufficient observations: 1
# Skipping night 6 (2024-02-22) due to insufficient observations: 1
# Skipping night 1 (2023-10-08) due to insufficient observations: 1
# Skipping night 3 for 2020QO1 due to non-physical fit estimations
# Skipping night 1 (2023-09-09) due to insufficient observations: 1
# Skipping night 4 (2015-04-15) due to insufficient observations: 1
# Skipping night 2 (2021-10-13) due to insufficient observations: 1
# Skipping night 4 for 2021TY14 due to non-physical fit estimations
# Skipping night 3 for 2022DW1 due to non-physical fit estimations
# REJECTED: Missing data for 2021VR6
# Skipping night 1 (2019-11-02) due to insufficient observations: 1
# Skipping night 2 (2021-10-31) due to insufficient observations: 1
# Skipping night 6 for 2015QT3 due to non-physical fit estimations
# Skipping night 4 (2024-08-10) due to insufficient observations: 1
# Skipping night 5 (2024-08-11) due to insufficient observations: 1
# Skipping night 1 (2015-12-06) due to insufficient observations: 1
# Skipping night 3 for 2020KC5 due to non-physical fit estimations
# Skipping night 4 for 2020KC5 due to non-physical fit estimations
# Skipping night 1 (2010-11-03) due to insufficient observations: 1
# REJECTED: Missing data for 2015HO182
# Skipping night 1 (2017-01-03) due to insufficient observations: 1
# Skipping night 4 (2014-05-28) due to insufficient observations: 1
# Skipping night 3 for 2018SD3 due to non-physical fit estimations
# REJECTED: Missing data for 2014HE198
# Skipping night 3 for 2012XE54 due to non-physical fit estimations
# Skipping night 1 (2017-01-24) due to insufficient observations: 1
# Skipping night 1 for 2023VU2 due to non-physical fit estimations
# Skipping night 1 (2020-10-16) due to insufficient observations: 1
# Skipping night 3 (2024-04-04) due to insufficient observations: 1
# Skipping night 4 for 2021TG14 due to non-physical fit estimations
# REJECTED: Missing data for 2019JY7
# Skipping night 2 for 2017TU5 due to non-physical fit estimations
# Skipping night 1 for 2024UF6 due to non-physical fit estimations
# Skipping night 2 for 2024UF6 due to non-physical fit estimations
# Skipping night 1 (2011-10-26) due to insufficient observations: 1
# REJECTED: Missing data for 2019VA4
# Skipping night 4 (2019-09-26) due to insufficient observations: 1
# Skipping night 8 for 2018VX1 due to non-physical fit estimations
# Skipping night 4 (2010-09-08) due to insufficient observations: 1
# Skipping night 6 (2018-06-15) due to insufficient observations: 1
# Skipping night 2 for 2005US64 due to non-physical fit estimations
# Skipping night 1 (2010-03-07) due to insufficient observations: 1
# Skipping night 3 (2004-03-24) due to insufficient observations: 1
# Skipping night 4 (2004-03-25) due to insufficient observations: 1
# Skipping night 4 for 2022EU6 due to non-physical fit estimations
# Skipping night 3 (2023-03-18) due to insufficient observations: 1
# Skipping night 4 (2010-06-05) due to insufficient observations: 1
# Skipping night 4 (2023-05-27) due to insufficient observations: 1
# Skipping night 4 (2023-06-21) due to insufficient observations: 1
# Skipping night 1 for 2018TH3 due to non-physical fit estimations
# Skipping night 1 (2021-12-08) due to insufficient observations: 1
# Skipping night 1 (2014-04-21) due to insufficient observations: 1
# Skipping night 6 for 2014KQ75 due to non-physical fit estimations
# Skipping night 8 (2016-12-12) due to insufficient observations: 1
# REJECTED: Missing data for 2004HT38
# Skipping night 6 for 2022UP17 due to non-physical fit estimations
# Skipping night 1 (2018-11-28) due to insufficient observations: 1
# Skipping night 5 for 2015MA54 due to non-physical fit estimations
# Skipping night 3 (2020-01-23) due to insufficient observations: 1
# Skipping night 8 for 2020PY2 due to non-physical fit estimations
# Skipping night 3 for 2012TR231 due to non-physical fit estimations
# Skipping night 1 for 2023TM14 due to non-physical fit estimations
# Skipping night 3 for 2015WZ12 due to non-physical fit estimations
# Skipping night 3 for 2025EX1 due to non-physical fit estimations
# Skipping night 2 for 2021ST1 due to non-physical fit estimations
# Skipping night 2 for 2009JL2 due to non-physical fit estimations
# Skipping night 2 for 2024SS1 due to non-physical fit estimations
# Skipping night 3 (2022-05-31) due to insufficient observations: 1
# Skipping night 5 (2022-06-03) due to insufficient observations: 1
# Skipping night 1 (2010-09-02) due to insufficient observations: 1
# Skipping night 1 (2021-07-07) due to insufficient observations: 1
# Skipping night 2 (2012-12-13) due to insufficient observations: 1
# Skipping night 2 (2019-04-06) due to insufficient observations: 1
# Skipping night 6 (2019-04-10) due to insufficient observations: 1
# Skipping night 5 (2019-05-10) due to insufficient observations: 1
# Skipping night 2 (2024-03-12) due to insufficient observations: 1
# REJECTED: Missing data for 2022UO10
# Skipping night 2 (2019-10-01) due to insufficient observations: 1
# Skipping night 3 (2023-03-18) due to insufficient observations: 1
# /tmp/ipykernel_133967/1737075548.py:216: RankWarning: Polyfit may be poorly conditioned
#   a_fit = np.polyfit(t, alpha, 1)
# /tmp/ipykernel_133967/1737075548.py:217: RankWarning: Polyfit may be poorly conditioned
#   d_fit = np.polyfit(t, delta, 1)
# Skipping night 6 for 2015OQ21 due to non-physical fit estimations
# REJECTED: Missing data for 2014FK38
# Skipping night 2 (2022-12-16) due to insufficient observations: 1
# Skipping night 3 for 2023CL1 due to non-physical fit estimations
# Skipping night 1 for 2019XL3 due to non-physical fit estimations
# Skipping night 2 (2010-10-07) due to insufficient observations: 1
# Skipping night 2 (2025-05-25) due to insufficient observations: 1
# Skipping night 3 (2025-05-26) due to insufficient observations: 1
# REJECTED: Missing data for 2021UW3
#
# 💾 Creating final DataFrame and saving to CSV...
#
# 📊 PROCESSING SUMMARY:
#    🎯 Target NEOs: 9000
#    ✅ Successfully processed: 7042
#    ❌ Rejected: 168
#    📊 Total data rows: 25404
#    🎯 Success rate: 97.7%
#
# 📋 Final dataset structure:
#    Basic fields: 7
#    Keplerian elements: 6 (a_kep, e, i, Omega, omega, M)
#    Equinoctial elements: 6 (a_equ, h, k, p, q, lambda)
#    Total columns: 19
#    Note: Separate semi-major axes: a_kep (Keplerian) and a_equ (Equinoctial)
#
# 🎉 SUCCESS! Pipeline complete.
# Dataset saved to: ./DataSet_NEO_VSA_from1to8nights.csv
# 📋 Columns: ['object', 'night', 't_fit', 'alpha', 'delta', 'alpha_dot', 'delta_dot', 'a_kep', 'e', 'i', 'Omega', 'omega', 'M', 'a_equ', 'h', 'k', 'p', 'q', 'lambda']
